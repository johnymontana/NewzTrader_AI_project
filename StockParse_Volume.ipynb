# %%
import pandas as pd
from datetime import datetime
from pandas.io.data import DataReader
from pandas.io.data import DataReader
class AutoVivification(dict):
    """Implementation of perl's autovivification feature."""
    def __getitem__(self, item):
        try:
            return dict.__getitem__(self, item)
        except KeyError:
            value = self[item] = type(self)()
            return value
        
# declare global DataFrame- sp500Frame (populate with SPX prices?)
sp500 = DataReader("SPY", "yahoo", datetime(2010, 1, 1))
sp500['UP']=0
sp500['DOWN']=0
sp500['NONE']=0
sp500News = AutoVivification()

pd.set_printoptions(max_rows=2000)
def only_alphanum(s):
    #s = unicode(s, "utf-8")
    return ' '.join(c for c in s.split() if c.isalnum())
def only_alpha(s):
    return ' '.join(c for c in s.split() if c.isalpha())
def removeNonAscii(s): return "".join(i for i in s if ord(i)<128)

def stockNewsGetter(ticker):
    import pandas as pd
    from datetime import datetime
    
    aapl = DataReader(ticker, "yahoo", datetime(2010, 1, 1))
   # returns = aapl.pct_change()
    
  #  def f(x):
  #      if x 
  #  def f(x):
  #      if x > 0.05:
  #          return 1
  #      elif x < -0.05:
  #          return -1
  #      else:
  #          return 0
   

   # frame = returns.applymap(f)
    frame=aapl
    frame['MA20_Volume']= pd.rolling_mean(frame['Volume'], 20)
   # frame['UP'] = frame['Volume'] == 1
   # frame['DOWN'] = frame['Volume'] == -1
   # frame['NONE'] = frame['Volume'] == 0
   
    #frame['UP'] = frame['Volume'] > (1.05 * frame['MA20_Volume'])
    #frame['DOWN'] = frame['Volume'] < (.95 * frame['MA20_Volume'])
    #frame['NONE'] = (frame['Volume'] > (.95 * frame['MA20_Volume']) and frame['Volume'] < (1.05*frame['MA20_Volume']))
    #frame['NONE'] = frame['UP']== False & frame['DOWN']==False
    #frame['UP'] = frame['MA20_Volume'] == 1
    #frame['DOWN'] = fram['MA20_Volume'] == -1
    #frame['NONE'] = frame['MA20_Volume'] == 0
    
    frame['UP'] = frame['Volume'] > (frame['MA20_Volume'] *1.2)
    frame['DOWN'] = frame['Volume'] < (frame['MA20_Volume'] * 0.8)
    frame['NONE'] = (frame.UP==False) & (frame.DOWN==False)
    
    sp500['UP'] += frame['UP'].dropna()==True
    sp500['DOWN'] += frame['DOWN'].dropna()==True
    sp500['NONE'] += frame['NONE'].dropna()==True
    
    from lxml import etree
    import datetime
    from dateutil.parser import parse
    path = "http://www.google.com/finance/company_news?q=%s&output=rss&num=500"% ticker
    root = etree.parse(path)
    myRoot = root.getroot()
    news={}
    for element in myRoot.iter("item"):
        for item in element.iter("pubDate"):
            pubDate = parse(item.text)
        for item in element.iter("title"):
            title = item.text
        news[pubDate.date()]=only_alphanum(removeNonAscii(title))
        sp500News[ticker][pubDate.date()]=only_alphanum(removeNonAscii(title))
    newsframe = pd.Series(news)
    frameWithNews = frame.join(pd.DataFrame(newsframe))
    #newsUP = frameWithNews['UP'==True]
    #newsDOWN = frameWithNews['DOWN'==True]
    #newsNONE = frameWithNews['NONE' == True]
    newsUP_frame = frameWithNews[frameWithNews['UP']==True]
    newsDOWN_frame = frameWithNews[frameWithNews['DOWN']==True]
    newsNONE_frame = frameWithNews[frameWithNews['NONE']==True]
    
    newsUP = newsUP_frame[0]
    newsDOWN = newsDOWN_frame[0]
    newsNONE = newsNONE_frame[0]
    
    import pandas.io as io
    
    if newsUP.dropna().count() > 1:
        newsUP.dropna().to_csv('%s_news_UP.csv'% ticker)
    if newsDOWN.dropna().count() > 1:
        newsDOWN.dropna().to_csv('%s_news_DOWN.csv'% ticker)
    if newsNONE.dropna().count() >1:
        newsNONE.dropna().to_csv('%s_news_NONE.csv' % ticker)

filename = 'sp_500.txt'
tickers = open(filename)
tickerz = tickers.readlines()
tickerzz = []
for ticker in tickerz:
    tickerzz.append(only_alphanum(ticker))
print tickerzz
for ticker in tickerzz:
    stockNewsGetter(ticker)
# Out:
# ['AAPL', 'XOM', 'GE', 'CVX', 'MSFT', 'IBM', 'T', 'GOOG', 'PG', 'JNJ', 'PFE', 'WFC', 'JPM', 'PM', 'KO', 'MRK', 'VZ', 'WMT', 'ORCL', 'INTC', 'PEP', 'ABT', 'QCOM', 'CSCO', 'SLB', 'C', 'CMCSA', 'BAC', 'DIS', 'MCD', 'AMZN', 'HD', 'KFT', 'V', 'OXY', 'COP', 'MO', 'UTX', 'USB', 'AMGN', 'CVS', 'MMM', 'EMC', 'UNH', 'BMY', 'UNP', 'CAT', 'EBAY', 'AXP', 'UPS', 'GS', 'ESRX', 'GILD', 'NWSA', 'MON', 'MA', 'LLY', 'CL', 'BA', 'DD', 'HON', 'SPG', 'DUK', 'ACN', 'MDT', 'COST', 'TWX', 'TGT', 'SO', 'SBUX', 'AIG', 'F', 'FCX', 'MET', 'BIIB', 'EMR', 'APC', 'NKE', 'DOW', 'LOW', 'NOV', 'KMB', 'APA', 'HPQ', 'PNC', 'COF', 'BAX', 'TJX', 'CELG', 'DTV', 'DE', 'DHR', 'TXN', 'HAL', 'WAG', 'PX', 'PCLN', 'EXC', 'D', 'EOG', 'YUM', 'NEE', 'TWC', 'PSX', 'COV', 'ADP', 'AMT', 'AGN', 'NEM', 'BK', 'TRV', 'TYC', 'GIS', 'ITW', 'ACE', 'PRU', 'VIAB', 'CTL', 'LMT', 'FDX', 'PCP', 'BBT', 'MS', 'BLK', 'DVN', 'AFL', 'ALXN', 'GD', 'WMB', 'CBS', 'CSX', 'TMO', 'AEP', 'CTSH', 'MRO', 'DFS', 'NSC', 'MCK', 'CB', 'KMI', 'STT', 'PSA', 'BHI', 'ISRG', 'GLW', 'CRM', 'ALL', 'SE', 'HCP', 'RTN', 'WLP', 'CCI', 'JCI', 'MPC', 'MMC', 'FE', 'VTR', 'SYY', 'PCG', 'HNZ', 'ADM', 'BRCM', 'ED', 'PPG', 'CME', 'LYB', 'APD', 'VLO', 'EQR', 'BEN', 'ECL', 'PPL', 'AON', 'WFM', 'BXP', 'YHOO', 'S', 'NBL', 'NOC', 'CMI', 'CCL', 'PEG', 'INTU', 'PLD', 'SYK', 'TROW', 'COH', 'ADBE', 'HES', 'ETN', 'MOS', 'IP', 'BDX', 'MHP', 'STI', 'LO', 'M', 'MJN', 'EIX', 'EL', 'DISCA', 'HCN', 'BBBY', 'TEL', 'SRE', 'MSI', 'ROST', 'DELL', 'CTXS', 'FITB', 'RAI', 'PCAR', 'WY', 'SCHW', 'VFC', 'WM', 'CF', 'AZO', 'AMAT', 'CAM', 'VNO', 'OMC', 'CI', 'XEL', 'A', 'CAH', 'AET', 'STJ', 'AVB', 'L', 'IR', 'PXD', 'KR', 'SWK', 'K', 'TDC', 'SHW', 'ESV', 'SYMC', 'PH', 'GWW', 'EW', 'ETR', 'NUE', 'SWN', 'MAT', 'CBE', 'NU', 'AMP', 'NTAP', 'ZMH', 'LTD', 'ADI', 'PGR', 'HST', 'FAST', 'MTB', 'HOT', 'RRC', 'HUM', 'CERN', 'CAG', 'IVZ', 'DLTR', 'KSS', 'FTI', 'RHT', 'WU', 'STX', 'DOV', 'ALTR', 'WPI', 'HSY', 'ROP', 'PAYX', 'GPS', 'SNDK', 'DTE', 'PRGO', 'RF', 'NTRS', 'DGX', 'CMG', 'FISV', 'ORLY', 'MUR', 'OKE', 'MYL', 'MAR', 'ROK', 'CHK', 'ABC', 'ICE', 'HOG', 'XRX', 'APH', 'GPC', 'CHRW', 'SJM', 'AA', 'COG', 'FLR', 'DPS', 'CLX', 'RL', 'WYNN', 'BEAM', 'CNP', 'NE', 'JNPR', 'LH', 'EQT', 'CA', 'DVA', 'XLNX', 'EMN', 'SIAL', 'WEC', 'CCE', 'WDC', 'LIFE', 'MCO', 'HIG', 'JWN', 'FRX', 'MNST', 'FFIV', 'NVDA', 'KIM', 'KEY', 'RSG', 'MKC', 'BCR', 'BSX', 'KLAC', 'AEE', 'BWA', 'SPLS', 'FIS', 'SRCL', 'EXPD', 'COL', 'VRSN', 'FMC', 'ADSK', 'PFG', 'WYN', 'SLM', 'PLL', 'TIF', 'TXT', 'XL', 'LLTC', 'WAT', 'NI', 'DRI', 'PCL', 'TAP', 'LLL', 'AVP', 'CNX', 'AES', 'AKAM', 'LNC', 'VAR', 'BLL', 'FLS', 'LUV', 'KMX', 'FDO', 'WHR', 'MCHP', 'SCG', 'DNR', 'CFN', 'CPB', 'CMS', 'VMC', 'MU', 'BMC', 'NYX', 'CMA', 'BTU', 'WIN', 'JOY', 'HBAN', 'TSO', 'HRS', 'LRCX', 'PNW', 'DHI', 'ARG', 'LEN', 'QEP', 'EFX', 'CVH', 'CLF', 'CBG', 'CINF', 'HSP', 'EXPE', 'XRAY', 'UNM', 'MAS', 'MWV', 'SNI', 'PWR', 'JEC', 'PHM', 'IRM', 'HP', 'CSC', 'SUN', 'TMK', 'FTR', 'NRG', 'IPG', 'IFF', 'GAS', 'STZ', 'HRB', 'XYL', 'TSN', 'FOSL', 'DO', 'BBY', 'LUK', 'CTAS', 'HAS', 'POM', 'PBCT', 'NFX', 'RDC', 'SNA', 'GCI', 'URBN', 'NBR', 'TEG', 'EA', 'HRL', 'SWY', 'LSI', 'TSS', 'ZION', 'HCBK', 'AIV', 'RHI', 'PCS', 'MOLX', 'TE', 'TRIP', 'DNB', 'LEG', 'JBL', 'IGT', 'JCP', 'CVC', 'ATI', 'SAI', 'PKI', 'WPX', 'BMS', 'AVY', 'HAR', 'OI', 'AIZ', 'NFLX', 'DF', 'FLIR', 'GT', 'LM', 'APOL', 'PDCO', 'JDSU', 'ANF', 'PBI', 'NDAQ', 'X', 'SEE', 'TER', 'THC', 'GME', 'GNW', 'FHN', 'ETFC', 'AMD', 'R', 'FII', 'RRD', 'BIG', 'AN', 'WPO', 'LXK', 'ANR', 'FSLR', 'DV', 'TIE']

# %%
sp500News
# Out:
# {'A': {datetime.date(2010, 11, 12): 'Agilent Issues Q1 2011 Guidance Above Issues FY 2011 Guidance In Line With Estimates',
#   datetime.date(2010, 11, 16): 'Agilent Launches Chromatography Data System',
#   datetime.date(2010, 11, 29): 'Agilent Secures Million Contract From Navy For Handheld Spectrum Analyzers',
#   datetime.date(2010, 12, 8): 'Agilent Collaborates With University of Davis On Food Safety Research',
#   datetime.date(2011, 1, 19): 'Agilent Signs Agreement To Acquire Assets of A2 Technologies',
#   datetime.date(2011, 2, 1): 'Atheros Selects Agilent Software For Testing Over Secure User Plane In Cellular Mobile Devices',
#   datetime.date(2011, 2, 2): 'Agilent Introduces SureSelect RNA Capture Kits',
#   datetime.date(2011, 2, 14): 'Agilent Launches Three New LTE Design Verification And Conformance Systems',
#   datetime.date(2011, 2, 16): 'Agilent Signs Licensing Agreement With Qualcomm For Factory Test Technology',
#   datetime.date(2011, 2, 24): 'Harvard Medical School Laboratory Selects Agilent NMR Spectrometer For Biomolecular Applications',
#   datetime.date(2011, 2, 28): 'Agilent Acquires Lab901',
#   datetime.date(2011, 3, 1): 'Agilent Acquires BIOCIUS Life',
#   datetime.date(2011, 4, 20): 'Breast Cancer Study Chooses Agilent Microarrays as Primary Genomic Screening Tool',
#   datetime.date(2011, 5, 3): 'Agilent Announces DisplayPort Source Compliance And Validation Software',
#   datetime.date(2011, 5, 13): 'Agilent Issues Q3 2011 Guidance Above Raises FY 2011 Guidance',
#   datetime.date(2011, 5, 18): 'TriQuint And Agilent Collaborate On Wireless Design Flow',
#   datetime.date(2011, 5, 26): 'Genetic Technologies Limited Files New Patent Infringement Suit Against Agilent Technologies In USA',
#   datetime.date(2011, 8, 15): 'Agilent Issues Q4 2011 Guidance In Line With Raises FY 2011 Guidance',
#   datetime.date(2011, 9, 19): 'Agilent Announces Signal Analyzer For Wide Bandwidth Signal Analysis',
#   datetime.date(2011, 10, 27): 'Agilent Secures Contract From Ambry Genetics',
#   datetime.date(2011, 11, 16): 'Agilent Issues FY 2012 Guidance In Line With Call',
#   datetime.date(2011, 12, 1): 'Agilent Announces Acquisitions Of Halo Genomics And Automated Analytical Solutions',
#   datetime.date(2011, 12, 13): 'Agilent Announces Yale University Adopts Multiple Agilent Platforms For Integrative Biology Research At New West Campus',
#   datetime.date(2011, 12, 21): 'Agilent Completes Acquisition of BioSystem Development Including AssayMAP Microchromatography Platform for Automated Analytical Solutions for Pharma',
#   datetime.date(2012, 1, 18): 'Agilent Announces First Cash Dividend of per Share',
#   datetime.date(2012, 2, 15): 'Agilent Issues Q2 2012 Guidance Below Narrows FY 2012 Guidance To A Range In Line With Estimates',
#   datetime.date(2012, 2, 21): u'Agilent Completes Acquisition Of Accelicon Technologies Solutions For Semiconductor Device Modeling',
#   datetime.date(2012, 3, 28): 'Electronics Maker SigmaTron Selects Agilent Test Equipment',
#   datetime.date(2012, 4, 25): 'Comtech EF Data Selects Agilent Advanced Design System',
#   datetime.date(2012, 4, 27): u'Agilent Inc And Centellax Announce Agilent Will Acquire Centellaxs Test and Measurement Business',
#   datetime.date(2012, 5, 14): 'Agilent Issues Q3 2012 Revenue Guidance Above Narrows FY 2012 Revenue Raises EPS Guidance',
#   datetime.date(2012, 5, 15): 'ADATA Technology Co Selects Agilent Advanced Design System To Speed Product Development',
#   datetime.date(2012, 5, 16): 'Agilent Announces Cash Dividend of per Share',
#   datetime.date(2012, 5, 17): 'Agilent To Acquire Dako For Billion',
#   datetime.date(2012, 6, 21): 'Agilent Completes Acquisition of Dako',
#   datetime.date(2012, 7, 16): u'Agilent Signs Agreement To Acquire AT4 wireless Test Systems Business',
#   datetime.date(2012, 8, 15): 'Agilent Technologies Inc Lowers FY 2012 Issues Q4 2012 Guidance Below Estimates',
#   datetime.date(2012, 8, 20): 'Agilent Technologies Inc Secures Patent For CGH Assays',
#   datetime.date(2012, 8, 22): 'Agilent Technologies Inc and China Mobile Communications Ltd Agree to Collaborate to Develop Solutions for Radio Access Network',
#   datetime.date(2012, 8, 27): 'Agilent Technologies Inc Announces Acquisition of Aurora SFC',
#   datetime.date(2012, 8, 31): 'Agilent Technologies Inc Introduces 14 FieldFox Handheld Analyzers',
#   datetime.date(2012, 9, 4): 'Agilent Technologies Inc Introduces PXI Vector Signal Generator',
#   datetime.date(2012, 9, 7): u'Agilent Technologies Inc Signs Exclusive Supply Agreement To Provide Components For LipoSciences Vantera Clinical Analyzer',
#   datetime.date(2012, 9, 10): 'Agilent Technologies Inc Announces Offering Of Senior Notes',
#   datetime.date(2012, 9, 13): 'Agilent Technologies Inc and CATR to Collaborate on MIMO',
#   datetime.date(2012, 9, 20): 'Agilent Technologies Inc Announces Cash Dividend of per Share',
#   datetime.date(2012, 10, 3): 'Agilent Technologies Inc Introduces Handheld Digital Multimeter Designed for Extreme Winter Weather',
#   datetime.date(2012, 10, 11): 'Agilent Technologies and University of Houston to Advance Petroleum Research',
#   datetime.date(2012, 10, 17): 'TRADE Agilent Technologies to Demonstrate Newest Microwave and RF',
#   datetime.date(2012, 10, 22): 'TRADE Agilent Technologies to Demonstrate Digital Design',
#   datetime.date(2012, 10, 26): 'Marathon Petroleum Achieves Analyst Surpassing Agilent Technologies',
#   datetime.date(2012, 10, 29): 'TRADE Agilent Technologies Expands Capabilities of Handheld',
#   datetime.date(2012, 10, 30): 'AGILENT TECHNOLOGIES Agilent Technologies and Centre for',
#   datetime.date(2012, 11, 1): 'TRADE Agilent Technologies Introduces Solution for',
#   datetime.date(2012, 11, 2): 'Agilent Technologies Announces Precision Power Source for',
#   datetime.date(2012, 11, 5): 'AGILENT TECHNOLOGIES Agilent Technologies to Host Webcast of',
#   datetime.date(2012, 11, 6): 'AGILENT TECHNOLOGIES Agilent Technologies and Bangor University',
#   datetime.date(2012, 11, 7): 'Agilent to Provide Service and Support for NimbleGen as Roche Shutters',
#   datetime.date(2012, 11, 8): 'Agilent Technologies and Roche Establish Agreement to Provide Continued'},
#  'AA': {datetime.date(2011, 1, 21): 'Alcoa Declares Common And Preferred Stock Dividend',
#   datetime.date(2011, 1, 31): 'Alcoa To Acquire TransDigm Group Fastener Business',
#   datetime.date(2011, 3, 2): 'Alcoa Announces Ownership Stake In Electronic Recyclers International',
#   datetime.date(2011, 3, 3): 'Alcoa Acquires Ownership of Carbothermic Smelting Technology from Orkla',
#   datetime.date(2011, 3, 9): 'TransDigm Group Incorporated Completes Fastener Businesses Divestiture To Alcoa',
#   datetime.date(2011, 4, 13): 'Alcoa Announces Pricing of Notes Offering',
#   datetime.date(2011, 5, 5): 'Alcoa Declares Common And Preferred Share Dividend',
#   datetime.date(2011, 5, 13): 'Alcoa Inc Announces Expiration And Final Results Of Tender Offers For Notes Due 2013 And Notes Due 2013',
#   datetime.date(2011, 6, 17): 'Alcoa And Sign Memorandum Of Understanding For Technical And Commercial Collaboration',
#   datetime.date(2011, 6, 24): 'Alcoa Signs Contract to Supply Aluminum Solutions to Airbus',
#   datetime.date(2011, 7, 1): 'Alcoa Partners with the Global Reporting Initiative to Develop the Next Generation of Sustainability Reporting Guidelines',
#   datetime.date(2011, 7, 22): 'Alcoa Announces Quarterly Dividend',
#   datetime.date(2011, 9, 14): 'Alcoa CPI Announce Letter Of Intent To Develop Joint Venture Producing High End Aluminum Products',
#   datetime.date(2011, 9, 30): 'Alcoa Announces Quarterly Dividend',
#   datetime.date(2011, 10, 16): u'Alcoa and Maaden Complete Aluminum Project Financing Agreements',
#   datetime.date(2012, 9, 5): 'Glencore International PLC Ready To Make Offer For Alcoa Sardinia',
#   datetime.date(2012, 9, 27): 'Alcoa Inc Announces Quarterly Dividend',
#   datetime.date(2012, 10, 9): 'Alcoa Inc And Aluminium Bahrain Resolve Civil Litigation',
#   datetime.date(2012, 10, 10): 'Oil Falls on Expectations of Gain in US Supply Report',
#   datetime.date(2012, 10, 11): 'Alcoa Pulled Back After Full Year Forecast Trimmed',
#   datetime.date(2012, 10, 12): 'US Stocks Fall Most in Week Since June on Profits',
#   datetime.date(2012, 10, 15): 'Alcoa Signs Tentative BPA Contract Analyst Blog',
#   datetime.date(2012, 10, 17): 'GDF Suez SA Inaugurates MW Estreito Hydro Power Plant in Brazil Owned in Partnership with Vale SA and Alcoa Inc',
#   datetime.date(2012, 10, 23): 'Aluminum Oversupply And Weak Outlook Make The Stock A Buy',
#   datetime.date(2012, 10, 30): 'ALCOA Alcoa Design Driver on Buildings',
#   datetime.date(2012, 11, 5): 'After Hours Most Active for Nov 2012 FTR',
#   datetime.date(2012, 11, 6): 'ALCOA Alcoa Congratulates Tesla on the Model S Being',
#   datetime.date(2012, 11, 8): 'Trading in First Carbon Units Shows Progress in Australia'},
#  'AAPL': {datetime.date(2010, 11, 10): 'Dentsu Announces Partnership with Apple to Bring iAd to Japan',
#   datetime.date(2010, 11, 16): 'Hrvatski Telekom Signs Agreement With Apple',
#   datetime.date(2010, 12, 16): 'Nokia Oyj Files Patent Infringement Complaints against Apple in Germany and Netherlands',
#   datetime.date(2010, 12, 28): 'Apple Sued For Allegedly Sending User Data To',
#   datetime.date(2010, 12, 29): 'Microsoft Relaunches Tech Patent Suit Against Apple Google Facebook And',
#   datetime.date(2011, 1, 11): 'Hagens Berman Investigates Claims Apple iPhone Glass Prone to Breakage',
#   datetime.date(2011, 1, 17): 'Apple Steve Jobs Takes Second Medical',
#   datetime.date(2011, 1, 18): 'Apple Issues Q2 2011 Guidance Above Estimates',
#   datetime.date(2011, 1, 24): 'Eastman Kodak Company Receives Notice of Initial Determination In ITC Patent Infringement Action Against Apple And Research In Motion Limited',
#   datetime.date(2011, 1, 31): 'To Reach Settlement With Apple',
#   datetime.date(2011, 2, 17): 'Telling Telecom Holding Subsidiary Signs Agreement to Be Apple Distributor',
#   datetime.date(2011, 2, 18): 'US Regulators Probe Apple Subscription',
#   datetime.date(2011, 2, 24): 'Intel Corporation Announces Thunderbolt Technology In Collaboration With',
#   datetime.date(2011, 3, 2): 'Apple Announces Launch Of iPad 2',
#   datetime.date(2011, 3, 15): 'Apple Delays iPad 2 Launch In',
#   datetime.date(2011, 3, 22): 'Apple Sues Over APP STORE',
#   datetime.date(2011, 3, 25): 'Eastman Kodak Company Wins Round In Research In Motion Limited And Apple Inc',
#   datetime.date(2011, 3, 28): 'ECS ICT Bhd Receives Distributorship Award From Apple For Apple iPad In Malaysia',
#   datetime.date(2011, 3, 29): 'Nokia Corporation Files Second ITC Complaint Against Apple',
#   datetime.date(2011, 4, 11): 'Bharti Airtel Aircel To Sell Apple iPhone 4 In',
#   datetime.date(2011, 4, 12): 'Walker Digital Files 15 Lawsuits Against Apple And',
#   datetime.date(2011, 4, 18): 'Apple Sues Samsung Electronics Over Galaxy',
#   datetime.date(2011, 4, 20): 'Apple Issues Q3 2011 EPS Guidance Below Estimates',
#   datetime.date(2011, 4, 25): 'Samsung Electronics Counter Sues Apple Over',
#   datetime.date(2011, 4, 29): 'Apple Launches iPad 2 In Standard',
#   datetime.date(2011, 5, 5): 'Lawsuit Accuses Adobe Apple Google Intel Corporation And Intuit For Fixing',
#   datetime.date(2011, 5, 30): 'Samsung Electronics Asks Court To Force Apple Inc To Hand Over Its Models Of iPhone And',
#   datetime.date(2011, 6, 4): 'US Probes Apple Bid For Nortel',
#   datetime.date(2011, 6, 11): 'Apple Recalls Some Verizon iPad 2',
#   datetime.date(2011, 6, 14): 'Nokia Corporation Enters Into Patent License Agreement With Apple',
#   datetime.date(2011, 6, 17): 'Apple And Samsung Electronics In Talks On Patent',
#   datetime.date(2011, 6, 18): 'Apple Intel Corporation And Telefonaktiebolaget LM Ericsson Vie For Nortel Patents With Google',
#   datetime.date(2011, 6, 22): 'Apple May Face Antitrust Probe In',
#   datetime.date(2011, 6, 23): 'Apple Wins Antitrust Clearance To Bid On Nortel Networks',
#   datetime.date(2011, 6, 24): 'Apple Apple Korea Sues Samsung Electronics In Seoul Over',
#   datetime.date(2011, 6, 30): 'Samsung Electronics Files Complaint Against Apple With US International Trade',
#   datetime.date(2011, 7, 1): 'Nortel Networks Announces Sale Of Its Patent Portfolio For Billion To A Consortium Which Include Apple',
#   datetime.date(2011, 7, 2): 'Samsung Electronics Drops Lawsuit Against Apple',
#   datetime.date(2011, 7, 6): 'Apple Trade Complaint With Authorities Against Samsung Electronics',
#   datetime.date(2011, 7, 7): 'Judge Rejects Apple Bid For Injunction Against',
#   datetime.date(2011, 7, 11): 'Apple Files Patent Complaint Against HTC',
#   datetime.date(2011, 7, 14): 'South Korean Attorney Files Suit Against Apple South Korea',
#   datetime.date(2011, 7, 15): 'Apple Notches Patent Win Against HTC',
#   datetime.date(2011, 7, 18): 'CORRECTION HTC Corp Will Appeal Decision In Favor of Apple On',
#   datetime.date(2011, 7, 19): 'Apple Issues Q4 2011 Guidance Below Estimates',
#   datetime.date(2011, 7, 22): 'Apple Joins Hulu Bid',
#   datetime.date(2011, 7, 29): 'Nortel Subsidiary Completes Sale of Patents And Patent Applications To A Consortium Which Include Apple',
#   datetime.date(2011, 8, 2): 'HTC Corp Sees Final Ruling On Apple Graphics Case In',
#   datetime.date(2011, 8, 9): 'Hagens Berman Files Lawsuit Against Apple News HarperCollins Pearson Penguin Group And CBS Simon Schuster',
#   datetime.date(2011, 8, 10): 'Apple Blocks Samsung Electronics From Selling Galaxy Tablet In',
#   datetime.date(2011, 8, 16): 'HTC Corp Sues Apple Over',
#   datetime.date(2011, 8, 17): 'Apple May Invest Billion In Sharp LCD Elpida Toshiba Corporation Expects Larger Orders From',
#   datetime.date(2011, 8, 18): 'China Mobile Limited Talking To Apple On',
#   datetime.date(2011, 8, 24): 'Steve Jobs Resigns as CEO of Apple Names Tim Cook As New CEO',
#   datetime.date(2011, 8, 25): 'German Court Upholds Apple Injunction On Samsung Electronics',
#   datetime.date(2011, 8, 31): 'Openwave Takes Legal Action Against Apple Inc And Research In Motion Limited To Protect Intellectual Property For Mobile Internet Access',
#   datetime.date(2011, 9, 2): 'Initiates Litigation Against Dell Company And Novatel',
#   datetime.date(2011, 9, 8): 'Google Assigns Patents To HTC Corp Used To Sue Apple',
#   datetime.date(2011, 9, 9): 'Apple Wins German Court Ruling On Samsung Electronics',
#   datetime.date(2011, 9, 19): 'Samsung Electronics Files Counter Claim In Australia Against Apple',
#   datetime.date(2011, 9, 22): 'VIA and Subsidiaries Sue Apple',
#   datetime.date(2011, 9, 28): 'Samsung Electronics Apple Tablet War Judgement Imminent In',
#   datetime.date(2011, 9, 29): 'Apple Jobs Tried To Defuse Samsung Electronics Patents',
#   datetime.date(2011, 10, 14): 'Samsung Electronics Loses Dutch Bid To Ban Apple Economic Times',
#   datetime.date(2011, 10, 17): 'Samsung Electronics Seeks Sales Ban On Apple iPhone 4S In',
#   datetime.date(2011, 10, 18): 'Apple Issues Q1 2012 Guidance Above Estimates',
#   datetime.date(2011, 11, 1): 'VirnetX Holding Corp Files New Complaint Against Apple',
#   datetime.date(2011, 11, 7): 'VirnetX Holding Inc Files Complaint Against Apple With International Trade Commission',
#   datetime.date(2011, 11, 15): 'Apple Names Arthur Levinson As Chairman Of Board',
#   datetime.date(2011, 11, 25): 'Samsung Electronics Attorney Says Judge Wrong In Australian Apple',
#   datetime.date(2011, 11, 30): 'Samsung Electronics Scores Patent Win Against Apple',
#   datetime.date(2011, 12, 1): 'NTT Denies Basic Agreement With Apple',
#   datetime.date(2011, 12, 6): 'Chinese Court Rejects Apple Lawsuit Over iPad',
#   datetime.date(2012, 1, 20): 'German Court Grants Victory To Apple In Patent Suit With Samsung Electronics',
#   datetime.date(2012, 1, 24): 'Apple Issues Q2 2012 Guidance Above Estimates',
#   datetime.date(2012, 1, 25): 'Motorola Mobility Holdings Inc Sues Apple Over New',
#   datetime.date(2012, 2, 7): 'Apple In Talks On iTV With Canada',
#   datetime.date(2012, 2, 9): 'Department of Justice Set To Clear Apple And To Buy Pending Patents From Nortel',
#   datetime.date(2012, 2, 13): 'Apple Launches New Legal Attack On Samsung',
#   datetime.date(2012, 2, 16): 'Apple Seeks Court Permission To Sue Eastman Kodak',
#   datetime.date(2012, 2, 18): 'Motorola Mobility Says Apple Files EU Patent',
#   datetime.date(2012, 2, 24): 'Apple Acquires Engine',
#   datetime.date(2012, 3, 2): 'German Court Dismisses Apple Suit Against Samsung Electronics Co Favor On',
#   datetime.date(2012, 3, 7): 'Samsung Electronics Co Ltd Files Fresh Lawsuit Against Apple In South',
#   datetime.date(2012, 3, 9): 'Apple To Build Million Campus In',
#   datetime.date(2012, 3, 12): 'Apple Motorola Mobility Holdings Held Talks Late',
#   datetime.date(2012, 3, 19): 'Apple Announces Plans To Initiate Dividend And Share Repurchase Program',
#   datetime.date(2012, 3, 20): 'Apple iPad Heat Reports Probe',
#   datetime.date(2012, 3, 27): 'Apple Four Others Sued By Graphics Properties Holdings',
#   datetime.date(2012, 4, 5): 'Apple Two Publishers Hold Out Against',
#   datetime.date(2012, 4, 10): 'DOJ May Sue Apple Over',
#   datetime.date(2012, 4, 11): 'Sues Apple Publishers In Price',
#   datetime.date(2012, 4, 13): 'Apple Inc Rejects Pricing Collusion',
#   datetime.date(2012, 4, 17): 'US Judge Sends Apple Samsung Electronics Co Ltd To Settlement',
#   datetime.date(2012, 4, 18): 'Apple Visa Intel The Company and Bank of America Corp Start Trading on Bucharest The Corporate Wire',
#   datetime.date(2012, 4, 19): 'Apple Inc And Other Technology Companies Fail To Dismiss',
#   datetime.date(2012, 4, 20): 'Hagens Berman Announces Lawsuit Claims Wide Range Of Apple Devices Infringe Patents For Screen Manipulation',
#   datetime.date(2012, 4, 24): 'Apple Inc Infringes On Motorola Mobility Holdings Inc ITC',
#   datetime.date(2012, 4, 25): 'Potter Voice Technologies Files Colorado Patent Infringement Lawsuit Against Apple Says The Lanier Law Firm',
#   datetime.date(2012, 4, 26): 'VirnetX Holding Corp Receives Markman Order In Patent Infringement Action Against Cisco Apple NEC And Aastra',
#   datetime.date(2012, 5, 8): 'US Judge Dismisses Ipad Suit Vs Apple',
#   datetime.date(2012, 5, 14): 'US Court Revives Apple Claim On Samsung Electronics Co',
#   datetime.date(2012, 5, 21): 'Apple Samsung Electronics Co Ltd CEOs In US Court Talks On',
#   datetime.date(2012, 6, 7): 'Samsung Electronics Co Ltd Says Galaxy S III Launch To Go Despite Apple',
#   datetime.date(2012, 6, 13): 'Apple Inc Fails To Fend Off Mobile Tracking Federal Judge Dismisses Google Inc And Several Other Defendants From',
#   datetime.date(2012, 6, 14): 'Judge Gives Apple Inc Reprieve In Patent Case Versus Google',
#   datetime.date(2012, 6, 19): 'NTT Not In Sync With Selling Apple iPhone In',
#   datetime.date(2012, 6, 20): 'Eastman Kodak Company Sues Apple Claiming Interference In Patent',
#   datetime.date(2012, 6, 21): 'Dutch Court Gives Samsung Electronics Co Ltd Rare Victory Over Apple',
#   datetime.date(2012, 6, 23): 'US Judge Blocks Apple Inc In Google Smartphone',
#   datetime.date(2012, 6, 24): 'Research In Considers Splitting Business In Potential Buyers May Be And Facebook Open Up To Apple Google',
#   datetime.date(2012, 6, 27): 'Judge Halts Sales Of Samsung Electronics Co Ltd Tab in Against Apple',
#   datetime.date(2012, 7, 1): 'Apple Wins Second Injunction Against Samsung Electronics Co Blocking Phone',
#   datetime.date(2012, 7, 2): 'Apple Inc Pays Million To Settle China iPad Trademark Dispute With Unit Of Proview International Holdings',
#   datetime.date(2012, 7, 3): 'Eastman Kodak Company Wins Approval To Auction Digital Imaging Patents Over Apple Complaint',
#   datetime.date(2012, 7, 4): 'Judge Rejects Samsung Electronics Co Request To Lift Stay On Nexus',
#   datetime.date(2012, 7, 5): 'China Tech Company Sues Apple Inc For Patent',
#   datetime.date(2012, 7, 7): 'Samsung Electronics Co Ltd Wins Bid To Sell Nexus In Apple Inc Court',
#   datetime.date(2012, 7, 9): 'Samsung Electronics Co Ltd Wins Court Case Against Apple Because As',
#   datetime.date(2012, 7, 18): 'Judge Rejects Secrecy Bids In Apple Inc Versus Samsung Electronics Co Ltd',
#   datetime.date(2012, 7, 19): 'HTC Corp Files Counterclaim Against Apple Inc In US',
#   datetime.date(2012, 7, 22): 'Eastman Kodak Company Loses Patent Case Versus Apple Inc And Research In Motion Plans',
#   datetime.date(2012, 7, 23): 'Apple Inc And Google Motorola Unit File Separate Patent The Economic Times',
#   datetime.date(2012, 7, 24): 'Apple Samsung Electronics Co Ltd Chiefs Disagree On Patent Reuters',
#   datetime.date(2012, 7, 26): 'Apple Inc Says Samsung Electronics Co Ltd Patent Royalty Demands Reuters',
#   datetime.date(2012, 7, 27): 'Apple Inc To Buy Fingerprint Sensor AuthenTec Inc For',
#   datetime.date(2012, 8, 6): 'Apple Inc And Google Inc Bid On Eastman Kodak Co',
#   datetime.date(2012, 8, 9): 'Google Inc Pays Million To Settle Apple Inc Safari',
#   datetime.date(2012, 8, 11): 'Suitors Bid Low For Eastman Kodak Co Apple Google And Microsoft Corp Reportedly Bidding For',
#   datetime.date(2012, 8, 14): 'Samsung Electronics Co Turn To Say Apple Inc Reuters',
#   datetime.date(2012, 8, 15): 'US Judge Urges Apple Samsung Electronics Co Ltd To Settle Before Reuters',
#   datetime.date(2012, 8, 17): 'Samsung Electronics Co Ltd Expert Says Apple Inc Overstates Damages At Reuters',
#   datetime.date(2012, 8, 21): 'Apple Samsung Electronics Co Ltd CEOs Talk But No Trial Settlement',
#   datetime.date(2012, 8, 22): 'Apple Samsung Electronics Co Ltd Make Final Pitch To',
#   datetime.date(2012, 8, 24): 'Seoul Court Rules Samsung Electronics Co Ltd Did Not Violate Apple',
#   datetime.date(2012, 8, 28): 'Apple Inc Seeks Quick Bans On Eight Samsung Electronics Co Ltd',
#   datetime.date(2012, 8, 30): 'Google Apple CEOs In Secret Patent',
#   datetime.date(2012, 8, 31): 'Samsung Electronics Co Ltd Wins Over Apple Inc In Japan Patent',
#   datetime.date(2012, 9, 1): 'Apple Targets More Samsung Electronics Co Ltd Products In Patent',
#   datetime.date(2012, 9, 6): 'Judge Approves Settlement With Apple Inc And Other Publishers Over',
#   datetime.date(2012, 9, 12): 'Apple Inc Introduces New iPod Touch iPod Nano',
#   datetime.date(2012, 9, 20): 'Unwired Planet Inc Charges Apple and Google Inc With Infringing 20 Patents',
#   datetime.date(2012, 10, 2): 'Google Motorola Mobility Withdraws Patent Claim Against Apple',
#   datetime.date(2012, 10, 3): 'Samsung Electronics Co Battling Apple Inc Cites Seagate',
#   datetime.date(2012, 10, 11): 'Court Clears Samsung Electronics Co Ltd Hands Apple',
#   datetime.date(2012, 10, 18): 'Apple Inc Loses Tablet Copyright Appeal Against Samsung Electronics Co',
#   datetime.date(2012, 10, 22): 'US Federal Agency To Switch To Apple Drop Research In Motion',
#   datetime.date(2012, 10, 23): 'Apple Inc To Sell Version iPad',
#   datetime.date(2012, 10, 24): 'Dutch Court Says Samsung Electronics Co Ltd Does Not Infringe Apple Inc',
#   datetime.date(2012, 10, 25): 'Apple Inc Declares Cash Dividend',
#   datetime.date(2012, 10, 30): 'Sharp Corp In Talks With Apple Google Inc And Microsoft Corp On LCD Panel',
#   datetime.date(2012, 11, 5): 'Judge Tosses Apple Versus Google Inc Lawsuit Over',
#   datetime.date(2012, 11, 6): 'Inc To Win EU Pricing Tussle With Apple',
#   datetime.date(2012, 11, 7): 'VirnetX Holding Corp Wins Over Million Verdict Against Apple Inc',
#   datetime.date(2012, 11, 8): 'Apple releases updates for iOS 6 apps'},
#  'ABC': {datetime.date(2010, 11, 11): 'AmerisourceBergen Increases Dividend',
#   datetime.date(2010, 11, 12): 'AmerisourceBergen Names Steve Collis President And Chief Operating Officer',
#   datetime.date(2010, 12, 16): 'AmerisourceBergen Reaffirms FY 2011 Guidance',
#   datetime.date(2011, 1, 6): 'AmerisourceBergen Corp Issues FY 2011 EPS Guidance In Line With Call',
#   datetime.date(2011, 2, 4): 'AmerisourceBergen Approves Quarterly Dividend',
#   datetime.date(2011, 3, 14): 'AmerisourceBergen Announces Retirement Of CEO',
#   datetime.date(2011, 4, 28): 'AmerisourceBergen Raises FY 2011 EPS Reaffirms FY 2011 Revenue Guidance',
#   datetime.date(2011, 5, 13): 'AmerisourceBergen Declares Dividend',
#   datetime.date(2011, 7, 1): 'Steven Collis Succeeds David Yost As CEO of AmerisourceBergen Corp',
#   datetime.date(2011, 7, 28): 'AmerisourceBergen Corp Raises FY 2011 EPS Reaffirms FY 2011 Revenue Guidance',
#   datetime.date(2011, 8, 11): 'AmerisourceBergen Corp Authorizes New Million Share Repurchase Program And Approves Quarterly Dividend',
#   datetime.date(2011, 9, 2): 'AmerisourceBergen Corp Acquires Premier Source',
#   datetime.date(2011, 9, 6): 'AmerisourceBergen Corp Acquires LLC',
#   datetime.date(2011, 9, 27): 'AmerisourceBergen Corp To Acquire A Subsidiary Of CVS Caremark Corporation',
#   datetime.date(2011, 11, 1): 'AmerisourceBergen Corp Issues FY 2012 EPS Guidance In Line With Comments On FY 2012 Revenue Guidance',
#   datetime.date(2011, 11, 8): 'AmerisourceBergen Corp Prices Million Senior Notes Due 2021',
#   datetime.date(2011, 11, 10): 'AmerisourceBergen Corp Increases Dividend',
#   datetime.date(2011, 12, 14): 'AmerisourceBergen Corp To Reaffirms FY 2012 Guidance',
#   datetime.date(2012, 1, 26): 'AmerisourceBergen Corp Reaffirms FY 2012 EPS Guidance',
#   datetime.date(2012, 2, 3): 'AmerisourceBergen Corp Approves Quarterly Dividend',
#   datetime.date(2012, 2, 13): 'AmerisourceBergen Corp Announces Departure Of Chief Financial Officer Michael Tim Guttman To Serve As Acting CFO',
#   datetime.date(2012, 3, 6): 'AmerisourceBergen Corp To Acquire World Courier Inc',
#   datetime.date(2012, 4, 26): 'AmerisourceBergen Corp Reaffirms FY 2012 Guidance',
#   datetime.date(2012, 5, 1): 'AmerisourceBergen Corp Completes Acquisition Of World Courier',
#   datetime.date(2012, 5, 10): 'AmerisourceBergen Corp Authorizes New Million Share Repurchase Program And Approves Quarterly Dividend',
#   datetime.date(2012, 5, 11): 'AmerisourceBergen Corp Names Tim Guttman Senior Vice President and Chief Financial Officer',
#   datetime.date(2012, 7, 26): 'AmerisourceBergen Corp Raises Low End Of Prior FY 2012 EPS Guidance To A Range In Line With Estimates',
#   datetime.date(2012, 7, 31): 'AmerisourceBergen Corp Signs Three Year Pharmaceutical Supply Agreement with Express Scripts',
#   datetime.date(2012, 8, 9): 'AmerisourceBergen Corp Approves Quarterly Dividend',
#   datetime.date(2012, 9, 6): 'Faruqi LLP is Investigating AmerisourceBergen Corp on Behalf of Shareholders',
#   datetime.date(2012, 9, 11): 'AmerisourceBergen Corp Comments On FY 2013 Call',
#   datetime.date(2012, 9, 12): 'AmerisourceBergen Corp Reaffirms FY 2012 EPS Call',
#   datetime.date(2012, 10, 19): 'Investment Ratings Reiterations for 19th ABE',
#   datetime.date(2012, 10, 23): 'Equities Research Ratings Reiterations for 23rd AAPL',
#   datetime.date(2012, 10, 26): 'affirms McKesson Corp outlook is Stable',
#   datetime.date(2012, 10, 29): 'AMERISOURCEBERGEN AmerisourceBergen Names Lawrence C',
#   datetime.date(2012, 11, 1): 'Quarterly Earnings ADP',
#   datetime.date(2012, 11, 2): 'AmerisourceBergen Pursues Competitor and 4 Stocks Hitting Highs',
#   datetime.date(2012, 11, 5): 'Dividend Changes to Know Fidelity',
#   datetime.date(2012, 11, 6): 'Indicated Dividend Yield Ranking for the 500 by Industry',
#   datetime.date(2012, 11, 8): '26 ways to profit from'},
#  'ABT': {datetime.date(2010, 11, 11): 'Abbott Laboratories Reaffirms FY 2010 EPS Call',
#   datetime.date(2010, 11, 20): 'Abbott Laboratories And Reata Announce Positive Phase 2b Study Results For Bardoxolone Methyl',
#   datetime.date(2010, 11, 22): 'Abbott Laboratories Announces Positive Results From Phase II Study Of Low Dose Atrasentan For Treatment Of Diabetic Kidney Disease',
#   datetime.date(2010, 12, 7): 'Abbott Laboratories And Squibb Announces Encouraging Phase 2 Interim Data For Elotuzumab In Relapsed Multiple Myeloma',
#   datetime.date(2010, 12, 10): 'Abbott Laboratories Declares Quarterly Dividend',
#   datetime.date(2010, 12, 14): 'Abbott Division Signs Agreement with STRATEC Biomedical Systems AG to Analyzer System Solution',
#   datetime.date(2010, 12, 20): 'EpiTherapeutics And Abbott Laboratories Enter Into Oncology Collaboration On Epigenetic Targets',
#   datetime.date(2010, 12, 22): 'AstraZeneca PLC And Abbott Laboratories End License Agreement For Development Of CERTRIAD',
#   datetime.date(2011, 1, 4): 'India Patent Office Rejects Abbott HIV Drug',
#   datetime.date(2011, 1, 10): 'Abbott Laboratories Receives CE Mark Approval For First Drug Eluting Bioresorbable Vascular Scaffold For Treatment Of Coronary Artery Disease',
#   datetime.date(2011, 1, 20): 'Abbott XIENCE PRIME Receives CE Mark For Treatment Of Most Advanced Form Of Arterial Disease',
#   datetime.date(2011, 1, 26): 'Abbott Laboratories Announces Restructuring In Its Pharmaceutical Issues FY 2011 EPS Guidance In Line With Estimates',
#   datetime.date(2011, 1, 31): 'Abbott Laboratories Receives Regulatory Clearance In United States',
#   datetime.date(2011, 2, 7): 'Abbott Laboratories Launches Biothreat Assay for System',
#   datetime.date(2011, 2, 18): 'Abbott Laboratories Announces Quarterly Dividend',
#   datetime.date(2011, 2, 24): u'Abbott Boston Scientific Corporations Boston Scientific Ceska Johnson Medtronic Czechia and Others Win Daily News',
#   datetime.date(2011, 3, 8): 'US Warns Against Abbott Laboratories HIV Drug In Premature',
#   datetime.date(2011, 3, 21): 'Abbott Laboratories Receives For New Qualitative Test',
#   datetime.date(2011, 3, 22): 'Seattle Genetics Announces Conjugate Collaboration With Abbott Laboratories',
#   datetime.date(2011, 3, 25): 'GlaxoSmithKline plc And Abbott Laboratories Case Handed To',
#   datetime.date(2011, 3, 30): 'Abbott Laboratories Announces Disease Trial To Explore Benefit Of New Therapeutic Monitoring Parameters For Patients',
#   datetime.date(2011, 4, 3): 'Abbott ABSORB Bioresorbable Vascular Scaffold Demonstrates Positive Safety and Efficacy Results',
#   datetime.date(2011, 4, 4): 'Data From Clinical Trial of Abbott MitraClip System Demonstrate Durable Clinical Benefits for Patients With Mitral Regurgitation Two Years After Treatment',
#   datetime.date(2011, 4, 20): 'Abbott Laboratories Reaffirms FY 2011 EPS Guidance',
#   datetime.date(2011, 4, 26): 'Lupin Announces Patent License Agreement With Abbott Laboratories',
#   datetime.date(2011, 5, 6): 'Abbott Laboratories Receives FDA Approval To Expand Use Of RX ACCULINK Carotid Stent System To Patients At Standard Surgical Risk',
#   datetime.date(2011, 5, 9): 'Abbott Laboratories Recalls MitraClip System Due To Faulty',
#   datetime.date(2011, 5, 10): 'Abbott HUMIRA Meets Primary Endpoints In Phase III Ulcerative Colitis Study',
#   datetime.date(2011, 5, 23): 'Abbott Laboratories Completes Submission Of New Molecular Test Intended For Lung Cancer Therapy Selection',
#   datetime.date(2011, 5, 24): 'Abbott Laboratories Receives FDA Approval for XIENCE nano',
#   datetime.date(2011, 5, 25): 'Court Rules For Abbott Diabetes Test',
#   datetime.date(2011, 6, 2): 'Abbott Laboratories In Talks To Settle US Probe Of Depakote',
#   datetime.date(2011, 6, 9): 'Abbott Laboratories Reports Interim Results From Phase III Study Of Investigational Treatment For Advanced Disease',
#   datetime.date(2011, 6, 10): 'Abbott Laboratories Declares Consecutive Quarterly Dividend',
#   datetime.date(2011, 6, 14): 'Abbott Laboratories Receives FDA Approval For CREON Dosage For Patients With Exocrine Pancreatic Insufficiency Due To Cystic Fibrosis',
#   datetime.date(2011, 6, 20): 'Abbott Laboratories Receives FDA Approval For New Formulation Of Lupron Depot For Palliative Treatment Of Advanced Prostate Cancer',
#   datetime.date(2011, 6, 21): 'Biotest AG and Abbott Announce Global Agreement to Develop and Commercialize Novel Antibody for Autoimmune Diseases',
#   datetime.date(2011, 6, 24): 'Kidney Improvement Sustained By Abbott Laboratories',
#   datetime.date(2011, 7, 20): 'Abbott Laboratories Raises FY 2011 EPS Guidance',
#   datetime.date(2011, 7, 29): 'Perdue Kidd Vickery Files Lawsuit Against Abbott Laboratories For Inadequate Leukemia And Cancer Warning',
#   datetime.date(2011, 8, 9): 'Biogen Idec Inc And Abbott Laboratories Announce Positive Results From First Registrational Trial For Daclizumab HYP In Multiple Sclerosis',
#   datetime.date(2011, 8, 10): 'Abbott Laboratories Receives FDA Approval For RX Herculink Elite Renal Stent System For Treatment of Renal Artery Disease',
#   datetime.date(2011, 8, 16): 'Abbott Laboratories Receives FDA Approval For Two Three Month Strengths Of Lupron For Treatment Of CPP',
#   datetime.date(2011, 8, 22): 'FDA Clears Abbott Genetic FISH Panel For Leukemia Patient Prognosis',
#   datetime.date(2011, 8, 26): 'Abbott Laboratories Receives FDA Approval For ALK Gene Test For Lung Cancer Therapy Selection',
#   datetime.date(2011, 8, 30): 'Abbott Laboratories Introduces New ALK Genetic Test For Specific Form Of Lung Cancer',
#   datetime.date(2011, 9, 8): 'Abbott Laboratories Initiates International ABSORB BTK Clinical Trial For Treatment Of Critical Limb Ischemia',
#   datetime.date(2011, 9, 13): 'Neurocrine Biosciences Inc Announces Start Of Phase II Study Of Elagolix in Uterine Fibroids By Abbott Laboratories',
#   datetime.date(2011, 9, 15): 'Abbott Laboratories Declares Quarterly Dividend',
#   datetime.date(2011, 10, 19): 'Abbott Laboratories To Separate Into Two Companies In Diversified Medical Products And Pharmaceuticals',
#   datetime.date(2011, 10, 20): 'plc Launches Assay on Abbot ARCHITECT Platform',
#   datetime.date(2011, 10, 22): 'Biogen Idec Inc And Abbott Laboratories Present Positive Data For Daclizumab HYP From Select Phase 2B Trial',
#   datetime.date(2011, 10, 24): 'Abbott Genetic Test for Acute Myeloid Leukemia Prognosis Cleared by FDA',
#   datetime.date(2011, 11, 1): 'Abbott Laboratories Receives FDA Approval For XIENCE PRIME Drug Eluting Stent',
#   datetime.date(2011, 11, 2): 'Experts Report That Abbott New Assay Offers Important Testing Capabilities For Biothreat Defense',
#   datetime.date(2011, 11, 6): 'Abbott Laboratories Announces New Data Evaluating Use Of HUMIRA For Patients With Moderate To Severe Rheumatoid Arthritis',
#   datetime.date(2011, 11, 7): 'Abbott Laboratories Presents HUMIRA Phase 3 Study Results For Patients With Active Axial Spondyloarthritis',
#   datetime.date(2011, 11, 9): 'Abbott Laboratories Receives CE Mark For New Hepatitis Test',
#   datetime.date(2011, 11, 21): 'Abbott Laboratories Receives FDA Approval For Supplemental Blood Test For Chagas Disease',
#   datetime.date(2011, 11, 30): 'Law Offices of Howard Smith Announces Investigation of Abbott Laboratories',
#   datetime.date(2011, 12, 5): 'Abbott Laboratories Dismisses Talk Of Pharma Unit',
#   datetime.date(2011, 12, 8): 'Abbott Laboratories Initiates Clinical Trial To Evaluate Absorb Bioresorbable Vascular Scaffold Compared To Metallic Drug Eluting Stent',
#   datetime.date(2011, 12, 9): 'Abbott Laboratories Declares Quarterly Dividend',
#   datetime.date(2011, 12, 12): 'Abbott Laboratories And Reata Pharmaceuticals Announces Agreement To Develop And Commercialize Antioxidant Inflammation Modulators',
#   datetime.date(2011, 12, 22): 'Abbott Laboratories Initiates Clinical Trial To Study Drug Eluting Bioresorbable Therapy For Treatment of Peripheral Artery Disease',
#   datetime.date(2011, 12, 28): 'Emergent BioSolutions Announces Plans For Program Following Termination Of Collaboration With Abbott Laboratories',
#   datetime.date(2012, 1, 18): 'Abbott STARLIMS LIMS Technology to be Installed in FDA Testing Laboratories',
#   datetime.date(2012, 1, 25): 'Abbott Laboratories Issues FY 2012 Guidance In Line With Call',
#   datetime.date(2012, 1, 30): 'DNDi And Abbott Laboratories Expand Partnership To Boost Innovation for Neglected Tropical Diseases',
#   datetime.date(2012, 2, 17): 'Abbott Laboratories Declares Quarterly Dividend',
#   datetime.date(2012, 2, 29): 'Abbott Laboratories And Galapagos NV Announce Global Collaboration For Oral In Phase II To Treat Autoimmune Diseases',
#   datetime.date(2012, 3, 2): 'Watson Pharmaceuticals Inc Launches Generic PROMETRIUM As Part Of Agreement With Abbott Laboratories',
#   datetime.date(2012, 3, 5): 'Abbott Laboratories To Collaborate With Genetics On Rapid Molecular Test To Identify Serious Infections In Bones And Joints',
#   datetime.date(2012, 3, 6): 'Abbott Laboratories And Merck Collaborate To Develop Companion Diagnostic Test For Investigational Cancer Therapy',
#   datetime.date(2012, 3, 7): 'Abbott Absolute Pro Vascular Stent System Receives FDA Approval For Treatment Of Iliac Artery Disease',
#   datetime.date(2012, 3, 12): 'New Publication Presents Comparative Efficacy Data for Abbott Zemplar in Treating Secondary Hyperparathyroidism in Hemodialysis Patients',
#   datetime.date(2012, 3, 30): 'Abbott Molecular System And Tests For Broad Microbial Identification Obtain CE Marking',
#   datetime.date(2012, 4, 9): 'Abbott Laboratories Receives Approval For XIENCE PRIME Drug Eluting Stent In Japan',
#   datetime.date(2012, 4, 11): 'Abbott Drug Humira Receives Approval In Europe For Ulcerative',
#   datetime.date(2012, 4, 17): 'Abbott Investigational Treatment For Advanced Disease Demonstrates Positive Results In Phase 3 Clinical Trial',
#   datetime.date(2012, 4, 18): 'Abbott Laboratories Raises FY 2012 EPS Guidance',
#   datetime.date(2012, 4, 19): 'Abbott Laboratories Presents Positive Results From Phase II Study For Treatment Of Hepatitis C',
#   datetime.date(2012, 4, 20): 'Abbott Laboratories Receives FDA Clearance To Use iFS Advanced Femtosecond Laser Technology For Arcuate Incisions In Cataract Surgery',
#   datetime.date(2012, 4, 23): 'Abbott Laboratories and Jude Medical Broaden Alliance For Cardiovascular Products In United States',
#   datetime.date(2012, 5, 3): 'Abbott Laboratories Announces Collaboration With Biocon Syngene To Open First Nutrition Center In India',
#   datetime.date(2012, 6, 5): 'Abbott Laboratories In Cooperation With Neurocrine Announces Initiation Of Phase 3 Study Of Elagolix In Patients With Endometriosis',
#   datetime.date(2012, 6, 6): 'Abbott Laboratories Announces Phase 3 Study Results for Investigational Use of HUMIRA in Patients with Active Axial Spondyloarthritis',
#   datetime.date(2012, 6, 8): 'Abbott Laboratories Declares Quarterly Dividend',
#   datetime.date(2012, 6, 18): 'Abbott Laboratories Announces Results Of Clinical Studies Evaluating Investigational Treatment For Advanced Disease',
#   datetime.date(2012, 6, 25): 'Abbott Laboratories Receives Positive Opinion for HUMIRA in Axial Spondyloarthritis from CHMP',
#   datetime.date(2012, 7, 3): 'Abbott Laboratories Receives FDA Approval For Healon EndoCoat Protective Gel For Cataract Surgery',
#   datetime.date(2012, 7, 18): 'Abbott Laboratories Confirms FY 2012 EPS Guidance',
#   datetime.date(2012, 7, 30): 'Abbott HUMIRA Approved In Europe For Treatment Of Axial Spondyloarthritis',
#   datetime.date(2012, 8, 7): 'Abbott Omnilink Elite Vascular Stent System Receives FDA Approval For Treatment Of Iliac Artery Disease',
#   datetime.date(2012, 8, 30): 'Abbott HUMIRA Secures Approval In Europe For Expanded Treatment Of Disease',
#   datetime.date(2012, 9, 6): 'Abbott Laboratories To Collaborate With Astellas In CMV Vaccine Trial',
#   datetime.date(2012, 9, 13): 'Abbott Laboratories Declares Quarterly Dividend',
#   datetime.date(2012, 10, 2): 'Judge Accepts Abbott Laboratories Misbranding',
#   datetime.date(2012, 10, 12): 'RBC Capital Gives Outperform Rating to Abbott Laboratories',
#   datetime.date(2012, 10, 15): 'Abbott Laboratories Oral Hepatitis C Regimen Cure Rate',
#   datetime.date(2012, 10, 17): 'Abbott Laboratories Narrows FY 2012 EPS Guidance',
#   datetime.date(2012, 10, 18): 'Abbott Laboratories Shares Scorched By Kidney Drug',
#   datetime.date(2012, 10, 19): 'Pipeline Setback at Abbott Analyst Blog',
#   datetime.date(2012, 10, 22): 'Abbott Laboratories Company Could Unlock Value For Shareholders',
#   datetime.date(2012, 10, 23): 'Seattle Genetics Inc Expands Conjugate Collaboration With Abbott Laboratories',
#   datetime.date(2012, 10, 24): 'Abbott Laboratories Announces Data Evaluating Reduction Of Steroid Usage With HUMIRA In Patients With Moderately To Severely Active Ulcerative Colitis',
#   datetime.date(2012, 10, 26): 'Abbott Labs Announces Cash Tender Offers For Notes',
#   datetime.date(2012, 10, 30): 'Abbott Laboratories Launches Ensure Complete Shakes For Adults',
#   datetime.date(2012, 10, 31): 'Abbott Laboratories Should Build A Foundation',
#   datetime.date(2012, 11, 5): 'Abbott Subsidiary Announces Pricing Of Billion Private Placement Notes Offering',
#   datetime.date(2012, 11, 6): 'Abbott Says AbbVie Prices Bln Private Placement Notes Offering',
#   datetime.date(2012, 11, 7): 'Unusual Trading Activity for Abbott Laboratories'},
#  'ACE': {datetime.date(2010, 11, 18): 'ACE Limited Announces Pricing Of Million Senior Note Offering By Subsidiary',
#   datetime.date(2010, 12, 1): 'ACE ACE Group Completes Acquisition Of Jerneh Insurance Berhad In Malaysia',
#   datetime.date(2010, 12, 28): 'ACE Limited Completes Acquisition of Rain and Hail Insurance',
#   datetime.date(2011, 2, 1): 'ACE Limited Completes Acquisition Of New York Operations In Korea',
#   datetime.date(2011, 2, 3): 'ACE Limited Issues FY 2011 Revenue In Line With Call',
#   datetime.date(2011, 2, 24): 'ACE Limited Declares First Quarter Dividend',
#   datetime.date(2011, 4, 1): u'ACE Limited Completes Acquisition Of New York Lifes Operations In Hong Kong',
#   datetime.date(2011, 5, 4): 'ACE Limited Lowers FY 2011 EPS Guidance',
#   datetime.date(2011, 6, 20): 'ACE Subsidiary To Acquire ACE Synergy Insurance Berhad',
#   datetime.date(2011, 7, 26): 'ACE Ltd Raises FY 2011 Earnings Guidance',
#   datetime.date(2011, 8, 11): 'ACE Ltd Declares Quarterly Announces Stock Repurchase Program',
#   datetime.date(2011, 9, 8): 'Penn Millers Holding Corp To Be Acquired By ACE Subsidiary',
#   datetime.date(2011, 9, 12): 'ACE Ltd Partners With IAM Drive Survive To Provide Superior Fleet Risk Management',
#   datetime.date(2011, 10, 25): 'ACE Ltd Raises FY 2011 EPS Guidance',
#   datetime.date(2011, 11, 17): 'ACE Ltd Recommends Increase In Dividend',
#   datetime.date(2011, 11, 30): 'Penn Millers Holding Corp Completes Sale To ACE Subsidiary',
#   datetime.date(2011, 12, 28): 'ACE Ltd Acquires General Insurer Rio Guayas In Ecuador',
#   datetime.date(2012, 1, 31): 'ACE Ltd Issues FY 2012 EPS Guidance Below Estimates',
#   datetime.date(2012, 2, 1): 'ACE Ltd Reaffirms FY 2012 EPS Call',
#   datetime.date(2012, 4, 25): 'ACE Ltd Raises FY 2012 EPS Call',
#   datetime.date(2012, 6, 13): 'ACE Limited To Acquire PT Asuransi Jaya Proteksi',
#   datetime.date(2012, 7, 6): 'ACE Limited Partners with RAC To Offer Travel Insurance',
#   datetime.date(2012, 7, 24): 'ACE Limited Raises FY 2012 EPS Guidance',
#   datetime.date(2012, 8, 9): 'ACE Limited Declares Quarterly Dividend',
#   datetime.date(2012, 9, 18): 'ACE Limited Acquires of Asuransi Jaya Proteksi in Indonesia',
#   datetime.date(2012, 10, 18): 'ACE to Acquire Mexican Personal Lines Insurer ABA Seguros',
#   datetime.date(2012, 10, 23): 'ACE Limited Raises FY 2012 EPS Guidance',
#   datetime.date(2012, 10, 24): 'ACE Beats EPS Ups View Analyst Blog',
#   datetime.date(2012, 11, 6): 'ACE LIMITED ACE Says Future Success of London Insurance Market Depends',
#   datetime.date(2012, 11, 7): 'Pacers ace Granger out for three months',
#   datetime.date(2012, 11, 8): 'Ace of Spades Launching Next Month'},
#  'ACN': {datetime.date(2010, 11, 10): 'Accenture Plc Completes Acquisition Of Mogenesis',
#   datetime.date(2010, 11, 16): 'Accenture Plc And BMC Software Expand Relationship With Technology Joint Development And Delivery Agreements',
#   datetime.date(2010, 11, 18): 'KF Awards Accenture Plc Finance And Accounting Business Process Outsourcing Contract',
#   datetime.date(2010, 11, 19): 'Accenture Plc Agrees To Acquire CAS Computer Systemberatung AG',
#   datetime.date(2010, 11, 30): 'Accenture Plc To Open Analytics Innovation Centre In Ireland',
#   datetime.date(2010, 12, 2): 'Accenture Plc And NHN Corporation Sign Agreement To Collaborate To Develop Mobile Applications For Smartphones',
#   datetime.date(2010, 12, 6): 'Accenture Plc Secures Contract From IT Services',
#   datetime.date(2010, 12, 7): 'Accenture Plc Broadens Digital Relationship With Universal Music Group',
#   datetime.date(2010, 12, 8): 'National Water Company Of Saudi Arabia Selects Accenture Plc For Comprehensive IT Solution',
#   datetime.date(2010, 12, 14): 'Accenture Plc Announces Multi Year Technology Services Agreement With Hilton Worldwide',
#   datetime.date(2010, 12, 16): 'Accenture Plc Issues Q2 2011 Revenue Guidance In Line With Raises FY 2011 Guidance',
#   datetime.date(2010, 12, 20): 'Accenture Plc Wins Portal Implementation Contract From State Government of Nagaland',
#   datetime.date(2010, 12, 21): 'Accenture Plc Supports Global Business Transformation Program at Fast Retailing',
#   datetime.date(2011, 1, 10): 'Accenture Plc Completes Acquisition of CAS Computer und Systemberatung AG',
#   datetime.date(2011, 1, 18): 'ONC Selects Accenture Plc To Help Achieve Healthcare IT Interoperability',
#   datetime.date(2011, 1, 19): 'Carlsberg Engages Application Services Contract With Accenture Plc',
#   datetime.date(2011, 2, 14): 'Accenture Plc And NetApp Expand Relationship With Agreements On Technology And Joint Development And Delivery Of New Enterprise Solutions',
#   datetime.date(2011, 2, 28): 'Accenture Plc Receives Consip SpA Contract to Develop eProcurement System to Transform Italian Government Procurement',
#   datetime.date(2011, 3, 2): 'Accenture Plc Secures Procurement Transformation Contract From City Of London Corporation',
#   datetime.date(2011, 3, 15): 'Israel Electric Corporation Awards Accenture Plc IT Services Contract',
#   datetime.date(2011, 3, 24): 'Accenture Plc Issues Q3 2011 Revenue Guidance Above Raises FY 2011 Declares Semi Annual Cash Dividend',
#   datetime.date(2011, 3, 28): 'Ministry of Justice Awards Systems Integration Contract To Accenture Plc',
#   datetime.date(2011, 3, 29): 'Accenture Plc Secures Five Year Outsourcing And Management Consulting Contract From CEVA LOGISTICS',
#   datetime.date(2011, 3, 30): 'Banco Bilbao Vizcaya Selects Accenture Alnova Banking Solution To Support Aggressive Technology Transformation',
#   datetime.date(2011, 4, 6): 'Accenture Plc And RSA UK Extend Business Process Outsourcing Agreement For Insurance Services',
#   datetime.date(2011, 4, 19): 'InBev And Accenture Plc Collaborate On Digital Merchandising Pilot',
#   datetime.date(2011, 4, 27): 'Nokia Oyj Announces Plans for Strategic Collaboration to Transfer Symbian Software Activities and About Employees to Accenture',
#   datetime.date(2011, 4, 28): 'Accenture Plc Teams With Harold Freeman Patient Navigation Institute',
#   datetime.date(2011, 5, 12): 'Navy Mutual Aid Association Selects Accenture Plc To Support Life Insurance And Annuity Business',
#   datetime.date(2011, 5, 17): 'Accenture Plc And SAP AG Announces Strategic Relationship',
#   datetime.date(2011, 6, 7): 'Accenture Plc To Acquire Majority Stake In Al Faisaliah Business Technology Company',
#   datetime.date(2011, 6, 14): 'CF Industries Selects Accenture Plc To Implement Information System',
#   datetime.date(2011, 6, 20): 'Accenture Plc Implements Nationwide Electronic Health Record System In Singapore',
#   datetime.date(2011, 6, 22): 'Accenture Plc Finalize Symbian Software Development And Support Services Outsourcing Agreement With Nokia',
#   datetime.date(2011, 6, 23): 'Accenture Plc Issues Q4 2011 Revenue Guidance Above Raises FY 2011 Guidance',
#   datetime.date(2011, 6, 29): 'Accenture Plc Receives Contract From Air Force Electronic Systems Center',
#   datetime.date(2011, 7, 18): 'Accenture Plc to Deliver Automated Border Control Systems at Schiphol Airport in Amsterdam',
#   datetime.date(2011, 7, 22): 'Accenture Plc Secures Contract',
#   datetime.date(2011, 7, 27): 'Accenture Plc To Partner With Pepco Holdings Inc To Build Communications Network Management System',
#   datetime.date(2011, 8, 1): 'Accenture Plc To Deliver Information Technology And Finance And Accounting Services To Intertek Under Outsourcing Contract',
#   datetime.date(2011, 8, 3): u'LOreal Selects Accenture Plc To Support Field Sales Operations',
# ...
#   datetime.date(2012, 10, 9): 'Xylem to release 2012 results on November 2012',
#   datetime.date(2012, 10, 10): 'DDR Larger Than 500 Component Xylem',
#   datetime.date(2012, 10, 12): 'Brean Murray Carret Starts Xylem at Buy',
#   datetime.date(2012, 10, 15): 'Daily Dividend XYL',
#   datetime.date(2012, 10, 16): u'7 Stocks approaching their date on 2012 WPO',
#   datetime.date(2012, 10, 18): 'Market GOOG RRD AMD COF AAPL CMG SVU M T DB POT SYK C MGM',
#   datetime.date(2012, 10, 22): 'Xylem Downgraded to at Ladenburg Thalmann',
#   datetime.date(2012, 10, 26): 'Xylem Purchases Heartland to Expand in US Dewatering Business',
#   datetime.date(2012, 10, 30): 'These 22 Stocks Benefit Most From The Sandy Monster Storm Of The Millenium',
#   datetime.date(2012, 10, 31): 'How to play 20 hurricane stocks',
#   datetime.date(2012, 11, 1): 'Xylem Q3 Profit Revises 2012 EPS View Quick Facts',
#   datetime.date(2012, 11, 2): 'Draining NY Tunnels Flooded by Sandy to Take Many Days',
#   datetime.date(2012, 11, 6): 'Indicated Dividend Yield Ranking for the 500 by Industry',
#   datetime.date(2012, 11, 8): 'Sewage Backups Mean Trillion Bill for Leaking US Pipes'},
#  'YHOO': {datetime.date(2010, 11, 15): 'Launches Contributor Network',
#   datetime.date(2010, 11, 16): 'Launches Comprehensive Local Offers Program',
#   datetime.date(2010, 12, 14): 'Prepares To Cut Up To Of Work',
#   datetime.date(2010, 12, 29): 'Microsoft Relaunches Tech Patent Suit Against Apple Google And',
#   datetime.date(2011, 1, 25): 'Cuts Of Staff Ahead Of',
#   datetime.date(2011, 1, 27): 'Agrees Online Media Partnership With The League Managers Association',
#   datetime.date(2011, 2, 2): 'Signs Agreement To Continue Delivery Of Search Results And Advertising Listings',
#   datetime.date(2011, 2, 3): 'And Real Estate Launch Real Estate Network',
#   datetime.date(2011, 2, 7): 'Announces It Is Launching Safely Worldwide',
#   datetime.date(2011, 2, 10): 'Monster And Ink Multicountry Alliance In Latin America',
#   datetime.date(2011, 2, 18): 'to Launch Portal in March Europe',
#   datetime.date(2011, 3, 2): 'In Talks On Billion Japan',
#   datetime.date(2011, 3, 23): 'Launches Search Direct',
#   datetime.date(2011, 4, 19): 'Issues Q2 2011 Guidance In Line With Estimates',
#   datetime.date(2011, 4, 25): 'Announces Acquisition Of IntoNow',
#   datetime.date(2011, 5, 5): 'Dot VN Inc Signs Search Reseller Program Agreement With Emerging Markets',
#   datetime.date(2011, 6, 1): 'MediaTek Incorporated Signs Cooperative Agreement with Yahoo',
#   datetime.date(2011, 6, 7): 'Robbins Geller Rudman Dowd LLP Files Class Action Suit Against',
#   datetime.date(2011, 6, 9): 'Robbins Umeda LLP Announces Investigation Of',
#   datetime.date(2011, 6, 13): 'Harwood Feffer LLP Announces Investigation of',
#   datetime.date(2011, 6, 21): 'Faruqi LLP Announces Investigation Of',
#   datetime.date(2011, 6, 22): 'Approached Hulu On Possible',
#   datetime.date(2011, 6, 27): 'Cohen Milstein Sellers Toll PLLC Announces Investigation Of',
#   datetime.date(2011, 6, 29): 'and Frontier Communications Corporation Extend Strategic Partnership',
#   datetime.date(2011, 6, 30): 'Goldfarb Branham Law Firm LLP Announces Class Action Lawsuits Against',
#   datetime.date(2011, 7, 1): 'Hulu Starts Sales Among Potential',
#   datetime.date(2011, 7, 19): 'Issues Q3 2011 Guidance Below Estimates',
#   datetime.date(2011, 8, 24): 'Walt News Corporation And JV Hulu Seen Drawing Bids From',
#   datetime.date(2011, 8, 26): 'SOFTBANK to Transfer Shares of to as Repayment for Debts',
#   datetime.date(2011, 8, 31): 'Gannett And To Expand Local Advertising Partnership To 19 Broadcasting Markets',
#   datetime.date(2011, 9, 7): 'Announces Leadership Reorganization',
#   datetime.date(2011, 9, 16): 'Silver Lake Looking To Buy',
#   datetime.date(2011, 9, 27): 'Augme Provides Intellectual Property Litigation Against AOL Inc And Update',
#   datetime.date(2011, 10, 18): 'Issues Q4 2011 Mixed Guidance',
#   datetime.date(2011, 10, 23): 'Google PE Firms Mull Bid For',
#   datetime.date(2011, 11, 1): 'To Acquire interCLICK Inc',
#   datetime.date(2011, 11, 8): 'Microsoft AOL Strike Ad',
#   datetime.date(2011, 11, 15): 'Begins Cash Tender Offer To Acquire interCLICK Inc',
#   datetime.date(2011, 11, 23): 'Singapore Press Holdings Limited Sues Over',
#   datetime.date(2011, 11, 29): 'Not Chasing Still Gets Top',
#   datetime.date(2011, 12, 1): 'Blackstone Group Bain Eye Billion',
#   datetime.date(2011, 12, 14): 'Completes interCLICK Inc Tender Offer',
#   datetime.date(2012, 1, 24): 'Issues Q1 2012 EBIT Guidance Below Estimates',
#   datetime.date(2012, 2, 3): 'AOL Selects Right Media Exchange As Display Advertising Platform For Ad Agreement',
#   datetime.date(2012, 2, 14): 'India probes Google For Possible Forex',
#   datetime.date(2012, 2, 21): 'Seeks To Avoid Indian Lawsuit Over',
#   datetime.date(2012, 3, 5): 'Preparing Could Affect',
#   datetime.date(2012, 3, 12): 'Files Patent Lawsuit Against Facebook News',
#   datetime.date(2012, 4, 3): 'And Renew Advertising Deal',
#   datetime.date(2012, 4, 4): 'Confirms Taking Important Steps To Reshape The Company For Expects To Recognize Majority Of Estimated Million Pretax Cash Charge In Q2 2012',
#   datetime.date(2012, 4, 17): 'Issues Q2 2012 Guidance In Line With Estimates',
#   datetime.date(2012, 4, 24): 'Yahoo Japan End Talks On Share',
#   datetime.date(2012, 5, 5): 'In Talks To Sell Of',
#   datetime.date(2012, 5, 13): 'Names Fred Amoroso As Appoints Ross Levinsohn Interim Announces Settlement With Third Point LLC',
#   datetime.date(2012, 5, 21): 'And Alibaba Group Holding Limited Reach Agreement On Comprehensive Plan For Alibaba Board Increases Share Repurchase Plan By Billion',
#   datetime.date(2012, 6, 13): 'and CNBC Announce Strategic Programming and Distribution Alliance',
#   datetime.date(2012, 6, 20): 'And Facebook Inc Seek More Time For Settlement',
#   datetime.date(2012, 6, 28): 'and Clear Channel Enter Content Distribution and Promotion Agreement',
#   datetime.date(2012, 7, 5): 'CEO Search Down To',
#   datetime.date(2012, 7, 6): 'And Facebook Inc Launch Strategic Resolve Patent Dispute',
#   datetime.date(2012, 7, 16): 'Appoints Marissa Mayer As Chief Executive Officer',
#   datetime.date(2012, 8, 16): 'Augme Technologies Inc Provides Patent Litigation Against Yahoo AOL Millennial Media And Velti',
#   datetime.date(2012, 9, 18): 'Alibaba Buys Back Half Of',
#   datetime.date(2012, 9, 25): 'Inc Names Ken Goldman As CFO',
#   datetime.date(2012, 10, 15): 'Henrique De incoming chief operating officer for Inc',
#   datetime.date(2012, 10, 17): 'An Early Look At Earnings',
#   datetime.date(2012, 10, 19): 'Inc To Exit South Korea In First Asian',
#   datetime.date(2012, 10, 22): 'US HOT Active in Late Trading',
#   datetime.date(2012, 10, 23): 'and CBS Television Distribution Team Up to Bring Insider To TV',
#   datetime.date(2012, 10, 24): 'Citi board fight signals rise of the activist chairman',
#   datetime.date(2012, 10, 25): 'Inc Buys Mobile Company In New',
#   datetime.date(2012, 10, 26): 'Yahoo could be creating mobile apps with the latest',
#   datetime.date(2012, 10, 31): '6 Possible takeover targets for',
#   datetime.date(2012, 11, 2): 'The Zacks Analyst Blog Walt Microsoft and',
#   datetime.date(2012, 11, 5): 'Inc And Samsung Form Multi Year Partnership To Deliver Interactive TV',
#   datetime.date(2012, 11, 6): 'AOL Climbs After Posting Profit on Higher Advertising Sales',
#   datetime.date(2012, 11, 7): 'Samsung enter TV market'},
#  'YUM': {datetime.date(2010, 11, 19): 'Declares Quarterly Dividend Of Per Share',
#   datetime.date(2010, 12, 3): 'Reaffirms FY 2010 EPS Comments On FY 2011 EPS Guidance',
#   datetime.date(2011, 1, 27): 'Announces Additional Million Authorization',
#   datetime.date(2011, 1, 28): 'Brands Taco Bells Unveils Seasoned Beef Recipe As Legal Fight',
#   datetime.date(2011, 3, 25): 'Declares Quarterly Dividend of Per Share',
#   datetime.date(2011, 4, 19): 'Beasley Allen Law Firm Voluntarily Withdraws Class Action Lawsuit Against Taco Bell',
#   datetime.date(2011, 4, 21): 'Reaffirms FY 2011 EPS Call',
#   datetime.date(2011, 4, 26): u'Makes Preliminary Proposal To Acquire Chinas Little Sheep Restaurants',
#   datetime.date(2011, 5, 12): 'Announces Proposed Privatization of Little Sheep Group Limited at per Scheme Share',
#   datetime.date(2011, 5, 19): 'Declares Quarterly Dividend Of Per Share',
#   datetime.date(2011, 7, 13): 'Brands Inc Raises FY 2011 EPS Guidance',
#   datetime.date(2011, 9, 22): 'Brands Inc Announces Definitive Agreements To Sell Long John And Restaurants',
#   datetime.date(2011, 11, 8): u'Chinas Ministry of Commerce Approves Brands Proposal To Acquire Little Sheep Group Limited',
#   datetime.date(2011, 11, 18): 'Brands Inc Announces Additional Million Authorization And Declares Quarterly Dividend Of Per Share',
#   datetime.date(2011, 11, 22): 'Brands Inc To Separates India Chronicle',
#   datetime.date(2011, 12, 5): 'Brands Inc Raises FY 2011 EPS Comments On FY 2012 EPS Guidance',
#   datetime.date(2012, 2, 4): 'Brands Keller Rohrback Announces Investigation Of Salmonella Outbreak Linked To Taco Bell Chain',
#   datetime.date(2012, 2, 7): 'Brands Inc Reaffirms FY 2012 EPS Comments On Long Term EPS Call',
#   datetime.date(2012, 3, 23): 'Brands Inc Declares Quarterly Dividend',
#   datetime.date(2012, 5, 1): 'Brands Inc Promotes Carucci President And Grismer Chief Financial Officer',
#   datetime.date(2012, 5, 17): 'Brands Inc Declares Quarterly Dividend',
#   datetime.date(2012, 7, 18): 'Brands Inc Reaffirms FY 2012 EPS Guidance',
#   datetime.date(2012, 9, 20): 'Brands Inc Announces Increase in Quarterly Dividend',
#   datetime.date(2012, 10, 9): 'Brands Inc Raises FY 2012 EPS Guidance',
#   datetime.date(2012, 10, 10): 'biggest gaining and declining stocks',
#   datetime.date(2012, 10, 16): 'Taking a Bite Out of Brands Stock',
#   datetime.date(2012, 10, 19): 'Yum Brands stock slips on lackluster earnings reports',
#   datetime.date(2012, 10, 22): 'Brands executive to speak on reputation global PR strategy',
#   datetime.date(2012, 10, 23): 'World Series Stolen Base Could Earn America Free',
#   datetime.date(2012, 10, 29): 'Yum Strong Chinese Growth',
#   datetime.date(2012, 10, 30): u'Free Doritos Locos Tacos for America Today',
#   datetime.date(2012, 10, 31): 'Brands and What the Yankees and China Have in Common',
#   datetime.date(2012, 11, 1): 'David Yum Brands Chipotle',
#   datetime.date(2012, 11, 5): 'Yum Looks Tasty In The Near Future',
#   datetime.date(2012, 11, 7): 'Franchisee acquires 120 KFCs from Brands',
#   datetime.date(2012, 11, 8): 'New sweet snacks offered at Taco Bell'},
#  'ZION': {datetime.date(2011, 2, 8): 'Zions Bancorporation Declares Dividends For Common And Preferred Shares',
#   datetime.date(2011, 2, 10): 'Zions Bancorporation Announces Entry Into New Equity Distribution Agreements',
#   datetime.date(2011, 5, 12): 'Zions Bancorporation Declares Dividends For Common And Preferred Shares',
#   datetime.date(2011, 8, 10): 'Zions Bancorporation Declares Dividends For Common And Preferred Shares',
#   datetime.date(2011, 11, 9): 'Zions Bancorporation Declares Dividends for Common and Preferred Shares',
#   datetime.date(2012, 2, 8): 'Zions Bancorporation Declares Dividends For Common And Preferred Shares',
#   datetime.date(2012, 3, 22): 'Zions Bancorporation Announces Completion Of Million Senior Note Auction',
#   datetime.date(2012, 4, 26): 'Zions Bancorporation Announces Completion Of Million Senior Notes Auction',
#   datetime.date(2012, 5, 1): 'Zions Bancorporation Announces Completion Of Million Perpetual Preferred Stock Auction',
#   datetime.date(2012, 5, 7): 'Zions Bancorporation Declares Dividends For Common And Preferred Shares',
#   datetime.date(2012, 6, 11): 'Zions Bancorporation Announces Plans To Auction million Of Senior Notes Through Zions Direct',
#   datetime.date(2012, 6, 14): 'Zions Bancorporation Announces Pricing Of Senior Notes',
#   datetime.date(2012, 8, 9): 'Zions Bancorporation Declares Dividends For Common And Preferred Shares',
#   datetime.date(2012, 10, 11): 'Zions Bancorporation Research Recent Ratings Updates',
#   datetime.date(2012, 10, 12): u'For five Financial RSI now represents an Overbought Condition',
#   datetime.date(2012, 10, 17): 'Zions Bancorp Third Quarter Earnings Sneak Peek',
#   datetime.date(2012, 10, 19): 'Stocks In News',
#   datetime.date(2012, 10, 22): 'advisories and surprises',
#   datetime.date(2012, 10, 30): 'AltaPacific Strong Capital Long History of Profitability',
#   datetime.date(2012, 11, 3): 'RBC Capital Reiterates Outperform on Zions Bancorporation',
#   datetime.date(2012, 11, 5): 'Snatch This Bargain Even Cheaper Than Exec Vice President Feiger Did',
#   datetime.date(2012, 11, 6): 'Indicated Dividend Yield Ranking for the 500 by Industry',
#   datetime.date(2012, 11, 7): 'Best Rally in Decade May Slow as Obama Faces Congress',
#   datetime.date(2012, 11, 8): 'Stocks In Focus'},
#  'ZMH': {datetime.date(2010, 12, 21): 'Zimmer Finalizes Acquisition Of Beijing Montagne Medical Device',
#   datetime.date(2010, 12, 22): 'Zimmer Announces Acquisition Of SoPlus Orthopaedic Surgical Power Tools Company',
#   datetime.date(2011, 1, 27): 'Zimmer Issues FY 2011 Guidance In Line With Estimates',
#   datetime.date(2011, 2, 17): 'Zimmer Launches PathFinder NXT Minimally Invasive Pedicle Screw System',
#   datetime.date(2011, 2, 18): 'Zimmer Announces Clinical Success Of Zimmer MotionLoc Screw Implantation',
#   datetime.date(2011, 4, 28): 'Zimmer Reaffirms FY 2011 Guidance',
#   datetime.date(2011, 5, 11): 'Zimmer Announces Lawsuit Filed by Genzyme Corporation',
#   datetime.date(2011, 7, 27): 'Zimmer Lowers FY 2011 Revenue Raises Low End Of Prior FY 2011 EPS Guidance To A Range In Line With Estimates',
#   datetime.date(2011, 9, 14): 'Zimmer Receives Pediatric Clearance For Universal Clamp Spinal Fixation System',
#   datetime.date(2011, 10, 20): 'Zimmer And Benvenue Inc Announces Distribution Agreement For Kiva VCF Treatment System',
#   datetime.date(2011, 10, 27): 'Zimmer Lowers FY 2011 Revenue Raises High End Of Prior FY 2011 EPS Guidance To A Range In Line Estimates',
#   datetime.date(2011, 11, 7): 'Zimmer Announces Offering of Senior Notes',
#   datetime.date(2011, 11, 10): 'Zimmer Announces Acquisition of XtraFix External Fixation System',
#   datetime.date(2011, 12, 1): 'Zimmer to Establish Research and Development Center',
#   datetime.date(2011, 12, 19): 'Zimmer Initiates Quarterly Dividend And Announces New Share Repurchase Program',
#   datetime.date(2012, 1, 12): 'Zimmer Announces Acquisition Of Synvasive',
#   datetime.date(2012, 1, 26): 'Zimmer Comments On FY 2012 Revenue Issues FY 2012 EPS Guidance In Line With Estimates',
#   datetime.date(2012, 4, 26): 'Zimmer Reaffirms FY 2012 Guidance',
#   datetime.date(2012, 6, 15): 'Zimmer Announces Quarterly Dividend For Second Quarter Of 2012',
#   datetime.date(2012, 7, 26): 'Zimmer Updates FY 2012 Revenue Narrows FY 2012 EPS Guidance To A Range In Line With Estimates',
#   datetime.date(2012, 9, 14): 'Zimmer Holdings Inc Announces Quarterly Dividend for Third Quarter of 2012',
#   datetime.date(2012, 10, 10): 'Hot Stocks',
#   datetime.date(2012, 10, 12): 'Zimmer Holdings Announces Live Audio Webcast and Conference Call of Third',
#   datetime.date(2012, 10, 15): 'See How Zimmer Holdings Ranks Among Top Picks With Strong',
#   datetime.date(2012, 10, 16): 'The Zacks Analyst Blog Stryker and',
#   datetime.date(2012, 10, 21): 'What Sectors To Buy or Sell If Mitt Romney Wins The Election C',
#   datetime.date(2012, 10, 22): 'Zimmer Holdings Third Quarter Earnings Sneak Peek',
#   datetime.date(2012, 10, 25): 'Zimmer Holdings Inc Lowers FY 2012 Revenue Narrows FY 2012 EPS Guidance To A Range In Line With Estimates',
#   datetime.date(2012, 10, 31): 'Zimmer Holdings to Present at Credit Suisse 2012 Healthcare Conference',
#   datetime.date(2012, 11, 1): 'RBC Capital Reaffirms Sector Perform Rating on Zimmer Holdings',
#   datetime.date(2012, 11, 6): 'WMGI Turns to Loss in Down Analyst Blog',
#   datetime.date(2012, 11, 7): '5 Dividend Stocks Investors Mostly Dislike',
#   datetime.date(2012, 11, 8): '26 ways to profit from'}}

# %%
print sp500

# %%
print sp500

# %%
import random
import nltk as nltk
#nltk.download()
from nltk.corpus import stopwords
import os, os.path
path = os.path.expanduser('~/nltk_data')
if not os.path.exists(path):
    os.mkdir(path)
os.path.exists(path)
import nltk.data
path in nltk.data.path
from nltk.corpus.reader import CategorizedPlaintextCorpusReader
reader = CategorizedPlaintextCorpusReader('.', r'.*_news_.*\.csv', cat_pattern=r'.*_news_(\w+)\.csv')
reader.categories()
reader.fileids(categories=['UP'])
def bag_of_words(words):
    return dict([(word, True) for word in words if word[0].isalpha()])
import collections
def bag_of_words_not_in_set(words, badwords):
    return bag_of_words(set(words)-set(badwords))

def bag_of_non_stopwords(words, stopfile='english'):
    badwords = stopwords.words(stopfile)
    return bag_of_words_not_in_set(words, badwords)

from nltk.metrics import BigramAssocMeasures
from nltk.collocations import BigramCollocationFinder

def bag_of_bigrams_words(words, score_fn=BigramAssocMeasures.chi_sq, n=2000):
    bigram_finder = BigramCollocationFinder.from_words(words)
    bigrams = bigram_finder.nbest(score_fn, n)
    dictOfBigrams = bag_of_words(bigrams)
    dictOfBigrams.update(bag_of_non_stopwords(words))
    return dictOfBigrams
    
def label_feats_from_corpus(corp, feature_detector=bag_of_words):
    label_feats = collections.defaultdict(list)
    for label in corp.categories():
        for fileid in corp.fileids(categories=[label]):
            feats = feature_detector(corp.words(fileids=[fileid]))
            label_feats[label].append(feats)
    return label_feats

def split_label_feats(lfeats, split=0.80):
    train_feats = []
    test_feats = []
    for label, feats in lfeats.iteritems():
        random.shuffle(feats, random.random)
        cutoff = int(len(feats) * split)
        train_feats.extend([(feat, label) for feat in feats[:cutoff]])
        test_feats.extend([(feat, label) for feat in feats[cutoff:]])
    return train_feats, test_feats




reader.categories()

lfeats = label_feats_from_corpus(reader)
lfeats.keys()
train_feats, test_feats = split_label_feats(lfeats)
len(train_feats)
len(test_feats)

from nltk.classify import NaiveBayesClassifier
nb_classifier = NaiveBayesClassifier.train(train_feats)
nb_classifier.labels()

from nltk.classify.util import accuracy
accuracy(nb_classifier, test_feats)
# Out:
# 0.4101694915254237

# %%
import pandas as pd

# %%
pd.set_printoptions(max_rows=2000)
from datetime import datetime
from datetime import date
from zipline.utils.factory import load_from_yahoo
mystart = date(2010, 1, 1)
myend = date(2012, 10, 1)
vixFrame = load_from_yahoo(stocks=['^VIX'], start=mystart, end=myend)
print vixFrame
# Out:
# ^VIX
# SPX
#                                SPX   ^VIX
# Date
# 2010-01-04 00:00:00+00:00  1132.99  20.04
# 2010-01-05 00:00:00+00:00  1136.52  19.35
# 2010-01-06 00:00:00+00:00  1137.14  19.16
# 2010-01-07 00:00:00+00:00  1141.69  19.06
# 2010-01-08 00:00:00+00:00  1144.98  18.13
# 2010-01-11 00:00:00+00:00  1146.98  17.55
# 2010-01-12 00:00:00+00:00  1136.22  18.25
# 2010-01-13 00:00:00+00:00  1145.68  17.85
# 2010-01-14 00:00:00+00:00  1148.46  17.63
# 2010-01-15 00:00:00+00:00  1136.03  17.91
# 2012-08-22 00:00:00+00:00  1413.49  15.11
# 2012-08-23 00:00:00+00:00  1402.08  15.96
# 2012-08-24 00:00:00+00:00  1411.13  15.18
# 2012-08-27 00:00:00+00:00  1410.44  16.35
# 2012-08-28 00:00:00+00:00  1409.30  16.49
# 2012-08-29 00:00:00+00:00  1410.49  17.06
# 2012-08-30 00:00:00+00:00  1399.48  17.83
# 2012-08-31 00:00:00+00:00  1406.58  17.47
# 2012-09-04 00:00:00+00:00  1404.94  17.98
# 2012-09-05 00:00:00+00:00  1403.44  17.74
# 2012-09-06 00:00:00+00:00  1432.12  15.63
# 2012-09-07 00:00:00+00:00  1437.92  14.38
# 2012-09-10 00:00:00+00:00  1429.08  16.28
# 2012-09-11 00:00:00+00:00  1433.56  16.41
# 2012-09-12 00:00:00+00:00  1436.56  15.80
# 2012-09-13 00:00:00+00:00  1459.99  14.05
# 2012-09-14 00:00:00+00:00  1465.77  14.51
# 2012-09-17 00:00:00+00:00  1461.19  14.59
# 2012-09-18 00:00:00+00:00  1459.32  14.18
# 2012-09-19 00:00:00+00:00  1461.05  13.88
# 2012-09-20 00:00:00+00:00  1460.26  14.07
# 2012-09-21 00:00:00+00:00  1460.15  13.98
# 2012-09-24 00:00:00+00:00  1456.89  14.15
# 2012-09-25 00:00:00+00:00  1441.59  15.43
# 2012-09-26 00:00:00+00:00  1433.32  16.81
# 2012-09-27 00:00:00+00:00  1447.15  14.84
# 2012-09-28 00:00:00+00:00  1440.67  15.73
# 2012-10-01 00:00:00+00:00  1444.49  16.32

# %%
sp500.UP.ix[datetime(2011, 10, 4)]
# Out:
# 4

# %%
def only_alphanum(s):
    #s = unicode(s, "utf-8")
    return ' '.join(c for c in s.split() if c.isalnum())
def only_alpha(s):
    return ' '.join(c for c in s.split() if c.isalpha())
def removeNonAscii(s): return "".join(i for i in s if ord(i)<128)


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#import zipline as zp
from zipline.algorithm import TradingAlgorithm
from zipline.transforms import MovingAverage, batch_transform
from zipline.utils.factory import load_from_yahoo


class NLPFinanceNews(TradingAlgorithm):
    def initialize(self, classifier, ticker, sp500):
        self.invested = False
        self.buy_orders = []
        self.sell_orders = []
        self.classifier = classifier
       # self.news = news
        self.ticker = ticker
        self.sp500 = sp500
    def bag_of_words(self, words):
        return dict([(word, True) for word in words if word[0].isalpha()])
    def getSignal(self, today):
        count =0
        up = 0
        down = 0
        none = 0
        # iterate thru sp500 and classify today's news, if up->up++, etc.
        
        for ticker in self.sp500:

            count += 1
            from lxml import etree
            import datetime
            from dateutil.parser import parse
            
            todaysNews = sp500News[ticker][today]
            newsClass = self.classifier.classify(bag_of_words(todaysNews))
            #print str(count) + ":"+str(today)+":"+ ticker + ":" + todaysNews + " : " + newsClass
            if not todaysNews == '0':
                if newsClass == 'NONE':
                    none += 1
                elif newsClass == 'UP':
                    up += 1
                elif newsClass == 'DOWN':
                    down += 1
        print "up: " + str(up) + " down: " + str(down) + " none: " + str(none)
        if down+none > 0:
            if up/(down+none) > 1:
                print 'BUY'
                return 'BUY'
        if none+up > 0:
            if down/(none+up) > 1:
                print 'SELL'
                return 'SELL'
        return None
    
    def handle_data(self, data):
        #up = sp500.UP.ix[date(data[self.ticker].datetime.year, data[self.ticker].datetime.month, data[self.ticker].datetime.day)]
        #down = sp500.DOWN.ix[date(data[self.ticker].datetime.year, data[self.ticker].datetime.month, data[self.ticker].datetime.day)]
        #none = sp500.NONE.ix[date(data[self.ticker].datetime.year, data[self.ticker].datetime.month, data[self.ticker].datetime.day)]
        #print  self.news.get(datetime.date(data[self.ticker].datetime.year, data[self.ticker].datetime.month, data[self.ticker].datetime.day), 'None') + " Classify: " + self.classifier.classify(self.bag_of_words(self.news.get(datetime.date(data[self.ticker].datetime.year, data[self.ticker].datetime.month, data[self.ticker].datetime.day), 'None')))
        today = date(data[self.ticker].datetime.year, data[self.ticker].datetime.month, data[self.ticker].datetime.day)
        signal=self.getSignal(today)
        if signal == 'BUY':
            self.order(self.ticker, 200)
            self.invested = True
            self.buy_orders.append(data[self.ticker].datetime)
            print ("{dt}: Buying 200" +  self.ticker + "shares.").format(dt=data[self.ticker].datetime)
        elif signal=='SELL':
            self.order(self.ticker, -200)
            self.invested = False
            self.sell_orders.append(data[self.ticker].datetime)
            print ("{dt}: Selling 200" +  self.ticker + "shares.").format(dt=data[self.ticker].datetime)

filename = 'sp_500.txt'    
tickers = open(filename)
tickerz = tickers.readlines()
tickerzz = []
for ticker in tickerz:
    tickerzz.append(only_alphanum(ticker))
print tickerzz
nlp = NLPFinanceNews(nb_classifier, '^VIX', tickerzz)
# Out:
# ['AAPL', 'XOM', 'GE', 'CVX', 'MSFT', 'IBM', 'T', 'GOOG', 'PG', 'JNJ', 'PFE', 'WFC', 'JPM', 'PM', 'KO', 'MRK', 'VZ', 'WMT', 'ORCL', 'INTC', 'PEP', 'ABT', 'QCOM', 'CSCO', 'SLB', 'C', 'CMCSA', 'BAC', 'DIS', 'MCD', 'AMZN', 'HD', 'KFT', 'V', 'OXY', 'COP', 'MO', 'UTX', 'USB', 'AMGN', 'CVS', 'MMM', 'EMC', 'UNH', 'BMY', 'UNP', 'CAT', 'EBAY', 'AXP', 'UPS', 'GS', 'ESRX', 'GILD', 'NWSA', 'MON', 'MA', 'LLY', 'CL', 'BA', 'DD', 'HON', 'SPG', 'DUK', 'ACN', 'MDT', 'COST', 'TWX', 'TGT', 'SO', 'SBUX', 'AIG', 'F', 'FCX', 'MET', 'BIIB', 'EMR', 'APC', 'NKE', 'DOW', 'LOW', 'NOV', 'KMB', 'APA', 'HPQ', 'PNC', 'COF', 'BAX', 'TJX', 'CELG', 'DTV', 'DE', 'DHR', 'TXN', 'HAL', 'WAG', 'PX', 'PCLN', 'EXC', 'D', 'EOG', 'YUM', 'NEE', 'TWC', 'PSX', 'COV', 'ADP', 'AMT', 'AGN', 'NEM', 'BK', 'TRV', 'TYC', 'GIS', 'ITW', 'ACE', 'PRU', 'VIAB', 'CTL', 'LMT', 'FDX', 'PCP', 'BBT', 'MS', 'BLK', 'DVN', 'AFL', 'ALXN', 'GD', 'WMB', 'CBS', 'CSX', 'TMO', 'AEP', 'CTSH', 'MRO', 'DFS', 'NSC', 'MCK', 'CB', 'KMI', 'STT', 'PSA', 'BHI', 'ISRG', 'GLW', 'CRM', 'ALL', 'SE', 'HCP', 'RTN', 'WLP', 'CCI', 'JCI', 'MPC', 'MMC', 'FE', 'VTR', 'SYY', 'PCG', 'HNZ', 'ADM', 'BRCM', 'ED', 'PPG', 'CME', 'LYB', 'APD', 'VLO', 'EQR', 'BEN', 'ECL', 'PPL', 'AON', 'WFM', 'BXP', 'YHOO', 'S', 'NBL', 'NOC', 'CMI', 'CCL', 'PEG', 'INTU', 'PLD', 'SYK', 'TROW', 'COH', 'ADBE', 'HES', 'ETN', 'MOS', 'IP', 'BDX', 'MHP', 'STI', 'LO', 'M', 'MJN', 'EIX', 'EL', 'DISCA', 'HCN', 'BBBY', 'TEL', 'SRE', 'MSI', 'ROST', 'DELL', 'CTXS', 'FITB', 'RAI', 'PCAR', 'WY', 'SCHW', 'VFC', 'WM', 'CF', 'AZO', 'AMAT', 'CAM', 'VNO', 'OMC', 'CI', 'XEL', 'A', 'CAH', 'AET', 'STJ', 'AVB', 'L', 'IR', 'PXD', 'KR', 'SWK', 'K', 'TDC', 'SHW', 'ESV', 'SYMC', 'PH', 'GWW', 'EW', 'ETR', 'NUE', 'SWN', 'MAT', 'CBE', 'NU', 'AMP', 'NTAP', 'ZMH', 'LTD', 'ADI', 'PGR', 'HST', 'FAST', 'MTB', 'HOT', 'RRC', 'HUM', 'CERN', 'CAG', 'IVZ', 'DLTR', 'KSS', 'FTI', 'RHT', 'WU', 'STX', 'DOV', 'ALTR', 'WPI', 'HSY', 'ROP', 'PAYX', 'GPS', 'SNDK', 'DTE', 'PRGO', 'RF', 'NTRS', 'DGX', 'CMG', 'FISV', 'ORLY', 'MUR', 'OKE', 'MYL', 'MAR', 'ROK', 'CHK', 'ABC', 'ICE', 'HOG', 'XRX', 'APH', 'GPC', 'CHRW', 'SJM', 'AA', 'COG', 'FLR', 'DPS', 'CLX', 'RL', 'WYNN', 'BEAM', 'CNP', 'NE', 'JNPR', 'LH', 'EQT', 'CA', 'DVA', 'XLNX', 'EMN', 'SIAL', 'WEC', 'CCE', 'WDC', 'LIFE', 'MCO', 'HIG', 'JWN', 'FRX', 'MNST', 'FFIV', 'NVDA', 'KIM', 'KEY', 'RSG', 'MKC', 'BCR', 'BSX', 'KLAC', 'AEE', 'BWA', 'SPLS', 'FIS', 'SRCL', 'EXPD', 'COL', 'VRSN', 'FMC', 'ADSK', 'PFG', 'WYN', 'SLM', 'PLL', 'TIF', 'TXT', 'XL', 'LLTC', 'WAT', 'NI', 'DRI', 'PCL', 'TAP', 'LLL', 'AVP', 'CNX', 'AES', 'AKAM', 'LNC', 'VAR', 'BLL', 'FLS', 'LUV', 'KMX', 'FDO', 'WHR', 'MCHP', 'SCG', 'DNR', 'CFN', 'CPB', 'CMS', 'VMC', 'MU', 'BMC', 'NYX', 'CMA', 'BTU', 'WIN', 'JOY', 'HBAN', 'TSO', 'HRS', 'LRCX', 'PNW', 'DHI', 'ARG', 'LEN', 'QEP', 'EFX', 'CVH', 'CLF', 'CBG', 'CINF', 'HSP', 'EXPE', 'XRAY', 'UNM', 'MAS', 'MWV', 'SNI', 'PWR', 'JEC', 'PHM', 'IRM', 'HP', 'CSC', 'SUN', 'TMK', 'FTR', 'NRG', 'IPG', 'IFF', 'GAS', 'STZ', 'HRB', 'XYL', 'TSN', 'FOSL', 'DO', 'BBY', 'LUK', 'CTAS', 'HAS', 'POM', 'PBCT', 'NFX', 'RDC', 'SNA', 'GCI', 'URBN', 'NBR', 'TEG', 'EA', 'HRL', 'SWY', 'LSI', 'TSS', 'ZION', 'HCBK', 'AIV', 'RHI', 'PCS', 'MOLX', 'TE', 'TRIP', 'DNB', 'LEG', 'JBL', 'IGT', 'JCP', 'CVC', 'ATI', 'SAI', 'PKI', 'WPX', 'BMS', 'AVY', 'HAR', 'OI', 'AIZ', 'NFLX', 'DF', 'FLIR', 'GT', 'LM', 'APOL', 'PDCO', 'JDSU', 'ANF', 'PBI', 'NDAQ', 'X', 'SEE', 'TER', 'THC', 'GME', 'GNW', 'FHN', 'ETFC', 'AMD', 'R', 'FII', 'RRD', 'BIG', 'AN', 'WPO', 'LXK', 'ANR', 'FSLR', 'DV', 'TIE']

# %%
results = nlp.run(vixFrame)
# Out:
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 496 down: 1 none: 0
# BUY
# 2010-01-21 00:00:00+00:00: Buying 200^VIXshares.
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 496 down: 0 none: 1
# BUY
# 2010-05-06 00:00:00+00:00: Buying 200^VIXshares.
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 496 down: 0 none: 1
# BUY
# 2010-05-18 00:00:00+00:00: Buying 200^VIXshares.
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 496 down: 0 none: 1
# BUY
# 2010-06-30 00:00:00+00:00: Buying 200^VIXshares.
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 496 down: 1 none: 0
# BUY
# 2010-07-09 00:00:00+00:00: Buying 200^VIXshares.
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 496 down: 0 none: 1
# BUY
# 2010-08-04 00:00:00+00:00: Buying 200^VIXshares.
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 496 down: 0 none: 1
# BUY
# 2010-09-22 00:00:00+00:00: Buying 200^VIXshares.
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 496 down: 0 none: 1
# BUY
# 2010-09-30 00:00:00+00:00: Buying 200^VIXshares.
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 496 down: 0 none: 1
# BUY
# 2010-10-20 00:00:00+00:00: Buying 200^VIXshares.
# up: 497 down: 0 none: 0
# up: 497 down: 0 none: 0
# up: 496 down: 0 none: 1
# BUY
# 2010-10-25 00:00:00+00:00: Buying 200^VIXshares.
# up: 497 down: 0 none: 0
# up: 496 down: 0 none: 1
# BUY
# 2010-10-27 00:00:00+00:00: Buying 200^VIXshares.
# up: 497 down: 0 none: 0
# up: 496 down: 0 none: 1
# BUY
# 2010-10-29 00:00:00+00:00: Buying 200^VIXshares.
# up: 496 down: 1 none: 0
# BUY
# 2010-11-01 00:00:00+00:00: Buying 200^VIXshares.
# up: 497 down: 0 none: 0
# up: 496 down: 0 none: 1
# BUY
# 2010-11-03 00:00:00+00:00: Buying 200^VIXshares.
# up: 496 down: 0 none: 1
# BUY
# 2010-11-04 00:00:00+00:00: Buying 200^VIXshares.
# up: 496 down: 0 none: 1
# BUY
# 2010-11-05 00:00:00+00:00: Buying 200^VIXshares.
# up: 495 down: 1 none: 1
# BUY
# 2010-11-08 00:00:00+00:00: Buying 200^VIXshares.
# up: 474 down: 3 none: 20
# BUY
# 2010-11-09 00:00:00+00:00: Buying 200^VIXshares.
# up: 460 down: 5 none: 32
# BUY
# 2010-11-10 00:00:00+00:00: Buying 200^VIXshares.
# up: 470 down: 5 none: 22
# BUY
# 2010-11-11 00:00:00+00:00: Buying 200^VIXshares.
# up: 473 down: 4 none: 20
# BUY
# 2010-11-12 00:00:00+00:00: Buying 200^VIXshares.
# up: 459 down: 10 none: 28
# BUY
# 2010-11-15 00:00:00+00:00: Buying 200^VIXshares.
# up: 453 down: 13 none: 31
# BUY
# 2010-11-16 00:00:00+00:00: Buying 200^VIXshares.
# up: 465 down: 7 none: 25
# BUY
# 2010-11-17 00:00:00+00:00: Buying 200^VIXshares.
# up: 446 down: 10 none: 41
# BUY
# 2010-11-18 00:00:00+00:00: Buying 200^VIXshares.
# up: 470 down: 7 none: 20
# BUY
# 2010-11-19 00:00:00+00:00: Buying 200^VIXshares.
# up: 470 down: 6 none: 21
# BUY
# 2010-11-22 00:00:00+00:00: Buying 200^VIXshares.
# up: 473 down: 3 none: 21
# BUY
# 2010-11-23 00:00:00+00:00: Buying 200^VIXshares.
# up: 485 down: 4 none: 8
# BUY
# 2010-11-24 00:00:00+00:00: Buying 200^VIXshares.
# up: 496 down: 1 none: 0
# BUY
# 2010-11-26 00:00:00+00:00: Buying 200^VIXshares.
# up: 462 down: 8 none: 27
# BUY
# 2010-11-29 00:00:00+00:00: Buying 200^VIXshares.
# up: 458 down: 10 none: 29
# BUY
# 2010-11-30 00:00:00+00:00: Buying 200^VIXshares.
# up: 450 down: 6 none: 41
# BUY
# 2010-12-01 00:00:00+00:00: Buying 200^VIXshares.
# up: 459 down: 13 none: 25
# BUY
# 2010-12-02 00:00:00+00:00: Buying 200^VIXshares.
# up: 476 down: 6 none: 15
# BUY
# 2010-12-03 00:00:00+00:00: Buying 200^VIXshares.
# up: 463 down: 12 none: 22
# BUY
# 2010-12-06 00:00:00+00:00: Buying 200^VIXshares.
# up: 453 down: 10 none: 34
# BUY
# 2010-12-07 00:00:00+00:00: Buying 200^VIXshares.
# up: 450 down: 11 none: 36
# BUY
# 2010-12-08 00:00:00+00:00: Buying 200^VIXshares.
# up: 455 down: 10 none: 32
# BUY
# 2010-12-09 00:00:00+00:00: Buying 200^VIXshares.
# up: 475 down: 6 none: 16
# BUY
# 2010-12-10 00:00:00+00:00: Buying 200^VIXshares.
# up: 464 down: 8 none: 25
# BUY
# 2010-12-13 00:00:00+00:00: Buying 200^VIXshares.
# up: 449 down: 13 none: 35
# BUY
# 2010-12-14 00:00:00+00:00: Buying 200^VIXshares.
# up: 457 down: 12 none: 28
# BUY
# 2010-12-15 00:00:00+00:00: Buying 200^VIXshares.
# up: 456 down: 11 none: 30
# BUY
# 2010-12-16 00:00:00+00:00: Buying 200^VIXshares.
# up: 477 down: 7 none: 13
# BUY
# 2010-12-17 00:00:00+00:00: Buying 200^VIXshares.
# up: 458 down: 11 none: 28
# BUY
# 2010-12-20 00:00:00+00:00: Buying 200^VIXshares.
# up: 475 down: 4 none: 18
# BUY
# 2010-12-21 00:00:00+00:00: Buying 200^VIXshares.
# up: 467 down: 7 none: 23
# BUY
# 2010-12-22 00:00:00+00:00: Buying 200^VIXshares.
# up: 487 down: 3 none: 7
# BUY
# 2010-12-23 00:00:00+00:00: Buying 200^VIXshares.
# up: 488 down: 4 none: 5
# BUY
# 2010-12-27 00:00:00+00:00: Buying 200^VIXshares.
# up: 482 down: 5 none: 10
# BUY
# 2010-12-28 00:00:00+00:00: Buying 200^VIXshares.
# up: 478 down: 9 none: 10
# BUY
# 2010-12-29 00:00:00+00:00: Buying 200^VIXshares.
# up: 487 down: 6 none: 4
# BUY
# 2010-12-30 00:00:00+00:00: Buying 200^VIXshares.
# up: 489 down: 3 none: 5
# BUY
# 2010-12-31 00:00:00+00:00: Buying 200^VIXshares.
# up: 476 down: 4 none: 17
# BUY
# 2011-01-03 00:00:00+00:00: Buying 200^VIXshares.
# up: 466 down: