# %%
import nltk as nltk
#nltk.download()
from nltk.corpus import stopwords
import os, os.path
path = os.path.expanduser('~/nltk_data')
if not os.path.exists(path):
    os.mkdir(path)
os.path.exists(path)
import nltk.data
path in nltk.data.path
from nltk.corpus.reader import CategorizedPlaintextCorpusReader
reader = CategorizedPlaintextCorpusReader('.', r'.*_news_.*\.csv', cat_pattern=r'.*_news_(\w+)\.csv')
reader.categories()
reader.fileids(categories=['UP'])
def bag_of_words(words):
    return dict([(word, True) for word in words if word[0].isalpha()])
import collections
def bag_of_words_not_in_set(words, badwords):
    return bag_of_words(set(words)-set(badwords))

def bag_of_non_stopwords(words, stopfile='english'):
    badwords = stopwords.words(stopfile)
    return bag_of_words_not_in_set(words, badwords)

from nltk.metrics import BigramAssocMeasures
from nltk.collocations import BigramCollocationFinder

def bag_of_bigrams_words(words, score_fn=BigramAssocMeasures.chi_sq, n=2000):
    bigram_finder = BigramCollocationFinder.from_words(words)
    bigrams = bigram_finder.nbest(score_fn, n)
    return bag_of_words(bigrams)
    
def label_feats_from_corpus(corp, feature_detector=bag_of_bigrams_words):
    label_feats = collections.defaultdict(list)
    for label in corp.categories():
        for fileid in corp.fileids(categories=[label]):
            feats = feature_detector(corp.words(fileids=[fileid]))
            label_feats[label].append(feats)
    return label_feats

def split_label_feats(lfeats, split=0.90):
    train_feats = []
    test_feats = []
    for label, feats in lfeats.iteritems():
        cutoff = int(len(feats) * split)
        train_feats.extend([(feat, label) for feat in feats[:cutoff]])
        test_feats.extend([(feat, label) for feat in feats[cutoff:]])
    return train_feats, test_feats




reader.categories()

lfeats = label_feats_from_corpus(reader)
lfeats.keys()
train_feats, test_feats = split_label_feats(lfeats)
len(train_feats)
len(test_feats)

from nltk.classify import NaiveBayesClassifier
nb_classifier = NaiveBayesClassifier.train(train_feats)
nb_classifier.labels()

from nltk.classify.util import accuracy
accuracy(nb_classifier, test_feats)
# Out:
# 0.3333333333333333

# %%
len(train_feats)
# Out:
# 145

# %%
reader.raw()
# Out:
# '2010-11-16 00:00:00,Hrvatski Telekom Signs Agreement With Apple\n2011-01-18 00:00:00,Apple Issues Q2 2011 Guidance Above Estimates\n2011-02-17 00:00:00,Telling Telecom Holding Subsidiary Signs Agreement to Be Apple Distributor\n2011-02-18 00:00:00,US Regulators Probe Apple Subscription\n2011-03-15 00:00:00,Apple Delays iPad 2 Launch In\n2011-04-11 00:00:00,Bharti Airtel Aircel To Sell Apple iPhone 4 In\n2011-06-17 00:00:00,Apple And Samsung Electronics In Talks On Patent\n2011-06-24 00:00:00,Apple Apple Korea Sues Samsung Electronics In Seoul Over\n2011-07-11 00:00:00,Apple Files Patent Complaint Against HTC\n2011-08-02 00:00:00,HTC Corp Sees Final Ruling On Apple Graphics Case In\n2011-08-10 00:00:00,Apple Blocks Samsung Electronics From Selling Galaxy Tablet In\n2011-08-18 00:00:00,China Mobile Limited Talking To Apple On\n2011-08-31 00:00:00,Openwave Takes Legal Action Against Apple Inc And Research In Motion Limited To Protect Intellectual Property For Mobile Internet Access\n2011-09-02 00:00:00,Initiates Litigation Against Dell Company And Novatel\n2011-09-09 00:00:00,Apple Wins German Court Ruling On Samsung Electronics\n2011-09-22 00:00:00,VIA and Subsidiaries Sue Apple\n2011-09-29 00:00:00,Apple Jobs Tried To Defuse Samsung Electronics Patents\n2011-11-01 00:00:00,VirnetX Holding Corp Files New Complaint Against Apple\n2012-01-20 00:00:00,German Court Grants Victory To Apple In Patent Suit With Samsung Electronics\n2012-01-24 00:00:00,Apple Issues Q2 2012 Guidance Above Estimates\n2012-04-10 00:00:00,DOJ May Sue Apple Over\n2012-04-13 00:00:00,Apple Inc Rejects Pricing Collusion\n2012-04-19 00:00:00,Apple Inc And Other Technology Companies Fail To Dismiss\n2012-04-20 00:00:00,Hagens Berman Announces Lawsuit Claims Wide Range Of Apple Devices Infringe Patents For Screen Manipulation\n2012-04-24 00:00:00,Apple Inc Infringes On Motorola Mobility Holdings Inc ITC\n2012-05-14 00:00:00,US Court Revives Apple Claim On Samsung Electronics Co\n2012-06-21 00:00:00,Dutch Court Gives Samsung Electronics Co Ltd Rare Victory Over Apple\n2012-08-21 00:00:00,Apple Samsung Electronics Co Ltd CEOs Talk But No Trial Settlement\n2012-08-30 00:00:00,Google Apple CEOs In Secret Patent\n2012-10-11 00:00:00,Court Clears Samsung Electronics Co Ltd Hands Apple\n2012-10-18 00:00:00,Apple Inc Loses Tablet Copyright Appeal Against Samsung Electronics Co\n2012-10-23 00:00:00,Apple Inc To Sell Version iPad\n2012-10-25 00:00:00,Apple Inc Declares Cash Dividend\n2010-11-10 00:00:00,Dentsu Announces Partnership with Apple to Bring iAd to Japan\n2010-12-16 00:00:00,Nokia Oyj Files Patent Infringement Complaints against Apple in Germany and Netherlands\n2010-12-28 00:00:00,Apple Sued For Allegedly Sending User Data To\n2010-12-29 00:00:00,Microsoft Relaunches Tech Patent Suit Against Apple Google Facebook And\n2011-01-11 00:00:00,Hagens Berman Investigates Claims Apple iPhone Glass Prone to Breakage\n2011-01-31 00:00:00,To Reach Settlement With Apple\n2011-02-24 00:00:00,Intel Corporation Announces Thunderbolt Technology In Collaboration With\n2011-03-02 00:00:00,Apple Announces Launch Of iPad 2\n2011-03-22 00:00:00,Apple Sues Over APP STORE\n2011-03-28 00:00:00,ECS ICT Bhd Receives Distributorship Award From Apple For Apple iPad In Malaysia\n2011-03-29 00:00:00,Nokia Corporation Files Second ITC Complaint Against Apple\n2011-04-12 00:00:00,Walker Digital Files 15 Lawsuits Against Apple And\n2011-04-25 00:00:00,Samsung Electronics Counter Sues Apple Over\n2011-04-29 00:00:00,Apple Launches iPad 2 In Standard\n2011-05-05 00:00:00,Lawsuit Accuses Adobe Apple Google Intel Corporation And Intuit For Fixing\n2011-06-22 00:00:00,Apple May Face Antitrust Probe In\n2011-06-30 00:00:00,Samsung Electronics Files Complaint Against Apple With US International Trade\n2011-07-06 00:00:00,Apple Trade Complaint With Authorities Against Samsung Electronics\n2011-07-14 00:00:00,South Korean Attorney Files Suit Against Apple South Korea\n2011-07-19 00:00:00,Apple Issues Q ...

# %%
nb_classifier.show_most_informative_features(n=1000)
# Out:
# Most Informative Features
#    ('Guidance', 'Above') = True               UP : DOWN   =      8.1 : 1.0
#         ('Agrees', 'To') = True             NONE : DOWN   =      7.1 : 1.0
#            ('Co', 'and') = True             NONE : UP     =      6.6 : 1.0
#          ('Talks', 'To') = True             NONE : UP     =      6.6 : 1.0
#      ('Company', '2012') = True             NONE : UP     =      6.6 : 1.0
# ('License', 'Agreement') = True             NONE : DOWN   =      6.4 : 1.0
# ('Repurchase', 'Program') = True             NONE : DOWN   =      6.4 : 1.0
#    ('Fourth', 'Quarter') = True             NONE : DOWN   =      6.4 : 1.0
#   ('Above', 'Estimates') = True               UP : DOWN   =      6.2 : 1.0
#         ('Blog', '2012') = True             NONE : UP     =      6.0 : 1.0
#     ('Services', '2011') = True             NONE : UP     =      5.9 : 1.0
#           ('Of', '2011') = True             NONE : UP     =      5.9 : 1.0
#           ('And', 'The') = True             NONE : UP     =      5.9 : 1.0
#        ('Million', 'To') = True             NONE : UP     =      5.9 : 1.0
#         ('Corp', '2012') = True             NONE : DOWN   =      5.7 : 1.0
#          ('OTC', '2011') = True             NONE : DOWN   =      5.7 : 1.0
#            ('Use', 'Of') = True             NONE : UP     =      5.2 : 1.0
#           ('Co', '2012') = True             NONE : UP     =      5.2 : 1.0
#      ('Agreement', 'To') = True             NONE : UP     =      5.2 : 1.0
#  ('Investigation', 'of') = True             NONE : UP     =      5.2 : 1.0
#        ('Results', 'Of') = True             NONE : UP     =      5.2 : 1.0
#    ('Development', 'Of') = True             NONE : UP     =      5.2 : 1.0
#     ('Contract', '2012') = True             NONE : UP     =      5.2 : 1.0
#           ('Of', '2012') = True             NONE : UP     =      5.2 : 1.0
#    ('JPMorgan', 'Chase') = True             NONE : UP     =      5.2 : 1.0
#  ('Partnership', '2011') = True             NONE : UP     =      5.2 : 1.0
#      ('Co', 'Announces') = True             NONE : DOWN   =      5.1 : 1.0
#         ('Offer', 'for') = True             NONE : DOWN   =      5.1 : 1.0
#       ('Dividend', 'By') = True             NONE : DOWN   =      5.1 : 1.0
#    ('Technology', 'For') = True             NONE : DOWN   =      5.1 : 1.0
#          ('Law', 'Firm') = True             NONE : DOWN   =      5.1 : 1.0
#     ('Patients', 'With') = True             NONE : DOWN   =      5.1 : 1.0
#        ('Partner', 'To') = True             NONE : DOWN   =      5.1 : 1.0
#            ('To', 'Cut') = True             NONE : DOWN   =      5.1 : 1.0
#      ('Tender', 'Offer') = True             NONE : DOWN   =      4.7 : 1.0
#         ('Group', 'And') = True             NONE : UP     =      4.5 : 1.0
#   ('Chief', 'Financial') = True             NONE : UP     =      4.5 : 1.0
#          ('Offer', 'To') = True             NONE : UP     =      4.5 : 1.0
# ('Financial', 'Officer') = True             NONE : UP     =      4.5 : 1.0
# ('Pharmaceuticals', 'Inc') = True             NONE : UP     =      4.5 : 1.0
#    ('Form', 'Strategic') = True             NONE : UP     =      4.5 : 1.0
#       ('Approval', 'Of') = True             NONE : UP     =      4.5 : 1.0
#        ('To', 'Advance') = True             NONE : UP     =      4.5 : 1.0
#        ('Enter', 'Into') = True             NONE : UP     =      4.5 : 1.0
#            ('Of', 'The') = True             NONE : UP     =      4.5 : 1.0
#       ('In', 'Patients') = True             NONE : DOWN   =      4.4 : 1.0
#      ('Treatment', 'of') = True             NONE : DOWN   =      4.4 : 1.0
#      ('Program', '2012') = True             NONE : DOWN   =      4.4 : 1.0
#          ('Plans', 'To') = True             NONE : DOWN   =      4.4 : 1.0
# ('Announces', 'Results') = True             NONE : DOWN   =      4.4 : 1.0
#      ('Analyst', 'Blog') = True             NONE : UP     =      4.3 : 1.0
#        ('Narrows', 'FY') = True             DOWN : NONE   =      4.3 : 1.0
#             ('To', 'Be') = True             NONE : DOWN   =      4.3 : 1.0
#         ('Offer', 'For') = True             NONE : DOWN   =      4.3 : 1.0
#  ('Share', 'Repurchase') = True             NONE : DOWN   =      4.2 : 1.0
#        ('Trading', 'on') = True             NONE : DOWN   =      4.2 : 1.0
#        ('To', 'Develop') = True             NONE : UP     =      4.0 : 1.0
#           ('To', 'Sell') = True             NONE : UP     =      3.9 : 1.0
#          ('Inc', '2012') = True             NONE : DOWN   =      3.9 : 1.0
# ('Collaboration', 'With') = True             NONE : DOWN   =      3.9 : 1.0
#           ('Corp', 'To') = True             NONE : UP     =      3.8 : 1.0
#            ('In', 'The') = True             NONE : UP     =      3.8 : 1.0
#           ('And', 'Its') = True             NONE : UP     =      3.8 : 1.0
#       ('Company', 'and') = True             NONE : UP     =      3.8 : 1.0
#           ('Jobs', 'In') = True             NONE : UP     =      3.8 : 1.0
#      ('FDA', 'Advisory') = True             NONE : UP     =      3.8 : 1.0
#         ('The', 'Zacks') = True             NONE : UP     =      3.8 : 1.0
#          ('State', 'of') = True             NONE : UP     =      3.8 : 1.0
#        ('To', 'Support') = True             NONE : UP     =      3.8 : 1.0
#       ('Interest', 'In') = True             NONE : UP     =      3.8 : 1.0
#      ('Senior', 'Notes') = True             NONE : UP     =      3.8 : 1.0
#  ('Million', 'Contract') = True             NONE : UP     =      3.8 : 1.0
#      ('Stock', 'Rating') = True             NONE : UP     =      3.8 : 1.0
#     ('Zacks', 'Analyst') = True             NONE : UP     =      3.8 : 1.0
#            ('SA', 'And') = True             NONE : UP     =      3.8 : 1.0
#       ('Files', 'Class') = True             NONE : UP     =      3.8 : 1.0
#        ('Teams', 'With') = True             NONE : UP     =      3.8 : 1.0
# ('Corporation', 'Completes') = True             NONE : DOWN   =      3.7 : 1.0
#      ('Million', '2011') = True             NONE : DOWN   =      3.7 : 1.0
#         ('On', 'Behalf') = True             NONE : DOWN   =      3.7 : 1.0
#             ('Up', 'To') = True             NONE : DOWN   =      3.7 : 1.0
#     ('Agreement', 'for') = True             NONE : DOWN   =      3.7 : 1.0
#        ('Daily', 'News') = True             NONE : DOWN   =      3.7 : 1.0
# ('Definitive', 'Agreement') = True             NONE : DOWN   =      3.7 : 1.0
#         ('In', 'Brazil') = True             NONE : DOWN   =      3.7 : 1.0
# ('Repurchase', 'Authorization') = True             NONE : DOWN   =      3.7 : 1.0
#    ('Starts', 'Trading') = True             NONE : DOWN   =      3.6 : 1.0
#            ('on', 'OTC') = True             NONE : DOWN   =      3.6 : 1.0
#     ('Inc', 'Announces') = True             NONE : UP     =      3.6 : 1.0
#       ('Pay', 'Million') = True             NONE : UP     =      3.5 : 1.0
#  ('Investigation', 'Of') = True             NONE : UP     =      3.5 : 1.0
#          ('For', '2011') = True             NONE : UP     =      3.5 : 1.0
#  ('Partnership', 'With') = True             NONE : DOWN   =      3.4 : 1.0
#   ('Signs', 'Agreement') = True             NONE : DOWN   =      3.4 : 1.0
#           ('In', '2012') = True             NONE : DOWN   =      3.4 : 1.0
#         ('To', 'Settle') = True             NONE : DOWN   =      3.4 : 1.0
#          ('Stake', 'In') = True             NONE : DOWN   =      3.4 : 1.0
#     ('Announces', 'New') = True             NONE : DOWN   =      3.4 : 1.0
#    ('Acquisition', 'of') = True             NONE : DOWN   =      3.3 : 1.0
#        ('System', 'For') = True             NONE : UP     =      3.1 : 1.0
#    ('Economic', 'Times') = True             NONE : UP     =      3.1 : 1.0
#           ('Team', 'Up') = True             NONE : UP     =      3.1 : 1.0
# ('Collaboration', '2011') = True             NONE : UP     =      3.1 : 1.0
#       ('Action', 'Suit') = True             NONE : UP     =      3.1 : 1.0
# ('Announces', 'Settlement') = True             NONE : UP     =      3.1 : 1.0
#         ('With', '2012') = True             NONE : UP     =      3.1 : 1.0
#   ('Company', 'Limited') = True             NONE : UP     =      3.1 : 1.0
#   ('Litigation', 'With') = True             NONE : UP     =      3.1 : 1.0
#        ('To', 'Deliver') = True             NONE : UP     =      3.1 : 1.0
#       ('Results', 'For') = True             NONE : UP     =      3.1 : 1.0
#    ('Robbins', 'Geller') = True             NONE : UP     =      3.1 : 1.0
# ('Receives', 'Approval') = True             NONE : UP     =      3.1 : 1.0
#    ('Into', 'Agreement') = True             NONE : UP     =      3.1 : 1.0
#    ('to', 'Collaborate') = True             NONE : UP     =      3.1 : 1.0
#         ('and', 'Merck') = True             NONE : UP     =      3.1 : 1.0
#        ('Talks', 'With') = True             NONE : UP     =      3.1 : 1.0
#         ('Deal', 'With') = True             NONE : UP     =      3.1 : 1.0
#       ('Market', '2011') = True             NONE : UP     =      3.1 : 1.0
#      ('Lawsuit', 'With') = True             NONE : UP     =      3.1 : 1.0
#     ('Projects', '2011') = True             NONE : UP     =      3.1 : 1.0
#          ('Of', 'Phase') = True             NONE : UP     =      3.1 : 1.0
#           ('For', 'Use') = True             NONE : UP     =      3.1 : 1.0
#             ('For', 'A') = True             NONE : UP     =      3.1 : 1.0
#           ('of', '2012') = True             NONE : UP     =      3.1 : 1.0
# ('Announce', 'Strategic') = True             NONE : UP     =      3.1 : 1.0
#        ('Of', 'Million') = True             NONE : UP     =      3.1 : 1.0
#     ('Research', '2011') = True             NONE : UP     =      3.1 : 1.0
#           ('Deal', 'To') = True             NONE : UP     =      3.1 : 1.0
#     ('Geller', 'Rudman') = True             NONE : UP     =      3.1 : 1.0
#           ('And', 'Gas') = True             NONE : UP     =      3.1 : 1.0
#     ('LLC', 'Announces') = True             NONE : UP     =      3.1 : 1.0
#         ('New', 'Share') = True             NONE : UP     =      3.1 : 1.0
#   ('Technology', '2011') = True             NONE : UP     =      3.1 : 1.0
#     ('Citigroup', 'And') = True             NONE : UP     =      3.1 : 1.0
#           ('To', '2012') = True             NONE : UP     =      3.1 : 1.0
#         ('Trials', 'Of') = True             NONE : UP     =      3.1 : 1.0
#      ('Announces', 'To') = True             NONE : UP     =      3.1 : 1.0
#       ('Adults', 'With') = True             NONE : UP     =      3.1 : 1.0
#         ('III', 'Study') = True             NONE : UP     =      3.1 : 1.0
# ('Rating', 'Reaffirmed') = True             NONE : UP     =      3.1 : 1.0
#       ('Rudman', 'Dowd') = True             NONE : UP     =      3.1 : 1.0
# ('Distribution', 'Agreement') = True             NONE : UP     =      3.1 : 1.0
#          ('Dowd', 'LLP') = True             NONE : UP     =      3.1 : 1.0
#  ('Corporation', '2010') = True             NONE : UP     =      3.1 : 1.0
#     ('Reaffirmed', 'by') = True             NONE : UP     =      3.1 : 1.0
#          ('In', 'Japan') = True             NONE : UP     =      3.1 : 1.0
#            ('To', 'Pay') = True             NONE : UP     =      3.1 : 1.0
# ('Strategic', 'Partnership') = True             NONE : UP     =      3.1 : 1.0
#         ('Launch', 'Of') = True             NONE : UP     =      3.1 : 1.0
#   ('And', 'Development') = True             NONE : UP     =      3.1 : 1.0
#             ('Co', 'To') = True             NONE : UP     =      3.1 : 1.0
#    ('Insurance', '2011') = True             NONE : UP     =      3.1 : 1.0
#             ('to', 'Be') = True             NONE : UP     =      3.1 : 1.0
#          ('At', 'Least') = True             NONE : UP     =      3.1 : 1.0
#      ('Of', 'Fiduciary') = True             NONE : UP     =      3.1 : 1.0
#            ('and', 'Co') = True             NONE : UP     =      3.1 : 1.0
#      ('FDA', 'Approves') = True             NONE : UP     =      3.1 : 1.0
#    ('Corp', 'Reaffirms') = True             NONE : UP     =      3.1 : 1.0
#        ('Study', '2011') = True             NONE : UP     =      3.1 : 1.0
#           ('Oil', 'And') = True             NONE : UP     =      3.1 : 1.0
#        ('From', 'Phase') = True             NONE : UP     =      3.1 : 1.0
#      ('Results', '2012') = True             NONE : UP     =      3.1 : 1.0
#     ('Business', 'From') = True             NONE : UP     =      3.1 : 1.0
#   ('Corporation', 'and') = True             DOWN : UP     =      3.1 : 1.0
#            ('To', 'Sue') = True             DOWN : UP     =      3.1 : 1.0
#  ('General', 'Electric') = True             DOWN : UP     =      3.1 : 1.0
#           ('Sees', 'FY') = True             DOWN : UP     =      3.1 : 1.0
#      ('EPS', 'Comments') = True             DOWN : UP     =      3.1 : 1.0
#       ('Expected', 'To') = True             DOWN : UP     =      3.1 : 1.0
#       ('Court', 'Rules') = True             NONE : DOWN   =      3.0 : 1.0
#     ('Offering', '2011') = True             NONE : DOWN   =      3.0 : 1.0
#      ('Co', 'Completes') = True             NONE : DOWN   =      3.0 : 1.0
#   ('Corporation', 'For') = True             NONE : DOWN   =      3.0 : 1.0
# ('Production', 'Guidance') = True             NONE : DOWN   =      3.0 : 1.0
#          ('Stake', 'in') = True             NONE : DOWN   =      3.0 : 1.0
#    ('Private', 'Equity') = True             NONE : DOWN   =      3.0 : 1.0
#        ('Berman', 'LLP') = True             NONE : DOWN   =      3.0 : 1.0
#      ('Program', '2011') = True             NONE : DOWN   =      3.0 : 1.0
#          ('Data', 'For') = True             NONE : DOWN   =      3.0 : 1.0
#     ('Contract', 'with') = True             NONE : DOWN   =      3.0 : 1.0
#   ('Chief', 'Executive') = True             NONE : DOWN   =      3.0 : 1.0
#         ('System', 'To') = True             NONE : DOWN   =      3.0 : 1.0
#         ('Behalf', 'Of') = True             NONE : DOWN   =      3.0 : 1.0
# ('Energy', 'Corporation') = True             NONE : DOWN   =      3.0 : 1.0
#    ('Collaborate', 'on') = True             NONE : DOWN   =      3.0 : 1.0
#     ('Corp', 'Acquires') = True             NONE : DOWN   =      3.0 : 1.0
#          ('Inc', '2011') = True             NONE : DOWN   =      3.0 : 1.0
#     ('Announces', 'FDA') = True             NONE : DOWN   =      3.0 : 1.0
#   ('Application', 'For') = True             NONE : DOWN   =      3.0 : 1.0
#        ('Share', '2012') = True             NONE : DOWN   =      3.0 : 1.0
#    ('Collaborate', 'To') = True             NONE : DOWN   =      3.0 : 1.0
#    ('Announces', 'Sale') = True             NONE : DOWN   =      3.0 : 1.0
#       ('Services', 'To') = True             NONE : DOWN   =      3.0 : 1.0
#        ('Inc', 'Starts') = True             NONE : DOWN   =      3.0 : 1.0
#   ('Banks', 'Including') = True             NONE : DOWN   =      3.0 : 1.0
#        ('Updates', 'FY') = True             DOWN : NONE   =      3.0 : 1.0
#     ('Dividend', '2010') = True               UP : DOWN   =      2.9 : 1.0
#           ('Part', 'Of') = True               UP : DOWN   =      2.9 : 1.0
#      ('Below', 'Issues') = True               UP : DOWN   =      2.9 : 1.0
#       ('With', 'Raises') = True               UP : DOWN   =      2.9 : 1.0
#           ('By', '2011') = True               UP : DOWN   =      2.9 : 1.0
#   ('Development', 'And') = True               UP : DOWN   =      2.9 : 1.0
# ('Announces', 'Completion') = True               UP : DOWN   =      2.9 : 1.0
# ('Corporation', 'Increases') = True               UP : DOWN   =      2.9 : 1.0
# ('Announces', 'Agreement') = True             NONE : UP     =      2.9 : 1.0
#     ('Credit', 'Suisse') = True               UP : NONE   =      2.9 : 1.0
#   ('Reach', 'Agreement') = True               UP : NONE   =      2.9 : 1.0
#   ('Declares', 'Second') = True               UP : NONE   =      2.9 : 1.0
#     ('Joint', 'Venture') = True             NONE : DOWN   =      2.9 : 1.0
# ('Strategic', 'Alliance') = True             NONE : UP     =      2.8 : 1.0
#          ('In', 'Talks') = True             NONE : UP     =      2.8 : 1.0
#     ('Business', '2011') = True             NONE : UP     =      2.8 : 1.0
#            ('Inc', 'To') = True             NONE : UP     =      2.8 : 1.0
#            ('To', 'Buy') = True             NONE : UP     =      2.8 : 1.0
#   ('Below', 'Estimates') = True             DOWN : UP     =      2.8 : 1.0
#            ('Of', 'New') = True             NONE : DOWN   =      2.8 : 1.0
#         ('To', 'Expand') = True             NONE : UP     =      2.7 : 1.0
#        ('Venture', 'To') = True             NONE : UP     =      2.7 : 1.0
#           ('PLC', 'And') = True             NONE : UP     =      2.7 : 1.0
#         ('Phase', 'III') = True             NONE : UP     =      2.7 : 1.0
#           ('FY', '2013') = True             DOWN : NONE   =      2.7 : 1.0
#       ('Limited', 'And') = True             NONE : DOWN   =      2.6 : 1.0
#           ('To', 'Make') = True             NONE : DOWN   =      2.6 : 1.0
# ('Patent', 'Infringement') = True             NONE : DOWN   =      2.6 : 1.0
#     ('For', 'Treatment') = True             NONE : DOWN   =      2.6 : 1.0
#      ('Results', 'From') = True             NONE : DOWN   =      2.6 : 1.0
#      ('Quarter', '2012') = True             NONE : DOWN   =      2.6 : 1.0
#        ('Billion', 'In') = True             NONE : DOWN   =      2.6 : 1.0
#    ('Company', 'Issues') = True             DOWN : NONE   =      2.6 : 1.0
#          ('High', 'End') = True             DOWN : NONE   =      2.6 : 1.0
#      ('Disease', '2011') = True               UP : DOWN   =      2.5 : 1.0
#    ('Revenue', 'Raises') = True               UP : DOWN   =      2.5 : 1.0
#       ('For', 'Billion') = True               UP : DOWN   =      2.5 : 1.0
#      ('FDA', 'Approval') = True             NONE : UP     =      2.5 : 1.0
#    ('Corp', 'Announces') = True             NONE : UP     =      2.5 : 1.0
#          ('To', 'Build') = True             NONE : UP     =      2.5 : 1.0
#    ('Second', 'Quarter') = True               UP : NONE   =      2.5 : 1.0
#        ('To', 'Provide') = True             DOWN : UP     =      2.5 : 1.0
#    ('Agreement', '2012') = True             NONE : DOWN   =      2.5 : 1.0
#       ('Co', 'Declares') = True             NONE : DOWN   =      2.5 : 1.0
#      ('Class', 'Action') = True             NONE : DOWN   =      2.5 : 1.0
#    ('Agreement', 'with') = True             NONE : DOWN   =      2.5 : 1.0
#        ('Chase', '2012') = True             NONE : UP     =      2.4 : 1.0
#    ('Neutral', 'Rating') = True             NONE : UP     =      2.4 : 1.0
#         ('Signs', 'New') = True             NONE : UP     =      2.4 : 1.0
#     ('Solutions', 'For') = True             NONE : UP     =      2.4 : 1.0
#         ('To', 'Launch') = True             NONE : UP     =      2.4 : 1.0
# ('Securities', 'Arbitration') = True             NONE : UP     =      2.4 : 1.0
#        ('GE', 'Capital') = True             NONE : UP     =      2.4 : 1.0
#             ('On', 'Q3') = True             NONE : UP     =      2.4 : 1.0
#    ('Dividend', 'Stock') = True             NONE : UP     =      2.4 : 1.0
# ('International', 'Declares') = True             NONE : UP     =      2.4 : 1.0
#   ('Public', 'Offering') = True             NONE : UP     =      2.4 : 1.0
#          ('For', '2012') = True             NONE : UP     =      2.4 : 1.0
#        ('Group', '2011') = True             NONE : UP     =      2.4 : 1.0
#    ('Notes', 'Offering') = True             NONE : UP     =      2.4 : 1.0
#            ('Due', 'To') = True             NONE : UP     =      2.4 : 1.0
#            ('US', 'FDA') = True             NONE : UP     =      2.4 : 1.0
#     ('Guidance', '2010') = True             NONE : UP     =      2.4 : 1.0
#        ('Files', 'Suit') = True             NONE : UP     =      2.4 : 1.0
#     ('Completion', 'of') = True             NONE : UP     =      2.4 : 1.0
#           ('AG', '2011') = True             NONE : UP     =      2.4 : 1.0
#          ('II', 'Study') = True             NONE : UP     =      2.4 : 1.0
#  ('Collaboration', 'to') = True             NONE : UP     =      2.4 : 1.0
# ('Investigation', 'Into') = True             NONE : UP     =      2.4 : 1.0
#        ('Ford', 'Motor') = True             NONE : UP     =      2.4 : 1.0
#       ('Contract', 'To') = True             NONE : UP     =      2.4 : 1.0
#         ('Of', 'Senior') = True             NONE : UP     =      2.4 : 1.0
#  ('Capital', 'Partners') = True             NONE : UP     =      2.4 : 1.0
#        ('To', 'Billion') = True             NONE : UP     =      2.4 : 1.0
# ('Honeywell', 'International') = True             NONE : UP     =      2.4 : 1.0
# ('Announces', 'Regular') = True             NONE : UP     =      2.4 : 1.0
#    ('Company', 'Starts') = True             NONE : UP     =      2.4 : 1.0
#        ('Signing', 'Of') = True             NONE : UP     =      2.4 : 1.0
#        ('to', 'Develop') = True             NONE : UP     =      2.4 : 1.0
# ('Form', 'Collaboration') = True             NONE : UP     =      2.4 : 1.0
#      ('Dividends', 'On') = True             NONE : UP     =      2.4 : 1.0
#        ('to', 'Provide') = True             NONE : UP     =      2.4 : 1.0
#          ('Merck', 'Co') = True             NONE : UP     =      2.4 : 1.0
#         ('Of', 'Tender') = True             NONE : UP     =      2.4 : 1.0
#          ('Plc', '2012') = True             NONE : UP     =      2.4 : 1.0
#            ('Co', 'Inc') = True             NONE : UP     =      2.4 : 1.0
#      ('Disease', '2012') = True             NONE : UP     =      2.4 : 1.0
#        ('Japan', '2012') = True             NONE : UP     =      2.4 : 1.0
#      ('Over', 'Billion') = True             NONE : UP     =      2.4 : 1.0
#   ('Arbitration', 'Law') = True             NONE : UP     =      2.4 : 1.0
#     ('Claim', 'Against') = True             NONE : UP     =      2.4 : 1.0
# ('Corporation', 'Announce') = True             NONE : UP     =      2.4 : 1.0
#     ('Department', 'Of') = True             NONE : UP     =      2.4 : 1.0
#             ('SA', 'To') = True             NONE : UP     =      2.4 : 1.0
#       ('Data', 'Center') = True             NONE : UP     =      2.4 : 1.0
#           ('To', 'Seek') = True             NONE : UP     =      2.4 : 1.0
#        ('Times', '2012') = True             NONE : UP     =      2.4 : 1.0
# ('Receives', 'Positive') = True             NONE : UP     =      2.4 : 1.0
#  ('Stock', 'Repurchase') = True             NONE : UP     =      2.4 : 1.0
# ('Subsidiary', 'Enters') = True             NONE : UP     =      2.4 : 1.0
# ('Announces', 'Positive') = True             NONE : UP     =      2.4 : 1.0
#   ('Announces', 'Third') = True             NONE : UP     =      2.4 : 1.0
# ('Announces', 'Strategic') = True             NONE : UP     =      2.4 : 1.0
#        ('Company', 'to') = True             NONE : UP     =      2.4 : 1.0
#      ('Launches', 'New') = True             NONE : UP     =      2.4 : 1.0
#       ('Real', 'Estate') = True             NONE : UP     =      2.4 : 1.0
#            ('One', 'Of') = True             NONE : UP     =      2.4 : 1.0
#           ('plc', 'And') = True             NONE : UP     =      2.4 : 1.0
#    ('Action', 'Against') = True             NONE : UP     =      2.4 : 1.0
#     ('United', 'Parcel') = True             NONE : UP     =      2.4 : 1.0
#     ('Solution', '2011') = True             NONE : UP     =      2.4 : 1.0
#  ('Asset', 'Management') = True             NONE : UP     =      2.4 : 1.0
#           ('Bank', 'Of') = True             NONE : UP     =      2.4 : 1.0
#           ('To', 'Join') = True             NONE : UP     =      2.4 : 1.0
# ('Announces', 'Definitive') = True             NONE : UP     =      2.4 : 1.0
#      ('to', 'Establish') = True             NONE : UP     =      2.4 : 1.0
# ('Products', 'Business') = True             NONE : UP     =      2.4 : 1.0
#    ('Majority', 'Stake') = True             NONE : UP     =      2.4 : 1.0
#           ('Oil', 'Gas') = True             NONE : UP     =      2.4 : 1.0
#  ('Completes', 'Tender') = True             NONE : UP     =      2.4 : 1.0
#           ('For', 'Two') = True             NONE : UP     =      2.4 : 1.0
#        ('Notes', '2012') = True             NONE : UP     =      2.4 : 1.0
#  ('Corporation', 'Sign') = True             NONE : UP     =      2.4 : 1.0
#           ('for', 'the') = True             NONE : UP     =      2.4 : 1.0
#    ('Life', 'Insurance') = True             NONE : UP     =      2.4 : 1.0
#    ('Declares', 'Third') = True             NONE : UP     =      2.4 : 1.0
#           ('Co', 'Form') = True             NONE : UP     =      2.4 : 1.0
#            ('Bid', 'To') = True             NONE : UP     =      2.4 : 1.0
#     ('Earnings', 'Call') = True             NONE : UP     =      2.4 : 1.0
#           ('Said', 'To') = True             NONE : UP     =      2.4 : 1.0
#            ('To', 'End') = True             NONE : UP     =      2.4 : 1.0
#         ('Air', 'Force') = True             NONE : UP     =      2.4 : 1.0
#          ('Chase', 'Co') = True             NONE : UP     =      2.4 : 1.0
# ('Health', 'Information') = True             NONE : UP     =      2.4 : 1.0
#      ('Billion', '2012') = True             NONE : UP     =      2.4 : 1.0
#        ('To', 'Enhance') = True             NONE : UP     =      2.4 : 1.0
# ('Collaboration', '2012') = True             NONE : UP     =      2.4 : 1.0
# ('Announces', 'Investigation') = True             NONE : UP     =      2.4 : 1.0
#  ('Raises', 'Quarterly') = True             NONE : UP     =      2.4 : 1.0
#    ('Klayman', 'Toskes') = True             NONE : UP     =      2.4 : 1.0
#              ('To', 'A') = True             DOWN : NONE   =      2.4 : 1.0
#      ('Price', 'Target') = True             DOWN : UP     =      2.4 : 1.0
#        ('Same', 'Store') = True             DOWN : UP     =      2.4 : 1.0
#  ('Finance', 'Holdings') = True             DOWN : UP     =      2.4 : 1.0
#          ('Sue', 'Bank') = True             DOWN : UP     =      2.4 : 1.0
#  ('Company', 'Receives') = True             DOWN : UP     =      2.4 : 1.0
#          ('of', 'China') = True             DOWN : UP     =      2.4 : 1.0
#     ('Woori', 'Finance') = True             DOWN : UP     =      2.4 : 1.0
#        ('Royal', 'Bank') = True             DOWN : UP     =      2.4 : 1.0
#        ('Repsol', 'YPF') = True             DOWN : UP     =      2.4 : 1.0
# ('Production', 'Comments') = True             DOWN : UP     =      2.4 : 1.0
#    ('Revenue', 'Lowers') = True             DOWN : UP     =      2.4 : 1.0
#     ('Reiterates', 'FY') = True             DOWN : UP     =      2.4 : 1.0
#       ('Assets', 'From') = True             DOWN : UP     =      2.4 : 1.0
# ('Complaint', 'Against') = True             NONE : DOWN   =      2.4 : 1.0
#         ('And', 'Chief') = True             NONE : DOWN   =      2.4 : 1.0
#        ('And', 'Pfizer') = True             NONE : DOWN   =      2.4 : 1.0
# ('Outsourcing', 'Agreement') = True             NONE : DOWN   =      2.4 : 1.0
#      ('Approval', 'for') = True             NONE : DOWN   =      2.4 : 1.0
#   ('Announces', 'Joint') = True             NONE : DOWN   =      2.4 : 1.0
#       ('The', 'Goldman') = True             NONE : DOWN   =      2.4 : 1.0
#          ('Board', 'Of') = True             NONE : DOWN   =      2.4 : 1.0
#       ('Develop', 'And') = True             NONE : DOWN   =      2.4 : 1.0
# ('Infringement', 'Lawsuit') = True             NONE : DOWN   =      2.4 : 1.0
#       ('Million', 'For') = True             NONE : DOWN   =      2.4 : 1.0
#         ('Eli', 'Lilly') = True             NONE : DOWN   =      2.4 : 1.0
#          ('Oil', '2012') = True             NONE : DOWN   =      2.4 : 1.0
#         ('Update', 'On') = True             NONE : DOWN   =      2.4 : 1.0
#        ('Energy', 'And') = True             NONE : DOWN   =      2.4 : 1.0
#         ('Lilly', 'and') = True             NONE : DOWN   =      2.4 : 1.0
#         ('Sued', 'Over') = True             NONE : DOWN   =      2.4 : 1.0
#      ('Inc', 'Receives') = True             NONE : DOWN   =      2.4 : 1.0
#     ('Mortgage', '2012') = True             NONE : DOWN   =      2.4 : 1.0
#        ('Sues', 'Banks') = True             NONE : DOWN   =      2.4 : 1.0
#    ('Energy', 'Limited') = True             NONE : DOWN   =      2.4 : 1.0
#      ('Of', 'Directors') = True             NONE : DOWN   =      2.4 : 1.0
#          ('to', 'Build') = True             NONE : DOWN   =      2.4 : 1.0
#        ('Sell', 'Stake') = True             NONE : DOWN   =      2.4 : 1.0
#          ('Plant', 'in') = True             NONE : DOWN   =      2.4 : 1.0
# ('Financial', 'Services') = True             NONE : DOWN   =      2.4 : 1.0
#      ('Service', '2012') = True             NONE : DOWN   =      2.4 : 1.0
#        ('Inc', 'Raises') = True             NONE : DOWN   =      2.4 : 1.0
# ('Of', 'Investigational') = True             NONE : DOWN   =      2.4 : 1.0
#   ('Agreements', 'With') = True             NONE : DOWN   =      2.4 : 1.0
#         ('News', '2011') = True             NONE : DOWN   =      2.4 : 1.0
#           ('to', '2012') = True             NONE : DOWN   =      2.4 : 1.0
#        ('To', 'Improve') = True             NONE : DOWN   =      2.4 : 1.0
#       ('Power', 'Plant') = True             NONE : DOWN   =      2.4 : 1.0
#      ('Trustee', 'Sues') = True             NONE : DOWN   =      2.4 : 1.0
#     ('Animal', 'Health') = True             NONE : DOWN   =      2.4 : 1.0
# ('Thornburg', 'Mortgage') = True             NONE : DOWN   =      2.4 : 1.0
#      ('Revenue', 'Call') = True             NONE : DOWN   =      2.4 : 1.0
#            ('Type', '2') = True             NONE : DOWN   =      2.4 : 1.0
# ('Announces', 'Proposed') = True             NONE : DOWN   =      2.4 : 1.0
#       ('Sells', 'Stake') = True             NONE : DOWN   =      2.4 : 1.0
# ('Bankruptcy', 'Trustee') = True             NONE : DOWN   =      2.4 : 1.0
# ('Mortgage', 'Bankruptcy') = True             NONE : DOWN   =      2.4 : 1.0
#    ('Receives', 'Order') = True             NONE : DOWN   =      2.4 : 1.0
#      ('NV', 'Announces') = True             NONE : DOWN   =      2.4 : 1.0
#      ('Lawsuit', 'Over') = True             NONE : DOWN   =      2.4 : 1.0
#      ('Outlook', '2011') = True             NONE : DOWN   =      2.4 : 1.0
#  ('Acquisition', '2011') = True             NONE : DOWN   =      2.4 : 1.0
#      ('Reuters', '2012') = True             NONE : DOWN   =      2.4 : 1.0
#  ('Company', 'Announce') = True             NONE : DOWN   =      2.4 : 1.0
# ('Executive', 'Officer') = True             NONE : DOWN   =      2.4 : 1.0
#          ('US', 'Court') = True             NONE : DOWN   =      2.4 : 1.0
#        ('In', 'Million') = True             NONE : DOWN   =      2.4 : 1.0
# ('Research', 'Collaboration') = True             NONE : DOWN   =      2.4 : 1.0
# ('Management', 'System') = True             NONE : DOWN   =      2.4 : 1.0
#         ('Issues', 'Q4') = True               UP : NONE   =      2.3 : 1.0
# ('European', 'Medicines') = True             DOWN : NONE   =      2.3 : 1.0
#       ('Company', 'For') = True             DOWN : NONE   =      2.3 : 1.0
#         ('To', 'Retire') = True             DOWN : NONE   =      2.3 : 1.0
#     ('Mortgage', '2011') = True             DOWN : NONE   =      2.3 : 1.0
#              ('Of', 'A') = True             DOWN : NONE   =      2.3 : 1.0
#        ('Story', '2011') = True             DOWN : NONE   =      2.3 : 1.0
#      ('Services', 'For') = True             DOWN : NONE   =      2.3 : 1.0
#       ('For', 'Million') = True             NONE : UP     =      2.3 : 1.0
#          ('New', 'Drug') = True             NONE : UP     =      2.3 : 1.0
#        ('Limited', 'To') = True             NONE : UP     =      2.3 : 1.0
#      ('Limited', '2012') = True             NONE : UP     =      2.3 : 1.0
#       ('Approval', 'To') = True             NONE : UP     =      2.3 : 1.0
#            ('Of', 'Per') = True             NONE : UP     =      2.3 : 1.0
#       ('Lung', 'Cancer') = True             NONE : UP     =      2.3 : 1.0
# ('Licensing', 'Agreement') = True             NONE : UP     =      2.3 : 1.0
#         ('LLP', 'Files') = True             NONE : UP     =      2.3 : 1.0
#      ('America', '2011') = True               UP : DOWN   =      2.3 : 1.0
#      ('Court', 'Ruling') = True               UP : DOWN   =      2.3 : 1.0
#           ('To', 'Form') = True               UP : DOWN   =      2.3 : 1.0
#    ('Declares', 'First') = True               UP : DOWN   =      2.3 : 1.0
#      ('Trading', '2011') = True               UP : DOWN   =      2.3 : 1.0
# ('Services', 'Agreement') = True               UP : DOWN   =      2.3 : 1.0
# ('Announce', 'Collaboration') = True               UP : DOWN   =      2.3 : 1.0
#           ('Co', 'Sues') = True               UP : DOWN   =      2.3 : 1.0
#       ('To', 'Purchase') = True               UP : DOWN   =      2.3 : 1.0
#    ('Prices', 'Billion') = True               UP : DOWN   =      2.3 : 1.0
#          ('Group', 'AG') = True               UP : DOWN   =      2.3 : 1.0
#          ('Inc', 'Over') = True               UP : DOWN   =      2.3 : 1.0
#      ('Suisse', 'Group') = True               UP : DOWN   =      2.3 : 1.0
# ('International', 'Raises') = True               UP : DOWN   =      2.3 : 1.0
#   ('Company', 'Invests') = True               UP : DOWN   =      2.3 : 1.0
#      ('Solution', 'For') = True               UP : DOWN   =      2.3 : 1.0
#       ('With', 'Lowers') = True               UP : DOWN   =      2.3 : 1.0
# ('International', '2011') = True               UP : DOWN   =      2.3 : 1.0
#      ('Extension', 'Of') = True               UP : DOWN   =      2.3 : 1.0
# ('America', 'Corporation') = True               UP : DOWN   =      2.3 : 1.0
#             ('On', 'H2') = True             DOWN : UP     =      2.3 : 1.0
#     ('EPS', 'Reaffirms') = True             DOWN : UP     =      2.3 : 1.0
# ('International', 'Issues') = True               UP : NONE   =      2.2 : 1.0
# ('Corporation', 'Limited') = True               UP : NONE   =      2.2 : 1.0
#       ('Be', 'Acquired') = True               UP : NONE   =      2.2 : 1.0
#      ('Corp', 'Secures') = True               UP : NONE   =      2.2 : 1.0
#          ('May', 'Sell') = True               UP : NONE   =      2.2 : 1.0
# ('Collaboration', 'Agreement') = True               UP : NONE   =      2.2 : 1.0
# ('Announces', 'Preliminary') = True               UP : NONE   =      2.2 : 1.0
#     ('LLP', 'Announces') = True             NONE : UP     =      2.2 : 1.0
#        ('Million', 'In') = True             NONE : UP     =      2.2 : 1.0
#        ('to', 'Acquire') = True             NONE : UP     =      2.2 : 1.0
#       ('Enters', 'Into') = True             NONE : UP     =      2.2 : 1.0
#           ('Unit', 'Of') = True             NONE : DOWN   =      2.2 : 1.0
#           ('For', 'New') = True             NONE : DOWN   =      2.2 : 1.0
#   ('Secures', 'Million') = True             NONE : DOWN   =      2.2 : 1.0
#        ('of', 'America') = True             NONE : DOWN   =      2.2 : 1.0
#     ('Contract', 'With') = True             NONE : DOWN   =      2.2 : 1.0
#         ('Inc', 'Signs') = True             NONE : DOWN   =      2.2 : 1.0
#          ('In', 'China') = True             NONE : UP     =      2.2 : 1.0
#         ('Group', 'Inc') = True             NONE : UP     =      2.2 : 1.0
#       ('Company', 'And') = True             NONE : UP     =      2.2 : 1.0
#           ('For', 'The') = True             NONE : DOWN   =      2.2 : 1.0
#       ('Dividend', 'Of') = True             NONE : DOWN   =      2.2 : 1.0
#    ('Agreement', '2011') = True             NONE : DOWN   =      2.2 : 1.0
# ('Dividend', 'Increase') = True             NONE : DOWN   =      2.2 : 1.0
#        ('Company', 'To') = True             DOWN : UP     =      2.2 : 1.0
# ('Company', 'Reaffirms') = True               UP : DOWN   =      2.1 : 1.0
#         ('Per', 'Share') = True             NONE : DOWN   =      2.1 : 1.0
#     ('And', 'Announces') = True               UP : NONE   =      2.1 : 1.0
#        ('To', 'Acquire') = True             NONE : UP     =      2.1 : 1.0
#           ('Inc', 'And') = True             NONE : DOWN   =      2.1 : 1.0
#        ('Raises', 'Low') = True               UP : DOWN   =      2.1 : 1.0
#     ('Dividend', '2012') = True             NONE : DOWN   =      2.0 : 1.0
#            ('Co', 'And') = True             NONE : UP     =      2.0 : 1.0
#     ('Third', 'Quarter') = True             NONE : UP     =      2.0 : 1.0
#  ('Corporation', '2011') = True             NONE : DOWN   =      1.9 : 1.0
#     ('Contract', 'From') = True             DOWN : UP     =      1.9 : 1.0
#     ('Agreement', 'For') = True             NONE : DOWN   =      1.9 : 1.0
#  ('Declares', 'Regular') = True             NONE : DOWN   =      1.9 : 1.0
#        ('Share', '2011') = True             NONE : UP     =      1.9 : 1.0
#      ('Treatment', 'Of') = True             NONE : UP     =      1.9 : 1.0
#    ('To', 'Collaborate') = True             NONE : UP     =      1.9 : 1.0
#      ('Contract', 'For') = True             NONE : UP     =      1.9 : 1.0
#     ('Business', '2012') = True             NONE : UP     =      1.9 : 1.0
#   ('Corporation', 'And') = True             NONE : DOWN   =      1.9 : 1.0
# ('Announces', 'Increase') = True             DOWN : UP     =      1.9 : 1.0
#           ('A', 'Range') = True             DOWN : NONE   =      1.9 : 1.0
#     ('Hagens', 'Berman') = True             NONE : DOWN   =      1.9 : 1.0
#            ('Inc', 'to') = True             NONE : DOWN   =      1.9 : 1.0
#     ('United', 'States') = True             NONE : DOWN   =      1.9 : 1.0
#           ('Inc', 'and') = True             NONE : DOWN   =      1.9 : 1.0
#     ('Dividend', '2012') = None             DOWN : NONE   =      1.9 : 1.0
#    ('Claims', 'Against') = True             NONE : UP     =      1.9 : 1.0
#       ('Electric', 'Co') = True             NONE : UP     =      1.9 : 1.0
#     ('Standard', '2011') = True             NONE : UP     =      1.9 : 1.0
#     ('To', 'Accelerate') = True             NONE : UP     =      1.9 : 1.0
#      ('Agreement', 'to') = True             NONE : UP     =      1.9 : 1.0
# ('Corporation', 'Signs') = True             NONE : UP     =      1.9 : 1.0
#            ('SA', 'and') = True             NONE : UP     =      1.9 : 1.0
#    ('Acquires', 'Stake') = True             NONE : UP     =      1.9 : 1.0
#  ('Positive', 'Results') = True             NONE : UP     =      1.9 : 1.0
#  ('Drug', 'Application') = True             NONE : UP     =      1.9 : 1.0
#        ('Plant', '2011') = True             NONE : UP     =      1.9 : 1.0
# ('Announces', 'Partnership') = True             NONE : UP     =      1.9 : 1.0
#    ('Dividends', '2011') = True             NONE : UP     =      1.9 : 1.0
#       ('System', '2011') = True             NONE : UP     =      1.9 : 1.0
#   ('Declares', 'Fourth') = True             NONE : UP     =      1.9 : 1.0
#     ('Files', 'Lawsuit') = True             NONE : UP     =      1.9 : 1.0
#         ('And', 'Other') = True             NONE : UP     =      1.9 : 1.0
#       ('Lowers', 'High') = True             DOWN : UP     =      1.8 : 1.0
#          ('EPS', 'Call') = True               UP : NONE   =      1.8 : 1.0
# ('Regular', 'Quarterly') = True             NONE : DOWN   =      1.8 : 1.0
#     ('First', 'Quarter') = True             NONE : DOWN   =      1.8 : 1.0
#         ('EU', 'Clears') = True             NONE : DOWN   =      1.8 : 1.0
#    ('Electric', 'Power') = True             NONE : DOWN   =      1.8 : 1.0
#          ('OTC', '2012') = True             NONE : DOWN   =      1.8 : 1.0
# ('For', 'Investigational') = True             NONE : DOWN   =      1.8 : 1.0
#     ('Services', '2012') = True             NONE : DOWN   =      1.8 : 1.0
#            ('To', 'Per') = True             NONE : DOWN   =      1.8 : 1.0
#     ('Goldman', 'Sachs') = True             NONE : DOWN   =      1.8 : 1.0
# ('Approves', 'Quarterly') = True             NONE : DOWN   =      1.8 : 1.0
# ('Rohrback', 'Announces') = True             NONE : DOWN   =      1.8 : 1.0
#   ('Keller', 'Rohrback') = True             NONE : DOWN   =      1.8 : 1.0
# ('Increases', 'Quarterly') = True             NONE : DOWN   =      1.8 : 1.0
#         ('To', 'Supply') = True             NONE : DOWN   =      1.8 : 1.0
#           ('to', 'Sell') = True               UP : DOWN   =      1.8 : 1.0
#    ('Agreement', 'With') = True             NONE : DOWN   =      1.8 : 1.0
# ('Announces', 'Dividend') = True             NONE : UP     =      1.8 : 1.0
#     ('Billion', 'Share') = True               UP : NONE   =      1.8 : 1.0
#        ('Revises', 'FY') = True             DOWN : NONE   =      1.8 : 1.0
#       ('Dividend', 'On') = True             DOWN : NONE   =      1.8 : 1.0
# ('American', 'International') = True             DOWN : NONE   =      1.8 : 1.0
#    ('Revenue', 'Issues') = True             DOWN : NONE   =      1.8 : 1.0
#      ('Below', 'Lowers') = True             DOWN : NONE   =      1.8 : 1.0
#   ('Settlement', 'With') = True               UP : DOWN   =      1.8 : 1.0
#       ('Business', 'To') = True               UP : DOWN   =      1.8 : 1.0
# ('Company', 'Completes') = True               UP : DOWN   =      1.8 : 1.0
#     ('With', 'Comments') = True               UP : DOWN   =      1.8 : 1.0
#    ('Sales', 'Guidance') = True               UP : DOWN   =      1.8 : 1.0
# ('Announces', 'Billion') = True               UP : DOWN   =      1.8 : 1.0
#      ('Company', '2011') = True             NONE : DOWN   =      1.8 : 1.0
#            ('Co', 'Ltd') = True             NONE : UP     =      1.7 : 1.0
# ('Announces', 'Signing') = True             NONE : UP     =      1.7 : 1.0
#         ('From', '2012') = True             NONE : UP     =      1.7 : 1.0
#       ('Czechia', 'and') = True             NONE : UP     =      1.7 : 1.0
#         ('Deal', '2011') = True             NONE : UP     =      1.7 : 1.0
#       ('Plants', '2012') = True             NONE : UP     =      1.7 : 1.0
#         ('Likely', 'To') = True             NONE : UP     =      1.7 : 1.0
#     ('Analysis', '2012') = True             NONE : UP     =      1.7 : 1.0
#       ('Exxon', 'Mobil') = True             NONE : UP     =      1.7 : 1.0
#           ('To', 'Exit') = True             NONE : UP     =      1.7 : 1.0
#      ('Officers', 'And') = True             NONE : UP     =      1.7 : 1.0
#        ('Stock', '2010') = True             NONE : UP     =      1.7 : 1.0
#            ('Use', 'In') = True             NONE : UP     =      1.7 : 1.0
#     ('Philip', 'Morris') = True             NONE : UP     =      1.7 : 1.0
#         ('Stock', 'And') = True             NONE : UP     =      1.7 : 1.0
#            ('to', 'Buy') = True             NONE : UP     =      1.7 : 1.0
#       ('The', 'Company') = True             NONE : UP     =      1.7 : 1.0
#      ('America', '2012') = True             NONE : UP     =      1.7 : 1.0
#     ('Latin', 'America') = True             NONE : UP     =      1.7 : 1.0
#    ('Million', 'Shares') = True             NONE : UP     =      1.7 : 1.0
#       ('Royal', 'Dutch') = True             NONE : UP     =      1.7 : 1.0
#           ('LLC', 'And') = True             NONE : UP     =      1.7 : 1.0
#      ('And', 'Deutsche') = True             NONE : UP     =      1.7 : 1.0
#         ('To', 'Divest') = True             NONE : UP     =      1.7 : 1.0
#     ('Declares', '2012') = True             NONE : UP     =      1.7 : 1.0
# ('Authorization', 'For') = True             NONE : UP     =      1.7 : 1.0
#      ('CVS', 'Caremark') = True             NONE : UP     =      1.7 : 1.0
#         ('Risk', '2011') = True             NONE : UP     =      1.7 : 1.0
#           ('To', 'Open') = True             NONE : UP     =      1.7 : 1.0
#           ('and', 'The') = True             NONE : UP     =      1.7 : 1.0
#     ('Production', 'In') = True             NONE : UP     =      1.7 : 1.0
#    ('Million', 'Credit') = True             NONE : UP     =      1.7 : 1.0
#  ('Commences', 'Tender') = True             NONE : UP     =      1.7 : 1.0
#   ('America', 'Merrill') = True             NONE : UP     =      1.7 : 1.0
#       ('And', 'Company') = True             NONE : UP     =      1.7 : 1.0
#   ('Offering', 'Period') = True             NONE : UP     =      1.7 : 1.0
#         ('North', 'Sea') = True             NONE : UP     =      1.7 : 1.0
#     ('President', 'And') = True             NONE : UP     =      1.7 : 1.0
#   ('Company', 'Recalls') = True             NONE : UP     =      1.7 : 1.0
#  ('Partnership', 'with') = True             NONE : UP     =      1.7 : 1.0
# ('Settlement', 'Agreement') = True             NONE : UP     =      1.7 : 1.0
# ('UnitedHealth', 'Group') = True             NONE : UP     =      1.7 : 1.0
#          ('Plant', 'In') = True             NONE : UP     =      1.7 : 1.0
#  ('Development', '2011') = True             NONE : UP     =      1.7 : 1.0
#       ('Confirms', 'FY') = True             NONE : UP     =      1.7 : 1.0
#          ('Stock', 'to') = True             NONE : UP     =      1.7 : 1.0
#       ('Electric', 'GE') = True             NONE : UP     =      1.7 : 1.0
#         ('Build', 'New') = True             NONE : UP     =      1.7 : 1.0
#       ('From', 'Plants') = True             NONE : UP     =      1.7 : 1.0
#        ('To', 'Dismiss') = True             NONE : UP     =      1.7 : 1.0
#        ('With', 'Merck') = True             NONE : UP     =      1.7 : 1.0
#        ('Cloud', '2011') = True             NONE : UP     =      1.7 : 1.0
#          ('Agree', 'To') = True             NONE : UP     =      1.7 : 1.0
# ('Scientific', 'Boston') = True             NONE : UP     =      1.7 : 1.0
#          ('Bayer', 'AG') = True             NONE : UP     =      1.7 : 1.0
#            ('In', 'New') = True             NONE : UP     =      1.7 : 1.0
#     ('Increase', '2011') = True             NONE : UP     =      1.7 : 1.0
# ('Amylin', 'Pharmaceuticals') = True             NONE : UP     =      1.7 : 1.0
#      ('Agreement', 'On') = True             NONE : UP     =      1.7 : 1.0
#      ('Program', '2010') = True             NONE : UP     =      1.7 : 1.0
# ('Research', 'Subsidiary') = True             NONE : UP     =      1.7 : 1.0
# ('Announces', 'Million') = True             NONE : UP     =      1.7 : 1.0
#             ('de', 'CV') = True             NONE : UP     =      1.7 : 1.0
#       ('Assets', '2011') = True             NONE : UP     =      1.7 : 1.0
#         ('Trial', 'For') = True             NONE : UP     =      1.7 : 1.0
#     ('Property', '2011') = True             NONE : UP     =      1.7 : 1.0
#    ('Its', 'Affiliates') = True             NONE : UP     =      1.7 : 1.0
#         ('in', 'France') = True             NONE : UP     =      1.7 : 1.0
#  ('Squibb', 'Announces') = True             NONE : UP     =      1.7 : 1.0
#            ('SAB', 'de') = True             NONE : UP     =      1.7 : 1.0
#     ('Alliance', '2011') = True             NONE : UP     =      1.7 : 1.0
#       ('Dividend', 'on') = True             NONE : UP     =      1.7 : 1.0
#       ('Credit', 'Card') = True             NONE : UP     =      1.7 : 1.0
#     ('Solutions', 'And') = True             NONE : UP     =      1.7 : 1.0
#   ('EMC', 'Corporation') = True             NONE : UP     =      1.7 : 1.0
#    ('Parcel', 'Service') = True             NONE : UP     =      1.7 : 1.0
#        ('Factory', 'In') = True             NONE : UP     =      1.7 : 1.0
#       ('Motor', 'Heinz') = True             NONE : UP     =      1.7 : 1.0
#            ('BP', 'PLC') = True             NONE : UP     =      1.7 : 1.0
# ('Abbott', 'Laboratories') = True             NONE : UP     =      1.7 : 1.0
#      ('Approval', 'For') = True             NONE : UP     =      1.7 : 1.0
#     ('Made', 'Entirely') = True             NONE : UP     =      1.7 : 1.0
#        ('Project', 'In') = True             NONE : UP     =      1.7 : 1.0
# ('FedEx', 'Corporation') = True             NONE : UP     =      1.7 : 1.0
#     ('With', 'Advanced') = True             NONE : UP     =      1.7 : 1.0
#        ('Others', 'Win') = True             NONE : UP     =      1.7 : 1.0
#       ('in', 'Patients') = True             NONE : UP     =      1.7 : 1.0
#     ('Dividend', 'Rate') = True             NONE : UP     =      1.7 : 1.0
#           ('In', '2011') = True             NONE : UP     =      1.7 : 1.0
# ('Investigational', 'Compound') = True             NONE : UP     =      1.7 : 1.0
#     ('Offering', '2012') = True             NONE : UP     =      1.7 : 1.0
#           ('And', 'Air') = True             NONE : UP     =      1.7 : 1.0
#      ('Goldberg', 'LLP') = True             NONE : UP     =      1.7 : 1.0
# ...
#     ('Products', 'Made') = True             NONE : UP     =      1.7 : 1.0
#       ('Kraft', 'Foods') = True             NONE : UP     =      1.7 : 1.0
#     ('Entirely', 'From') = True             NONE : UP     =      1.7 : 1.0
#       ('Dividend', 'To') = True               UP : NONE   =      1.7 : 1.0
# ('Company', 'Increases') = True               UP : NONE   =      1.7 : 1.0
#     ('Holdings', '2011') = True             DOWN : UP     =      1.7 : 1.0
#        ('Trial', '2011') = True             DOWN : UP     =      1.7 : 1.0
#            ('BP', 'plc') = True             DOWN : UP     =      1.7 : 1.0
#          ('To', 'Merge') = True             DOWN : UP     =      1.7 : 1.0
#        ('For', 'Fourth') = True             DOWN : UP     =      1.7 : 1.0
#     ('General', 'Files') = True             DOWN : UP     =      1.7 : 1.0
#     ('Heart', 'Failure') = True             DOWN : UP     =      1.7 : 1.0
#     ('Platform', '2011') = True             DOWN : UP     =      1.7 : 1.0
# ('Earnings', 'Guidance') = True             DOWN : UP     =      1.7 : 1.0
#          ('Probe', 'Of') = True             DOWN : UP     =      1.7 : 1.0
#      ('ELIQUIS', '2012') = True             DOWN : UP     =      1.7 : 1.0
#         ('In', 'Russia') = True             DOWN : UP     =      1.7 : 1.0
#         ('Letter', 'Of') = True             DOWN : UP     =      1.7 : 1.0
# ('Announces', 'Management') = True             DOWN : UP     =      1.7 : 1.0
#      ('Servicing', 'To') = True             DOWN : UP     =      1.7 : 1.0
#    ('Clinical', 'Trial') = True             DOWN : UP     =      1.7 : 1.0
#         ('In', 'Patent') = True             DOWN : UP     =      1.7 : 1.0
#         ('Of', 'Intent') = True             DOWN : UP     =      1.7 : 1.0
#       ('Range', 'Above') = True             DOWN : UP     =      1.7 : 1.0
#     ('As', 'Depositary') = True             DOWN : UP     =      1.7 : 1.0
#        ('Reports', 'on') = True             DOWN : UP     =      1.7 : 1.0
#        ('Trial', 'with') = True             DOWN : UP     =      1.7 : 1.0
#         ('Chase', 'And') = True             DOWN : UP     =      1.7 : 1.0
#           ('To', 'Meet') = True             DOWN : UP     =      1.7 : 1.0
# ('Technologies', '2011') = True             DOWN : UP     =      1.7 : 1.0
# ('Declares', 'Dividends') = True             DOWN : UP     =      1.7 : 1.0
# ('Expanded', 'Indication') = True             DOWN : UP     =      1.7 : 1.0
# ('Shareholders', '2012') = True             DOWN : UP     =      1.7 : 1.0
# ('Prudential', 'Financial') = True             DOWN : UP     =      1.7 : 1.0
#             ('On', 'Q1') = True             DOWN : UP     =      1.7 : 1.0
#         ('Order', 'For') = True             DOWN : UP     =      1.7 : 1.0
#            ('And', 'GE') = True             DOWN : UP     =      1.7 : 1.0
# ('Business', 'Machines') = True             DOWN : UP     =      1.7 : 1.0
#           ('To', 'Work') = True             DOWN : UP     =      1.7 : 1.0
# ('Distribution', 'Business') = True             DOWN : UP     =      1.7 : 1.0
#   ('Increases', 'Stake') = True             DOWN : UP     =      1.7 : 1.0
#        ('of', 'Justice') = True             DOWN : UP     =      1.7 : 1.0
#         ('To', 'Appeal') = True             DOWN : UP     =      1.7 : 1.0
#       ('Ministry', 'of') = True             DOWN : UP     =      1.7 : 1.0
#        ('Other', '2011') = True             DOWN : UP     =      1.7 : 1.0
#     ('Financing', 'For') = True             DOWN : UP     =      1.7 : 1.0
#      ('Outlook', '2012') = True             DOWN : UP     =      1.7 : 1.0
#         ('Agent', 'For') = True             DOWN : UP     =      1.7 : 1.0
#   ('Credit', 'Facility') = True             DOWN : UP     =      1.7 : 1.0
#            ('To', 'The') = True             DOWN : UP     =      1.7 : 1.0
# ('Massachusetts', 'Attorney') = True             DOWN : UP     =      1.7 : 1.0
#          ('Job', '2011') = True             DOWN : UP     =      1.7 : 1.0
#       ('II', 'Clinical') = True             DOWN : UP     =      1.7 : 1.0
#        ('In', 'Western') = True             DOWN : UP     =      1.7 : 1.0
#    ('Announce', 'Joint') = True             DOWN : UP     =      1.7 : 1.0
#   ('Comparable', 'Same') = True             DOWN : UP     =      1.7 : 1.0
#    ('Petroleum', '2012') = True             DOWN : UP     =      1.7 : 1.0
#       ('of', 'Scotland') = True             DOWN : UP     =      1.7 : 1.0
#        ('Quality', 'Of') = True             DOWN : UP     =      1.7 : 1.0
# ('Relationship', 'With') = True             DOWN : UP     =      1.7 : 1.0
#  ('National', 'Oilwell') = True             DOWN : UP     =      1.7 : 1.0
# ('Revenue', 'Reaffirms') = True             DOWN : UP     =      1.7 : 1.0
#   ('Businesses', '2011') = True             DOWN : UP     =      1.7 : 1.0
# ('International', 'Business') = True             DOWN : UP     =      1.7 : 1.0
#           ('FY', '2014') = True             DOWN : UP     =      1.7 : 1.0
#          ('Term', 'EPS') = True             DOWN : UP     =      1.7 : 1.0
#  ('Company', 'Provides') = True             DOWN : UP     =      1.7 : 1.0
# ('Corporation', 'Lowers') = True             DOWN : UP     =      1.7 : 1.0
#  ('Clinical', 'Studies') = True             NONE : DOWN   =      1.7 : 1.0
#    ('Signs', 'Contract') = True             NONE : DOWN   =      1.7 : 1.0
#       ('Europe', '2011') = True             NONE : DOWN   =      1.7 : 1.0
#       ('Energy', '2012') = True             NONE : DOWN   =      1.7 : 1.0
#     ('Million', 'Share') = True             NONE : DOWN   =      1.7 : 1.0
#          ('Offer', 'to') = True             NONE : DOWN   =      1.7 : 1.0
#          ('Bids', 'For') = True             NONE : DOWN   =      1.7 : 1.0
#       ('Change', '2012') = True             NONE : DOWN   =      1.7 : 1.0
#       ('Other', 'Large') = True             NONE : DOWN   =      1.7 : 1.0
#       ('States', '2012') = True             NONE : DOWN   =      1.7 : 1.0
#     ('Fund', 'Services') = True             NONE : DOWN   =      1.7 : 1.0
#        ('Corp', 'Signs') = True             NONE : DOWN   =      1.7 : 1.0
#    ('Be', 'Substantial') = True             NONE : DOWN   =      1.7 : 1.0
#           ('Low', 'End') = True             NONE : DOWN   =      1.7 : 1.0
#       ('Mexico', '2011') = True             NONE : DOWN   =      1.7 : 1.0
#        ('The', 'United') = True             NONE : DOWN   =      1.7 : 1.0
# ('International', 'And') = True             NONE : DOWN   =      1.7 : 1.0
#         ('Rules', 'Out') = True             NONE : DOWN   =      1.7 : 1.0
#        ('Company', 'In') = True             NONE : DOWN   =      1.7 : 1.0
#    ('Sachs', 'JPMorgan') = True             NONE : DOWN   =      1.7 : 1.0
# ('From', 'Schlumberger') = True             NONE : DOWN   =      1.7 : 1.0
#     ('Sprint', 'Nextel') = True             NONE : DOWN   =      1.7 : 1.0
#         ('Assets', 'To') = True             NONE : DOWN   =      1.7 : 1.0
#        ('Fitch', 'Cuts') = True             NONE : DOWN   =      1.7 : 1.0
#      ('Services', 'for') = True             NONE : DOWN   =      1.7 : 1.0
#          ('To', 'Power') = True             NONE : DOWN   =      1.7 : 1.0
#         ('Case', '2011') = True             NONE : DOWN   =      1.7 : 1.0
#          ('Sell', 'Its') = True             NONE : DOWN   =      1.7 : 1.0
#         ('Assets', 'In') = True             NONE : DOWN   =      1.7 : 1.0
#        ('For', 'Global') = True             NONE : DOWN   =      1.7 : 1.0
# ('Marketing', 'Authorization') = True             NONE : DOWN   =      1.7 : 1.0
#      ('Card', 'Program') = True             NONE : DOWN   =      1.7 : 1.0
#      ('Plc', 'Receives') = True             NONE : DOWN   =      1.7 : 1.0
#    ('Board', 'Approves') = True             NONE : DOWN   =      1.7 : 1.0
# ('Capital', 'Management') = True             NONE : DOWN   =      1.7 : 1.0
#       ('Services', 'to') = True             NONE : DOWN   =      1.7 : 1.0
#      ('FHA', 'Mortgage') = True             NONE : DOWN   =      1.7 : 1.0
#          ('Of', 'Third') = True             NONE : DOWN   =      1.7 : 1.0
#    ('Artery', 'Disease') = True             NONE : DOWN   =      1.7 : 1.0
#      ('For', 'Business') = True             NONE : DOWN   =      1.7 : 1.0
#          ('Sued', 'For') = True             NONE : DOWN   =      1.7 : 1.0
#       ('Increase', 'Of') = True             NONE : DOWN   =      1.7 : 1.0
# ('Collaboration', 'For') = True             NONE : DOWN   =      1.7 : 1.0
#    ('Submission', 'For') = True             NONE : DOWN   =      1.7 : 1.0
#   ('Subsidiary', '2012') = True             NONE : DOWN   =      1.7 : 1.0
#      ('Agreement', 'In') = True             NONE : DOWN   =      1.7 : 1.0
#     ('Resources', 'Ltd') = True             NONE : DOWN   =      1.7 : 1.0
#       ('Corp', 'Raises') = True             NONE : DOWN   =      1.7 : 1.0
#            ('Set', 'To') = True             NONE : DOWN   =      1.7 : 1.0
#         ('Farm', '2011') = True             NONE : DOWN   =      1.7 : 1.0
#         ('and', 'Other') = True             NONE : DOWN   =      1.7 : 1.0
#       ('Co', 'Receives') = True             NONE : DOWN   =      1.7 : 1.0
#      ('To', 'Transform') = True             NONE : DOWN   =      1.7 : 1.0
#       ('In', 'Dividend') = True             NONE : DOWN   =      1.7 : 1.0
#  ('Laboratories', 'And') = True             NONE : DOWN   =      1.7 : 1.0
#     ('Regarding', 'FHA') = True             NONE : DOWN   =      1.7 : 1.0
#            ('A', 'Unit') = True             NONE : DOWN   =      1.7 : 1.0
#         ('Access', 'To') = True             NONE : DOWN   =      1.7 : 1.0
#         ('Gamble', 'Co') = True             NONE : DOWN   =      1.7 : 1.0
#   ('Litigation', '2012') = True             NONE : DOWN   =      1.7 : 1.0
# ('Partnership', 'Agreement') = True             NONE : DOWN   =      1.7 : 1.0
# ('Strategic', 'Agreement') = True             NONE : DOWN   =      1.7 : 1.0
#        ('Times', '2011') = True             NONE : DOWN   =      1.7 : 1.0
# ('Announces', 'Purchase') = True             NONE : DOWN   =      1.7 : 1.0
#          ('Co', 'Signs') = True             NONE : DOWN   =      1.7 : 1.0
# ('Administration', 'And') = True             NONE : DOWN   =      1.7 : 1.0
# ('Lenders', 'Regarding') = True             NONE : DOWN   =      1.7 : 1.0
# ('Subsidiaries', '2012') = True             NONE : DOWN   =      1.7 : 1.0
#       ('Large', 'Banks') = True             NONE : DOWN   =      1.7 : 1.0
#      ('Approves', 'New') = True             NONE : DOWN   =      1.7 : 1.0
#     ('Inc', 'Increases') = True             NONE : DOWN   =      1.7 : 1.0
#          ('In', 'Favor') = True             NONE : DOWN   =      1.7 : 1.0
#     ('Of', 'California') = True             NONE : DOWN   =      1.7 : 1.0
# ('Management', 'Business') = True             NONE : DOWN   =      1.7 : 1.0
#  ('Primary', 'Endpoint') = True             NONE : DOWN   =      1.7 : 1.0
#      ('Systems', '2011') = True             NONE : DOWN   =      1.7 : 1.0
#     ('Diabetes', '2012') = True             NONE : DOWN   =      1.7 : 1.0
# ('Collaborates', 'With') = True             NONE : DOWN   =      1.7 : 1.0
#   ('Industry', 'Report') = True             NONE : DOWN   =      1.7 : 1.0
#  ('Electric', 'Company') = True             NONE : DOWN   =      1.7 : 1.0
#         ('Year', '2012') = True             NONE : DOWN   =      1.7 : 1.0
#     ('Government', 'of') = True             NONE : DOWN   =      1.7 : 1.0
#  ('Citigroup', 'Global') = True             NONE : DOWN   =      1.7 : 1.0
#         ('Of', 'Mexico') = True             NONE : DOWN   =      1.7 : 1.0
#         ('Wind', 'Farm') = True             NONE : DOWN   =      1.7 : 1.0
#       ('Develop', 'New') = True             NONE : DOWN   =      1.7 : 1.0
#        ('Funds', '2011') = True             NONE : DOWN   =      1.7 : 1.0
#         ('Two', 'Phase') = True             NONE : DOWN   =      1.7 : 1.0
#        ('Pfizer', 'Inc') = True             NONE : DOWN   =      1.7 : 1.0
# ('Schlumberger', 'Limited') = True             NONE : DOWN   =      1.7 : 1.0
#   ('Relationship', 'To') = True             NONE : DOWN   =      1.7 : 1.0
#      ('Capital', '2012') = True             NONE : DOWN   =      1.7 : 1.0
#    ('Initiate', 'Phase') = True             NONE : DOWN   =      1.7 : 1.0
# ('Corporation', 'Declares') = True             NONE : DOWN   =      1.7 : 1.0
#       ('And', 'Support') = True             NONE : DOWN   =      1.7 : 1.0
#  ('Issues', 'Statement') = True             NONE : DOWN   =      1.7 : 1.0
#    ('Boeing', 'Company') = True             NONE : DOWN   =      1.7 : 1.0
#   ('AstraZeneca', 'PLC') = True             NONE : DOWN   =      1.7 : 1.0
#         ('of', 'Common') = True             NONE : DOWN   =      1.7 : 1.0
#         ('and', 'Chief') = True             NONE : DOWN   =      1.7 : 1.0
#         ('Year', '2011') = True             NONE : DOWN   =      1.7 : 1.0
#        ('Venture', 'In') = True             NONE : DOWN   =      1.7 : 1.0
#           ('Inc', 'For') = True             NONE : DOWN   =      1.7 : 1.0
#   ('Annual', 'Dividend') = True             NONE : DOWN   =      1.7 : 1.0
#        ('Texas', '2011') = True             NONE : DOWN   =      1.7 : 1.0
#  ('Company', 'Approves') = True             NONE : DOWN   =      1.7 : 1.0
#         ('Bank', '2011') = True             NONE : DOWN   =      1.7 : 1.0
#      ('As', 'Successor') = True             NONE : DOWN   =      1.7 : 1.0
#  ('Biosense', 'Webster') = True             NONE : DOWN   =      1.7 : 1.0
#    ('Portfolio', 'With') = True             NONE : DOWN   =      1.7 : 1.0
#         ('Group', 'Plc') = True             NONE : DOWN   =      1.7 : 1.0
#       ('Monsanto', 'Co') = True             NONE : DOWN   =      1.7 : 1.0
#   ('Chase', 'Regarding') = True             NONE : DOWN   =      1.7 : 1.0
#          ('Favor', 'Of') = True             NONE : DOWN   =      1.7 : 1.0
#           ('To', 'Bank') = True             NONE : DOWN   =      1.7 : 1.0
#      ('Officer', '2011') = True             NONE : DOWN   =      1.7 : 1.0
#     ('Withdrawal', 'Of') = True             NONE : DOWN   =      1.7 : 1.0
#          ('Plant', 'To') = True             NONE : DOWN   =      1.7 : 1.0
#  ('Services', 'Secures') = True             NONE : DOWN   =      1.7 : 1.0
# ('International', '2012') = True             NONE : DOWN   =      1.7 : 1.0
#         ('OAO', 'Signs') = True             NONE : DOWN   =      1.7 : 1.0
# ('Information', 'Technology') = True             NONE : DOWN   =      1.7 : 1.0
#           ('of', 'Bank') = True             NONE : DOWN   =      1.7 : 1.0
#  ('To', 'Commercialize') = True             NONE : DOWN   =      1.7 : 1.0
#  ('Regular', 'Dividend') = True             NONE : DOWN   =      1.7 : 1.0
#     ('Roche', 'Holding') = True             NONE : DOWN   =      1.7 : 1.0
#        ('Inc', 'Enters') = True             NONE : DOWN   =      1.7 : 1.0
#     ('Slovakia', '2011') = True             NONE : DOWN   =      1.7 : 1.0
#       ('Shares', '2012') = True             NONE : DOWN   =      1.7 : 1.0
#            ('UK', 'Oil') = True             NONE : DOWN   =      1.7 : 1.0
#         ('Of', 'Equity') = True             NONE : DOWN   =      1.7 : 1.0
#           ('For', 'All') = True             NONE : DOWN   =      1.7 : 1.0
#   ('Jefferies', 'Group') = True             NONE : DOWN   =      1.7 : 1.0
#     ('Technology', 'To') = True             NONE : DOWN   =      1.7 : 1.0
#     ('Other', 'Lenders') = True             NONE : DOWN   =      1.7 : 1.0
#           ('By', '2012') = True             NONE : DOWN   =      1.7 : 1.0
#   ('Sign', 'Memorandum') = True             NONE : DOWN   =      1.7 : 1.0
#     ('Settlement', 'Of') = True             NONE : DOWN   =      1.7 : 1.0
#        ('The', 'Boeing') = True             NONE : DOWN   =      1.7 : 1.0
# ('Mortgage', 'Insurance') = True             NONE : DOWN   =      1.7 : 1.0
#  ('Mitsubishi', 'Heavy') = True             NONE : DOWN   =      1.7 : 1.0
# ('Company', 'Announces') = True               UP : DOWN   =      1.7 : 1.0
#        ('EPS', 'Issues') = True               UP : NONE   =      1.7 : 1.0
#       ('Guidance', 'To') = True             DOWN : UP     =      1.7 : 1.0

# %%
from nltk.classify import DecisionTreeClassifier
dt_classifier = DecisionTreeClassifier.train(train_feats)#, entropy_cutoff=0.8, depth_cutoff=5, support_cutoff=30)

# %%
accuracy(dt_classifier, test_feats)
# Out:
# 0.3055555555555556

# %%
from nltk.classify import MaxentClassifier
me_classifier = MaxentClassifier.train(train_feats)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-69a5376f7192> in <module>()
#       1 from nltk.classify import MaxentClassifier
# ----> 2 me_classifier = MaxentClassifier.train(train_feats)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/nltk/classify/maxent.pyc in train(cls, train_toks, algorithm, trace, encoding, labels, sparse, gaussian_prior_sigma, **cutoffs)
#     309                 train_toks, trace, encoding, labels,
#     310                 cls._SCIPY_ALGS[algorithm], sparse,
# --> 311                 gaussian_prior_sigma, **cutoffs)
#     312         elif algorithm == 'megam':
#     313             return train_maxent_classifier_with_megam(
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/nltk/classify/maxent.pyc in train_maxent_classifier_with_scipy(train_toks, trace, encoding, labels, algorithm, sparse, gaussian_prior_sigma, **cutoffs)
#    1434
#    1435     # Train the model.
# -> 1436     model.fit(algorithm=algorithm)
#    1437
#    1438     # Convert the model's weights from base-e to base-2 weights.
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/scipy/maxentropy/maxentropy.py in fit(self, algorithm)
#    1025
#    1026         # Call base class method
# -> 1027         return model.fit(self, self.K, algorithm)
#    1028
#    1029
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/scipy/maxentropy/maxentropy.py in fit(self, K, algorithm)
#     225                                       maxiter=self.maxiter, full_output=1, \
#     226                                       disp=self.verbose, retall=0,
# --> 227                                       callback=callback)
#     228
#     229             (newparams, fopt, func_calls, grad_calls, warnflag) = retval
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/scipy/optimize/optimize.py in fmin_cg(f, x0, fprime, args, gtol, norm, epsilon, maxiter, full_output, disp, retall, callback)
#     689     else:
#     690         grad_calls, myfprime = wrap_function(fprime, args)
# --> 691     gfk = myfprime(x0)
#     692     k = 0
#     693     N = len(x0)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/scipy/optimize/optimize.py in function_wrapper(x)
#     174     def function_wrapper(x):
#     175         ncalls[0] += 1
# --> 176         return function(x, *args)
#     177     return ncalls, function_wrapper
#     178
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/scipy/maxentropy/maxentropy.py in grad(self, params, ignorepenalty)
#     419             self.setparams(params)
#     420
# --> 421         G = self.expectations() - self.K
#     422
#     423         if self.verbose and self.external is None:
#
# ValueError: operands could not be broadcast together with shapes (648) (6198)
# Grad eval #0

# %%
accuracy(me_classifier, test_feats)

# %%
fdist = FreqDist(reader)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-05e4a813f3cb> in <module>()
# ----> 1 fdist = FreqDist(reader)
#
# NameError: name 'FreqDist' is not defined

# %%
fdist = nltk.FreqDist(reader.words())

# %%
vocab = fdist.keys()

# %%
vocab[:50]
# Out:
# ['00',
#  '-',
#  ':',
#  ',',
#  '2012',
#  '2011',
#  '10',
#  'To',
#  'Guidance',
#  'And',
#  'Corporation',
#  'Announces',
#  'In',
#  'With',
#  '07',
#  'FY',
#  'Inc',
#  'Of',
#  'Issues',
#  '02',
#  '04',
#  '05',
#  '08',
#  '11',
#  '09',
#  '06',
#  '03',
#  '01',
#  '12',
#  '2010',
#  'For',
#  'Dividend',
#  'Revenue',
#  'EPS',
#  'to',
#  'and',
#  'Technology',
#  'Technologies',
#  'The',
#  'Apple',
#  'Quarterly',
#  'of',
#  'Estimates',
#  'Google',
#  'Line',
#  'Declares',
#  'Raises',
#  'Agreement',
#  'Call',
#  'On']

# %%
fdist
# Out:
# <FreqDist with 4675 samples and 67254 outcomes>

# %%
fdist.plot(50, cumulative=True)
