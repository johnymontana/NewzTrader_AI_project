# %%
import random
import nltk as nltk
#nltk.download()
from nltk.corpus import stopwords
import os, os.path
path = os.path.expanduser('~/nltk_data')
if not os.path.exists(path):
    os.mkdir(path)
os.path.exists(path)
import nltk.data
path in nltk.data.path
from nltk.corpus.reader import CategorizedPlaintextCorpusReader
reader = CategorizedPlaintextCorpusReader('.', r'.*_news_.*\.csv', cat_pattern=r'.*_news_(\w+)\.csv')
reader.categories()
reader.fileids(categories=['UP'])
def bag_of_words(words):
    return dict([(word, True) for word in words if word[0].isalpha()])
import collections
def bag_of_words_not_in_set(words, badwords):
    return bag_of_words(set(words)-set(badwords))

def bag_of_non_stopwords(words, stopfile='english'):
    badwords = stopwords.words(stopfile)
    return bag_of_words_not_in_set(words, badwords)

from nltk.metrics import BigramAssocMeasures
from nltk.collocations import BigramCollocationFinder

def bag_of_bigrams_words(words, score_fn=BigramAssocMeasures.chi_sq, n=2000):
    bigram_finder = BigramCollocationFinder.from_words(words)
    bigrams = bigram_finder.nbest(score_fn, n)
    dictOfBigrams = bag_of_words(bigrams)
    dictOfBigrams.update(bag_of_non_stopwords(words))
    return dictOfBigrams
    
def label_feats_from_corpus(corp, feature_detector=bag_of_bigrams_words):
    label_feats = collections.defaultdict(list)
    for label in corp.categories():
        for fileid in corp.fileids(categories=[label]):
            feats = feature_detector(corp.words(fileids=[fileid]))
            label_feats[label].append(feats)
    return label_feats

def split_label_feats(lfeats, split=0.99):
    train_feats = []
    test_feats = []
    for label, feats in lfeats.iteritems():
        random.shuffle(feats, random.random)
        cutoff = int(len(feats) * split)
        train_feats.extend([(feat, label) for feat in feats[:cutoff]])
        test_feats.extend([(feat, label) for feat in feats[cutoff:]])
    return train_feats, test_feats




reader.categories()

lfeats = label_feats_from_corpus(reader)
lfeats.keys()
train_feats, test_feats = split_label_feats(lfeats)
len(train_feats)
len(test_feats)

from nltk.classify import NaiveBayesClassifier
nb_classifier = NaiveBayesClassifier.train(train_feats)
nb_classifier.labels()

from nltk.classify.util import accuracy
accuracy(nb_classifier, test_feats)
# Out:
# 0.07575757575757576

# %%
# Out:
# str

# %%
print len(reader.fileids(categories=['UP']))
print len(reader.fileids(categories=['DOWN']))
print len(reader.fileids(categories=['NONE']))
# Out:
# 47
# 40
# 93

# %%
nb_classifier.show_most_informative_features(n=1000)
# Out:
# Most Informative Features
#                     Free = True               UP : NONE   =     11.0 : 1.0
#                     Swap = True               UP : NONE   =     11.0 : 1.0
#                  Results = True               UP : DOWN   =      7.7 : 1.0
#              Concessions = True             DOWN : NONE   =      7.2 : 1.0
#                   Abbott = True             DOWN : NONE   =      7.2 : 1.0
#                    Light = True             DOWN : NONE   =      7.2 : 1.0
#                 Stations = True             DOWN : NONE   =      7.2 : 1.0
#                      Cap = True             DOWN : NONE   =      7.2 : 1.0
#                     Shed = True             DOWN : NONE   =      7.2 : 1.0
#         ('Offer', 'for') = True               UP : NONE   =      7.1 : 1.0
#                   Turkey = True               UP : NONE   =      7.1 : 1.0
#                      NEC = True               UP : NONE   =      7.1 : 1.0
#                      SAP = True               UP : NONE   =      7.1 : 1.0
#        ('Sell', 'Stake') = True               UP : NONE   =      7.1 : 1.0
#                   Stakes = True               UP : NONE   =      7.1 : 1.0
#         ('Rules', 'for') = True               UP : NONE   =      7.1 : 1.0
#                    Trial = True             DOWN : UP     =      7.1 : 1.0
#                  Presses = True               UP : NONE   =      6.6 : 1.0
#                   Police = True             NONE : DOWN   =      6.3 : 1.0
#          ('as', 'Sales') = True               UP : DOWN   =      6.2 : 1.0
#         ('to', 'Profit') = True               UP : DOWN   =      6.2 : 1.0
#                     Chip = True             NONE : DOWN   =      5.9 : 1.0
#                    Lilly = True             DOWN : NONE   =      5.9 : 1.0
#                    Wyeth = True             DOWN : NONE   =      5.9 : 1.0
#                     Pare = True             DOWN : NONE   =      5.9 : 1.0
#                      RIM = True             DOWN : NONE   =      5.9 : 1.0
#      ('Posts', 'Record') = True             DOWN : NONE   =      5.9 : 1.0
#                  Airline = True             DOWN : NONE   =      5.9 : 1.0
#           ('to', 'Meet') = True             DOWN : NONE   =      5.9 : 1.0
#                   Stores = True             DOWN : NONE   =      5.9 : 1.0
#                Marketing = True             DOWN : NONE   =      5.9 : 1.0
#                Cellphone = True             DOWN : NONE   =      5.9 : 1.0
#                    Seoul = True             DOWN : NONE   =      5.9 : 1.0
#              Electronics = True             DOWN : NONE   =      5.9 : 1.0
#                  Vivendi = True             DOWN : NONE   =      5.9 : 1.0
#                   Helped = True             DOWN : NONE   =      5.9 : 1.0
#                Fortescue = True             DOWN : NONE   =      5.9 : 1.0
#                 Sweetens = True             DOWN : NONE   =      5.9 : 1.0
#                   Swatch = True             DOWN : NONE   =      5.9 : 1.0
#          ('Surge', 'in') = True               UP : NONE   =      5.8 : 1.0
#                  Visteon = True               UP : NONE   =      5.8 : 1.0
#         ('Profit', 'on') = True               UP : NONE   =      5.8 : 1.0
#          ('Judge', 'to') = True               UP : NONE   =      5.8 : 1.0
#                  Shutter = True               UP : NONE   =      5.8 : 1.0
#                   Marvel = True               UP : NONE   =      5.8 : 1.0
#                 Vodafone = True               UP : NONE   =      5.8 : 1.0
#                   Biogen = True               UP : NONE   =      5.8 : 1.0
#                 Motorola = True               UP : NONE   =      5.8 : 1.0
#                      LSE = True               UP : NONE   =      5.8 : 1.0
#        ('York', 'Times') = True               UP : NONE   =      5.8 : 1.0
#                    Terra = True               UP : NONE   =      5.8 : 1.0
#                   Julius = True               UP : NONE   =      5.8 : 1.0
#        ('Home', 'Sales') = True               UP : NONE   =      5.8 : 1.0
#                  Bankers = True               UP : NONE   =      5.8 : 1.0
#                      WTO = True               UP : NONE   =      5.8 : 1.0
#                Sentiment = True               UP : NONE   =      5.8 : 1.0
#                  Scandal = True             DOWN : UP     =      5.7 : 1.0
#           ('Bank', 'of') = True             DOWN : UP     =      5.7 : 1.0
#                       Ad = True               UP : DOWN   =      5.6 : 1.0
#                    Surge = True               UP : DOWN   =      5.6 : 1.0
#                   Agrees = True             DOWN : NONE   =      5.3 : 1.0
#         ('Agrees', 'to') = True             DOWN : NONE   =      5.3 : 1.0
#                   Boeing = True             NONE : UP     =      5.3 : 1.0
#                    Apple = True             NONE : DOWN   =      5.2 : 1.0
#                     Buys = True             NONE : DOWN   =      5.2 : 1.0
#                   Brazil = True             DOWN : NONE   =      5.1 : 1.0
#                     Spat = True             DOWN : NONE   =      5.1 : 1.0
#                   Lloyds = True             DOWN : NONE   =      5.1 : 1.0
#                     Iran = True             DOWN : UP     =      5.1 : 1.0
#                   Israel = True             DOWN : UP     =      5.1 : 1.0
#                   Public = True             DOWN : UP     =      5.1 : 1.0
#                  America = True             DOWN : UP     =      5.1 : 1.0
#                  Funding = True             DOWN : UP     =      5.1 : 1.0
#         ('for', 'Banks') = True               UP : NONE   =      5.1 : 1.0
#               Protesters = True               UP : NONE   =      5.1 : 1.0
#      ('Retail', 'Sales') = True             NONE : UP     =      5.0 : 1.0
#                      IMF = True               UP : NONE   =      5.0 : 1.0
#          ('Signs', 'of') = True               UP : DOWN   =      4.9 : 1.0
#                      War = True               UP : DOWN   =      4.9 : 1.0
#                   Amazon = True               UP : DOWN   =      4.9 : 1.0
#           ('Sale', 'of') = True               UP : DOWN   =      4.9 : 1.0
#                    Mixed = True             NONE : DOWN   =      4.9 : 1.0
#                  Ratings = True               UP : NONE   =      4.7 : 1.0
#                       BP = True               UP : NONE   =      4.7 : 1.0
#                 Spending = True             NONE : UP     =      4.6 : 1.0
#                 Suspends = True             DOWN : NONE   =      4.6 : 1.0
#                  Payment = True             DOWN : NONE   =      4.6 : 1.0
#                       XM = True             DOWN : NONE   =      4.6 : 1.0
#                  Veteran = True             DOWN : NONE   =      4.6 : 1.0
#                 Illinois = True             DOWN : NONE   =      4.6 : 1.0
#                    Widen = True             DOWN : NONE   =      4.6 : 1.0
#           ('Fund', 'to') = True             DOWN : NONE   =      4.6 : 1.0
#                Coalition = True             DOWN : NONE   =      4.6 : 1.0
#                     Hear = True             DOWN : NONE   =      4.6 : 1.0
#                 Building = True             DOWN : NONE   =      4.6 : 1.0
#                 Salaries = True             DOWN : NONE   =      4.6 : 1.0
#                   Needed = True             DOWN : NONE   =      4.6 : 1.0
#       ('Is', 'Arrested') = True             DOWN : NONE   =      4.6 : 1.0
#                   Blocks = True             DOWN : NONE   =      4.6 : 1.0
#                   Missed = True             DOWN : NONE   =      4.6 : 1.0
#       ('Interest', 'in') = True             DOWN : NONE   =      4.6 : 1.0
#                     Spar = True             DOWN : NONE   =      4.6 : 1.0
#                Guarantee = True             DOWN : NONE   =      4.6 : 1.0
#                   Lingus = True             DOWN : NONE   =      4.6 : 1.0
#           ('for', 'Its') = True             DOWN : NONE   =      4.6 : 1.0
#                      DOJ = True             DOWN : NONE   =      4.6 : 1.0
#                     Acts = True             DOWN : NONE   =      4.6 : 1.0
#                   Jailed = True             DOWN : NONE   =      4.6 : 1.0
#                  Detains = True             DOWN : NONE   =      4.6 : 1.0
#                  Reality = True             DOWN : NONE   =      4.6 : 1.0
#           ('to', 'Join') = True             DOWN : NONE   =      4.6 : 1.0
#                     Lays = True             DOWN : NONE   =      4.6 : 1.0
#                     Want = True             DOWN : NONE   =      4.6 : 1.0
#                   Toward = True             DOWN : NONE   =      4.6 : 1.0
#                  Nearing = True             DOWN : NONE   =      4.6 : 1.0
#                   Fourth = True             DOWN : NONE   =      4.6 : 1.0
#          ('Gas', 'Spat') = True             DOWN : NONE   =      4.6 : 1.0
#         ('to', 'Remain') = True             DOWN : NONE   =      4.6 : 1.0
#                Kickbacks = True             DOWN : NONE   =      4.6 : 1.0
#                   Peanut = True             DOWN : NONE   =      4.6 : 1.0
#                   Layoff = True             DOWN : NONE   =      4.6 : 1.0
#                     Lure = True             DOWN : NONE   =      4.6 : 1.0
#           ('in', 'Hong') = True             DOWN : NONE   =      4.6 : 1.0
#            ('RBS', 'to') = True             DOWN : NONE   =      4.6 : 1.0
#                  Limited = True             DOWN : NONE   =      4.6 : 1.0
#                   Cracks = True             DOWN : NONE   =      4.6 : 1.0
#                  Numbers = True             DOWN : NONE   =      4.6 : 1.0
#     ('for', 'Genentech') = True             DOWN : NONE   =      4.6 : 1.0
#             ('Up', 'in') = True             DOWN : NONE   =      4.6 : 1.0
#           ('to', 'Hear') = True             DOWN : NONE   =      4.6 : 1.0
#        ('for', 'Global') = True             DOWN : NONE   =      4.6 : 1.0
#         ('Meet', 'With') = True             DOWN : NONE   =      4.6 : 1.0
#        ('Aer', 'Lingus') = True             DOWN : NONE   =      4.6 : 1.0
#                  Olympic = True             DOWN : NONE   =      4.6 : 1.0
#          ('Chief', 'to') = True             DOWN : NONE   =      4.6 : 1.0
#                Expansion = True             DOWN : NONE   =      4.6 : 1.0
#                 Canadian = True             DOWN : NONE   =      4.6 : 1.0
#           ('Firm', 'to') = True             DOWN : NONE   =      4.6 : 1.0
#                 Producer = True             DOWN : NONE   =      4.6 : 1.0
#                      Aso = True             DOWN : NONE   =      4.6 : 1.0
#                  Through = True             DOWN : NONE   =      4.6 : 1.0
#                      Eye = True             DOWN : NONE   =      4.6 : 1.0
#                Crackdown = True             DOWN : NONE   =      4.6 : 1.0
#                  Reforms = True             DOWN : NONE   =      4.6 : 1.0
#         ('as', 'Profit') = True             DOWN : NONE   =      4.6 : 1.0
#         ('Sirius', 'XM') = True             DOWN : NONE   =      4.6 : 1.0
#                 Baseball = True             DOWN : NONE   =      4.6 : 1.0
#                  Attacks = True             NONE : DOWN   =      4.6 : 1.0
#                  Planned = True               UP : NONE   =      4.5 : 1.0
#           ('Jobs', 'in') = True               UP : NONE   =      4.5 : 1.0
#                  Bidders = True               UP : NONE   =      4.5 : 1.0
#                   Making = True               UP : NONE   =      4.5 : 1.0
#                  Drought = True               UP : NONE   =      4.5 : 1.0
#              AstraZeneca = True               UP : NONE   =      4.5 : 1.0
#           ('on', 'Deal') = True               UP : NONE   =      4.5 : 1.0
#        ('Sees', 'Signs') = True               UP : NONE   =      4.5 : 1.0
#           ('in', 'Some') = True               UP : NONE   =      4.5 : 1.0
#                  Hershey = True               UP : NONE   =      4.5 : 1.0
#           ('Time', 'to') = True               UP : NONE   =      4.5 : 1.0
#         ('Cut', 'Staff') = True               UP : NONE   =      4.5 : 1.0
#  ('Economic', 'Outlook') = True               UP : NONE   =      4.5 : 1.0
#           ('Set', 'for') = True               UP : NONE   =      4.5 : 1.0
#                 Mahindra = True               UP : NONE   =      4.5 : 1.0
#            ('Is', 'Set') = True               UP : NONE   =      4.5 : 1.0
#           ('Buys', 'of') = True               UP : NONE   =      4.5 : 1.0
#                 Progress = True               UP : NONE   =      4.5 : 1.0
#                 Hartford = True               UP : NONE   =      4.5 : 1.0
#                Indonesia = True               UP : NONE   =      4.5 : 1.0
#                   Owners = True               UP : NONE   =      4.5 : 1.0
#                    Month = True               UP : NONE   =      4.5 : 1.0
#                     Club = True               UP : NONE   =      4.5 : 1.0
#         ('for', 'Fraud') = True               UP : NONE   =      4.5 : 1.0
#                     Grim = True               UP : NONE   =      4.5 : 1.0
#                 Fidelity = True               UP : NONE   =      4.5 : 1.0
#                      Ore = True               UP : NONE   =      4.5 : 1.0
#                    Xerox = True               UP : NONE   =      4.5 : 1.0
#                   Elpida = True               UP : NONE   =      4.5 : 1.0
#                  Bancorp = True               UP : NONE   =      4.5 : 1.0
#                   Splits = True               UP : NONE   =      4.5 : 1.0
#                     Camp = True               UP : NONE   =      4.5 : 1.0
#                     Zone = True               UP : NONE   =      4.5 : 1.0
#    ('Geithner', 'Urges') = True               UP : NONE   =      4.5 : 1.0
#          ('ECB', 'Cuts') = True               UP : NONE   =      4.5 : 1.0
#                Struggles = True               UP : NONE   =      4.5 : 1.0
#          ('in', 'Fraud') = True               UP : NONE   =      4.5 : 1.0
#                Discusses = True               UP : NONE   =      4.5 : 1.0
#                     Book = True               UP : NONE   =      4.5 : 1.0
#                    Terms = True               UP : NONE   =      4.5 : 1.0
#          ('Slows', 'in') = True               UP : NONE   =      4.5 : 1.0
#                    Bombs = True               UP : NONE   =      4.5 : 1.0
#          ('Banks', 'to') = True               UP : NONE   =      4.5 : 1.0
#       ('Profit', 'Drop') = True               UP : NONE   =      4.5 : 1.0
# ('China', 'Manufacturing') = True               UP : NONE   =      4.5 : 1.0
#                    Crime = True               UP : NONE   =      4.5 : 1.0
#        ('to', 'Shutter') = True               UP : NONE   =      4.5 : 1.0
#                Withdraws = True               UP : NONE   =      4.5 : 1.0
#        ('With', 'China') = True               UP : NONE   =      4.5 : 1.0
#       ('Intel', 'Gives') = True               UP : NONE   =      4.5 : 1.0
#         ('New', 'Chief') = True               UP : NONE   =      4.5 : 1.0
#                  Setback = True               UP : NONE   =      4.5 : 1.0
#     ('Cuts', 'Dividend') = True             DOWN : UP     =      4.4 : 1.0
#                     Name = True             DOWN : UP     =      4.4 : 1.0
#                  Control = True             DOWN : UP     =      4.4 : 1.0
#           ('Rise', 'in') = True               UP : NONE   =      4.3 : 1.0
#                 Dividend = True             DOWN : NONE   =      4.3 : 1.0
#                   Cities = True             DOWN : NONE   =      4.3 : 1.0
#                     Must = True             DOWN : NONE   =      4.3 : 1.0
#                     East = True             DOWN : NONE   =      4.3 : 1.0
#                     Jail = True             DOWN : NONE   =      4.3 : 1.0
#                  Margins = True             DOWN : NONE   =      4.3 : 1.0
#                 Arrested = True             DOWN : NONE   =      4.3 : 1.0
#                   Sirius = True             DOWN : NONE   =      4.3 : 1.0
#                  Beijing = True             NONE : UP     =      4.3 : 1.0
#                    Qwest = True               UP : NONE   =      4.3 : 1.0
#                  Premier = True               UP : NONE   =      4.3 : 1.0
#                      AOL = True               UP : NONE   =      4.3 : 1.0
#                       Do = True               UP : NONE   =      4.3 : 1.0
#                Santander = True               UP : NONE   =      4.3 : 1.0
#                   Groups = True               UP : NONE   =      4.3 : 1.0
#      ('Loss', 'Narrows') = True               UP : NONE   =      4.3 : 1.0
#                    Glaxo = True               UP : NONE   =      4.3 : 1.0
#           ('Loss', 'as') = True               UP : DOWN   =      4.3 : 1.0
#                    Issue = True               UP : DOWN   =      4.3 : 1.0
#               Australian = True               UP : DOWN   =      4.3 : 1.0
#                     Adds = True               UP : DOWN   =      4.3 : 1.0
#                 Chemical = True               UP : DOWN   =      4.3 : 1.0
#        ('Net', 'Income') = True               UP : DOWN   =      4.3 : 1.0
#                  Narrows = True               UP : DOWN   =      4.3 : 1.0
#                 Scrutiny = True               UP : DOWN   =      4.3 : 1.0
#                  Dispute = True               UP : DOWN   =      4.3 : 1.0
#                    Irish = True             DOWN : UP     =      4.3 : 1.0
#                 Downturn = True             NONE : DOWN   =      4.2 : 1.0
#                     Next = True             NONE : DOWN   =      4.2 : 1.0
#                    Tries = True             DOWN : NONE   =      4.2 : 1.0
#                  Alleged = True               UP : NONE   =      4.2 : 1.0
#                  Defense = True               UP : NONE   =      4.2 : 1.0
#                  Profits = True               UP : DOWN   =      4.1 : 1.0
#                   Taiwan = True               UP : DOWN   =      4.1 : 1.0
#                  Goldman = True             DOWN : NONE   =      4.1 : 1.0
#                     Move = True               UP : NONE   =      4.0 : 1.0
#                  Dealers = True             NONE : UP     =      3.9 : 1.0
#                   Airbus = True             NONE : UP     =      3.9 : 1.0
#                     Race = True             NONE : UP     =      3.9 : 1.0
#                   Closes = True             NONE : UP     =      3.9 : 1.0
#                     Fire = True             NONE : UP     =      3.9 : 1.0
#                   Effort = True             NONE : UP     =      3.9 : 1.0
#             Shareholders = True             NONE : DOWN   =      3.9 : 1.0
#                   Extend = True             NONE : DOWN   =      3.9 : 1.0
#                     Meet = True             DOWN : UP     =      3.9 : 1.0
#                    Signs = True             NONE : DOWN   =      3.8 : 1.0
#                    Shell = True             DOWN : NONE   =      3.7 : 1.0
#                   Attack = True             DOWN : UP     =      3.7 : 1.0
#                    Maker = True             DOWN : UP     =      3.7 : 1.0
#              ('in', 'a') = True             DOWN : UP     =      3.7 : 1.0
#                   Sought = True             DOWN : UP     =      3.7 : 1.0
#                   Better = True             DOWN : UP     =      3.7 : 1.0
#                   Supply = True             DOWN : UP     =      3.7 : 1.0
#                      FBI = True             DOWN : UP     =      3.7 : 1.0
#        ('World', 'Bank') = True             DOWN : UP     =      3.7 : 1.0
#                     City = True             DOWN : UP     =      3.7 : 1.0
#       ('Expected', 'to') = True             DOWN : UP     =      3.7 : 1.0
#                      CFO = True             DOWN : UP     =      3.7 : 1.0
#         ('Cost', 'Cuts') = True               UP : NONE   =      3.7 : 1.0
#                Militants = True             DOWN : NONE   =      3.7 : 1.0
#                     Hong = True             DOWN : UP     =      3.6 : 1.0
#                     Sued = True               UP : DOWN   =      3.6 : 1.0
#           ('to', 'Lead') = True               UP : DOWN   =      3.6 : 1.0
#                   Unions = True               UP : DOWN   =      3.6 : 1.0
#                  Digital = True               UP : DOWN   =      3.6 : 1.0
#                   Lehman = True               UP : DOWN   =      3.6 : 1.0
#                 Analysts = True               UP : DOWN   =      3.6 : 1.0
#                   Upbeat = True               UP : DOWN   =      3.6 : 1.0
#                Sotomayor = True               UP : DOWN   =      3.6 : 1.0
#                    Short = True               UP : DOWN   =      3.6 : 1.0
#                      GOP = True               UP : DOWN   =      3.6 : 1.0
#       ('in', 'Pakistan') = True               UP : DOWN   =      3.6 : 1.0
#                  Housing = True               UP : DOWN   =      3.6 : 1.0
#      ('Posts', 'Profit') = True               UP : DOWN   =      3.6 : 1.0
#                       As = True               UP : DOWN   =      3.6 : 1.0
#        ('Sales', 'Rise') = True               UP : NONE   =      3.6 : 1.0
#                     EBay = True               UP : NONE   =      3.6 : 1.0
#                      Web = True             NONE : UP     =      3.6 : 1.0
#                 Bernanke = True             NONE : UP     =      3.6 : 1.0
#                    Found = True             NONE : UP     =      3.6 : 1.0
#          ('Deal', 'for') = True             NONE : DOWN   =      3.6 : 1.0
#                    Dubai = True             DOWN : NONE   =      3.5 : 1.0
#                    Death = True             DOWN : NONE   =      3.5 : 1.0
#          ('Tries', 'to') = True             DOWN : NONE   =      3.5 : 1.0
#   ('Profit', 'Declines') = True             DOWN : NONE   =      3.5 : 1.0
#            ('to', 'Lay') = True             DOWN : NONE   =      3.5 : 1.0
#              Foreclosure = True             DOWN : NONE   =      3.5 : 1.0
#        ('Control', 'of') = True             DOWN : NONE   =      3.5 : 1.0
#                     Save = True             DOWN : NONE   =      3.5 : 1.0
#                   Freeze = True             DOWN : NONE   =      3.5 : 1.0
#                   Others = True             DOWN : NONE   =      3.5 : 1.0
#           ('Lay', 'Off') = True             DOWN : NONE   =      3.5 : 1.0
#                     CEOs = True             DOWN : NONE   =      3.5 : 1.0
#           ('to', 'Lift') = True             DOWN : NONE   =      3.5 : 1.0
#             ('Is', 'on') = True             DOWN : NONE   =      3.5 : 1.0
#                      BOJ = True             DOWN : NONE   =      3.5 : 1.0
#         ('Cut', 'Costs') = True             DOWN : NONE   =      3.5 : 1.0
#                      IPO = True               UP : DOWN   =      3.5 : 1.0
#                     Test = True               UP : DOWN   =      3.5 : 1.0
#       ('Prices', 'Fall') = True               UP : NONE   =      3.5 : 1.0
#                Berkshire = True               UP : NONE   =      3.5 : 1.0
#                 Partners = True               UP : NONE   =      3.5 : 1.0
#                 Trillion = True               UP : NONE   =      3.5 : 1.0
#               Operations = True               UP : NONE   =      3.5 : 1.0
#                   Plunge = True               UP : NONE   =      3.5 : 1.0
#                    March = True               UP : NONE   =      3.5 : 1.0
#                   Shrink = True               UP : NONE   =      3.5 : 1.0
#                  Premium = True               UP : NONE   =      3.5 : 1.0
#                     Hypo = True               UP : NONE   =      3.5 : 1.0
#                 Slightly = True               UP : NONE   =      3.5 : 1.0
#        ('Car', 'Makers') = True               UP : NONE   =      3.5 : 1.0
#          ('Best', 'Buy') = True               UP : NONE   =      3.5 : 1.0
#                      KKR = True               UP : NONE   =      3.5 : 1.0
#                  Spreads = True               UP : NONE   =      3.5 : 1.0
#                  Airways = True               UP : NONE   =      3.5 : 1.0
#                    Press = True               UP : NONE   =      3.5 : 1.0
#                 Confirms = True               UP : NONE   =      3.5 : 1.0
#                      ADP = True               UP : NONE   =      3.5 : 1.0
#                    Drugs = True               UP : NONE   =      3.5 : 1.0
#           ('Aims', 'to') = True             DOWN : NONE   =      3.5 : 1.0
#                      FDA = True             DOWN : UP     =      3.4 : 1.0
#                     Gaza = True             DOWN : UP     =      3.4 : 1.0
#    ('Quarterly', 'Loss') = True             DOWN : UP     =      3.4 : 1.0
#                    Music = True             DOWN : UP     =      3.4 : 1.0
#                   Mobile = True             DOWN : NONE   =      3.4 : 1.0
#              ('to', 'a') = True               UP : DOWN   =      3.4 : 1.0
#                  Another = True               UP : NONE   =      3.4 : 1.0
#          ('Warns', 'on') = True               UP : NONE   =      3.4 : 1.0
#                  Taliban = True               UP : DOWN   =      3.4 : 1.0
#                    Share = True               UP : DOWN   =      3.4 : 1.0
#                     Team = True             DOWN : UP     =      3.3 : 1.0
#               Investment = True             DOWN : UP     =      3.3 : 1.0
#       ('Tech', 'Giants') = True             DOWN : NONE   =      3.3 : 1.0
#                      Led = True             DOWN : NONE   =      3.3 : 1.0
#                    Water = True             DOWN : NONE   =      3.3 : 1.0
#         ('Impact', 'on') = True             DOWN : NONE   =      3.3 : 1.0
#        ('Gambles', 'on') = True             DOWN : NONE   =      3.3 : 1.0
#           ('to', 'Team') = True             DOWN : NONE   =      3.3 : 1.0
#                   Visits = True             DOWN : NONE   =      3.3 : 1.0
#                  Asserts = True             DOWN : NONE   =      3.3 : 1.0
#              Philippines = True             DOWN : NONE   =      3.3 : 1.0
#         ('Offers', 'to') = True             DOWN : NONE   =      3.3 : 1.0
#                    Depth = True             DOWN : NONE   =      3.3 : 1.0
#             ('Up', 'on') = True             DOWN : NONE   =      3.3 : 1.0
#                 Reynolds = True             DOWN : NONE   =      3.3 : 1.0
#  ('Pakistan', 'Arrests') = True             DOWN : NONE   =      3.3 : 1.0
#                  Foxconn = True             DOWN : NONE   =      3.3 : 1.0
#       ('Stocks', 'Drop') = True             DOWN : NONE   =      3.3 : 1.0
#               Foreigners = True             DOWN : NONE   =      3.3 : 1.0
#           ('Look', 'to') = True             DOWN : NONE   =      3.3 : 1.0
#                   Arrest = True             DOWN : NONE   =      3.3 : 1.0
#       ('Obama', 'Makes') = True             DOWN : NONE   =      3.3 : 1.0
#                   Repair = True             DOWN : NONE   =      3.3 : 1.0
#         ('Israel', 'to') = True             DOWN : NONE   =      3.3 : 1.0
#           ('to', 'Shed') = True             DOWN : NONE   =      3.3 : 1.0
#              Stabilizing = True             DOWN : NONE   =      3.3 : 1.0
#   ('Regulators', 'Shut') = True             DOWN : NONE   =      3.3 : 1.0
#                  Bullish = True             DOWN : NONE   =      3.3 : 1.0
#       ('Official', 'Is') = True             DOWN : NONE   =      3.3 : 1.0
#                Copyright = True             DOWN : NONE   =      3.3 : 1.0
#                 Discount = True             DOWN : NONE   =      3.3 : 1.0
#         ('Posts', 'Net') = True             DOWN : NONE   =      3.3 : 1.0
#               Smithfield = True             DOWN : NONE   =      3.3 : 1.0
#           ('Give', 'Up') = True             DOWN : NONE   =      3.3 : 1.0
#      ('to', 'Quarterly') = True             DOWN : NONE   =      3.3 : 1.0
#       ('Los', 'Angeles') = True             DOWN : NONE   =      3.3 : 1.0
#                  Angeles = True             DOWN : NONE   =      3.3 : 1.0
#                  Gambles = True             DOWN : NONE   =      3.3 : 1.0
#     ('New', 'President') = True             DOWN : NONE   =      3.3 : 1.0
#         ('on', 'Stocks') = True             DOWN : NONE   =      3.3 : 1.0
#      ('Nikkei', 'Slips') = True             DOWN : NONE   =      3.3 : 1.0
#                  Flights = True             DOWN : NONE   =      3.3 : 1.0
#                  Stumble = True             DOWN : NONE   =      3.3 : 1.0
#      ('Electric', 'Car') = True             DOWN : NONE   =      3.3 : 1.0
#                    Ideas = True             DOWN : NONE   =      3.3 : 1.0
#         ('Boeing', 'to') = True             DOWN : NONE   =      3.3 : 1.0
#                    Liddy = True             DOWN : NONE   =      3.3 : 1.0
#                    Cnooc = True             DOWN : NONE   =      3.3 : 1.0
#           ('Fall', 'as') = True             DOWN : NONE   =      3.3 : 1.0
#                    Image = True             DOWN : NONE   =      3.3 : 1.0
#       ('on', 'Economic') = True             DOWN : NONE   =      3.3 : 1.0
#                    Norsk = True             DOWN : NONE   =      3.3 : 1.0
#                  Embraer = True             DOWN : NONE   =      3.3 : 1.0
#                McClatchy = True             DOWN : NONE   =      3.3 : 1.0
#      ('President', 'to') = True             DOWN : NONE   =      3.3 : 1.0
#                  Turkish = True             DOWN : NONE   =      3.3 : 1.0
#     ('of', 'Investment') = True             DOWN : NONE   =      3.3 : 1.0
#       ('on', 'Recovery') = True             DOWN : NONE   =      3.3 : 1.0
#                 Nintendo = True             DOWN : NONE   =      3.3 : 1.0
#                   Malone = True             DOWN : NONE   =      3.3 : 1.0
#                 Broadway = True             DOWN : NONE   =      3.3 : 1.0
#                  Loosens = True             DOWN : NONE   =      3.3 : 1.0
#          ('GE', 'Loses') = True             DOWN : NONE   =      3.3 : 1.0
#                     John = True             DOWN : NONE   =      3.3 : 1.0
#                    Lends = True             DOWN : NONE   =      3.3 : 1.0
#            ('Take', 'a') = True             DOWN : NONE   =      3.3 : 1.0
#                Attention = True             DOWN : NONE   =      3.3 : 1.0
#                    Hefty = True             DOWN : NONE   =      3.3 : 1.0
#                Chartered = True             DOWN : NONE   =      3.3 : 1.0
#    ('Eastern', 'Europe') = True             DOWN : NONE   =      3.3 : 1.0
#      ('Starbucks', 'to') = True             DOWN : NONE   =      3.3 : 1.0
#                     Odds = True             DOWN : NONE   =      3.3 : 1.0
#                    Defer = True             DOWN : NONE   =      3.3 : 1.0
#         ('Sales', 'Are') = True             DOWN : NONE   =      3.3 : 1.0
#     ('Credit', 'Suisse') = True             DOWN : NONE   =      3.3 : 1.0
#          ('on', 'Trade') = True             DOWN : NONE   =      3.3 : 1.0
#              Immigration = True             DOWN : NONE   =      3.3 : 1.0
#         ('Windows', '7') = True             DOWN : NONE   =      3.3 : 1.0
#                   Weaker = True             DOWN : NONE   =      3.3 : 1.0
#           ('Hard', 'to') = True             DOWN : NONE   =      3.3 : 1.0
#             ('Is', 'in') = True             DOWN : NONE   =      3.3 : 1.0
#                   Resort = True             DOWN : NONE   =      3.3 : 1.0
#                Sentenced = True             DOWN : NONE   =      3.3 : 1.0
#                 Magazine = True             DOWN : NONE   =      3.3 : 1.0
#          ('to', 'Defer') = True             DOWN : NONE   =      3.3 : 1.0
#                    Below = True             DOWN : NONE   =      3.3 : 1.0
#           ('to', 'Exit') = True             DOWN : NONE   =      3.3 : 1.0
#       ('Falls', 'Below') = True             DOWN : NONE   =      3.3 : 1.0
#                   Revive = True             DOWN : NONE   =      3.3 : 1.0
#   ('Universal', 'Music') = True             DOWN : NONE   =      3.3 : 1.0
#                      RBA = True             DOWN : NONE   =      3.3 : 1.0
#                  Dropped = True             DOWN : NONE   =      3.3 : 1.0
#                Magazines = True             DOWN : NONE   =      3.3 : 1.0
#                   Frozen = True             DOWN : NONE   =      3.3 : 1.0
#           ('to', 'Quit') = True             DOWN : NONE   =      3.3 : 1.0
#                 Windfall = True             DOWN : NONE   =      3.3 : 1.0
#              Blagojevich = True             DOWN : NONE   =      3.3 : 1.0
#                 Senators = True             DOWN : NONE   =      3.3 : 1.0
#        ('Take', 'Stake') = True             DOWN : NONE   =      3.3 : 1.0
#                   Drives = True             DOWN : NONE   =      3.3 : 1.0
#                      KBC = True             DOWN : NONE   =      3.3 : 1.0
#       ('Decision', 'on') = True             DOWN : NONE   =      3.3 : 1.0
#          ('Yahoo', 'to') = True             DOWN : NONE   =      3.3 : 1.0
#       ('Treasury', 'to') = True             DOWN : NONE   =      3.3 : 1.0
#                  Bearish = True             DOWN : NONE   =      3.3 : 1.0
#     ('Weak', 'Earnings') = True             DOWN : NONE   =      3.3 : 1.0
#                    Other = True             DOWN : NONE   =      3.3 : 1.0
#                    Brand = True             DOWN : NONE   =      3.3 : 1.0
#                  Stories = True             DOWN : NONE   =      3.3 : 1.0
#           Communications = True             DOWN : NONE   =      3.3 : 1.0
#          ('Tinto', 'to') = True             DOWN : NONE   =      3.3 : 1.0
#       ('Judge', 'Rules') = True             DOWN : NONE   =      3.3 : 1.0
#           ('Back', 'to') = True             DOWN : NONE   =      3.3 : 1.0
#                      CCB = True             DOWN : NONE   =      3.3 : 1.0
#                  Appeals = True             DOWN : NONE   =      3.3 : 1.0
#                     Care = True             DOWN : NONE   =      3.3 : 1.0
#                    Simon = True             DOWN : NONE   =      3.3 : 1.0
#      ('Raises', 'Funds') = True             DOWN : NONE   =      3.3 : 1.0
#        ('to', 'Propose') = True             DOWN : NONE   =      3.3 : 1.0
#                 Restarts = True             DOWN : NONE   =      3.3 : 1.0
#           ('to', 'Grow') = True             DOWN : NONE   =      3.3 : 1.0
#          ('May', 'Sell') = True             DOWN : NONE   =      3.3 : 1.0
#     ('Family', 'Dollar') = True             DOWN : NONE   =      3.3 : 1.0
#      ('Energy', 'Posts') = True             DOWN : NONE   =      3.3 : 1.0
#       ('Unlikely', 'to') = True             DOWN : NONE   =      3.3 : 1.0
#                    Seven = True             DOWN : NONE   =      3.3 : 1.0
#      ('Poor', 'Nations') = True             DOWN : NONE   =      3.3 : 1.0
#                   Poland = True             DOWN : NONE   =      3.3 : 1.0
#       ('Detained', 'in') = True             DOWN : NONE   =      3.3 : 1.0
#            ('to', 'Woo') = True             DOWN : NONE   =      3.3 : 1.0
#        ('Banks', 'Slip') = True             DOWN : NONE   =      3.3 : 1.0
#                   Gunmen = True             DOWN : NONE   =      3.3 : 1.0
#        ('Demand', 'for') = True             DOWN : NONE   =      3.3 : 1.0
#                    Aegon = True             DOWN : NONE   =      3.3 : 1.0
#      ('Rates', 'Steady') = True             DOWN : NONE   =      3.3 : 1.0
#       ('Billions', 'in') = True             DOWN : NONE   =      3.3 : 1.0
#                      TVs = True             DOWN : NONE   =      3.3 : 1.0
#        ('Net', 'Slumps') = True             DOWN : NONE   =      3.3 : 1.0
#                 Collapse = True             DOWN : NONE   =      3.3 : 1.0
#                   Forest = True             DOWN : NONE   =      3.3 : 1.0
#           ('to', 'Pare') = True             DOWN : NONE   =      3.3 : 1.0
#           ('Seen', 'in') = True             DOWN : NONE   =      3.3 : 1.0
#                  Appears = True             DOWN : NONE   =      3.3 : 1.0
#                  Revisit = True             DOWN : NONE   =      3.3 : 1.0
#                    Stops = True             DOWN : NONE   =      3.3 : 1.0
#           ('at', 'Home') = True             DOWN : NONE   =      3.3 : 1.0
#   ('Asserts', 'Control') = True             DOWN : NONE   =      3.3 : 1.0
#            HarperCollins = True             DOWN : NONE   =      3.3 : 1.0
#       ('Chooses', 'New') = True             DOWN : NONE   =      3.3 : 1.0
#         ('Seeks', 'End') = True             DOWN : NONE   =      3.3 : 1.0
#                Petrobras = True             DOWN : NONE   =      3.3 : 1.0
#       ('Stocks', 'Sink') = True             DOWN : NONE   =      3.3 : 1.0
#                   Longer = True             DOWN : NONE   =      3.3 : 1.0
#      ('Beijing', 'Auto') = True             DOWN : NONE   =      3.3 : 1.0
#                   Senior = True             DOWN : NONE   =      3.3 : 1.0
#           ('Off', 'for') = True             DOWN : NONE   =      3.3 : 1.0
#                 Facility = True             DOWN : NONE   =      3.3 : 1.0
#                Extension = True             DOWN : NONE   =      3.3 : 1.0
#   ('Investment', 'Bank') = True             DOWN : NONE   =      3.3 : 1.0
#                 Negative = True             DOWN : NONE   =      3.3 : 1.0
#      ('Gets', 'Billion') = True             DOWN : NONE   =      3.3 : 1.0
#                   Suisse = True             DOWN : NONE   =      3.3 : 1.0
#                 Criminal = True             DOWN : NONE   =      3.3 : 1.0
#          ('Obama', 'Is') = True             DOWN : NONE   =      3.3 : 1.0
#                  Dilemma = True             DOWN : NONE   =      3.3 : 1.0
#        ('Expects', 'to') = True             DOWN : NONE   =      3.3 : 1.0
#                      Yet = True             DOWN : NONE   =      3.3 : 1.0
#         ('Net', 'Jumps') = True             DOWN : NONE   =      3.3 : 1.0
#      ('Cut', 'Dividend') = True             DOWN : NONE   =      3.3 : 1.0
#                 Upgrades = True             DOWN : NONE   =      3.3 : 1.0
#                    Brink = True             DOWN : NONE   =      3.3 : 1.0
#       ('Orders', 'Fall') = True             DOWN : NONE   =      3.3 : 1.0
#            Constellation = True             DOWN : NONE   =      3.3 : 1.0
#       ('in', 'Chrysler') = True             DOWN : NONE   =      3.3 : 1.0
#                   Halted = True             DOWN : NONE   =      3.3 : 1.0
#         ('Killed', 'in') = True             DOWN : NONE   =      3.3 : 1.0
#                   Church = True             DOWN : NONE   =      3.3 : 1.0
#           ('to', 'Push') = True             DOWN : NONE   =      3.3 : 1.0
#              Allegations = True             DOWN : NONE   =      3.3 : 1.0
#                  Warning = True             DOWN : NONE   =      3.3 : 1.0
#                      SAG = True             DOWN : NONE   =      3.3 : 1.0
#        ('on', 'Bonuses') = True             DOWN : NONE   =      3.3 : 1.0
#                 Advanced = True             DOWN : NONE   =      3.3 : 1.0
#              Subscribers = True             DOWN : NONE   =      3.3 : 1.0
#          ('on', 'Block') = True             DOWN : NONE   =      3.3 : 1.0
#                 Approach = True             DOWN : NONE   =      3.3 : 1.0
#                    Taste = True             DOWN : NONE   =      3.3 : 1.0
#                     TiVo = True             DOWN : NONE   =      3.3 : 1.0
#                     Duke = True             DOWN : NONE   =      3.3 : 1.0
#         ('on', 'Madoff') = True             DOWN : NONE   =      3.3 : 1.0
#        ('Braces', 'for') = True             DOWN : NONE   =      3.3 : 1.0
#                    Forgo = True             DOWN : NONE   =      3.3 : 1.0
#                     Bull = True             DOWN : NONE   =      3.3 : 1.0
#          ('Focus', 'to') = True             DOWN : NONE   =      3.3 : 1.0
#                      Los = True             DOWN : NONE   =      3.3 : 1.0
#                  Fujitsu = True             DOWN : NONE   =      3.3 : 1.0
# ('Standard', 'Chartered') = True             DOWN : NONE   =      3.3 : 1.0
#                  Reverse = True             DOWN : NONE   =      3.3 : 1.0
#         ('Ties', 'With') = True             DOWN : NONE   =      3.3 : 1.0
#                    Going = True             DOWN : NONE   =      3.3 : 1.0
#                   Agency = True             DOWN : NONE   =      3.3 : 1.0
#              Afghanistan = True             DOWN : NONE   =      3.3 : 1.0
#                    Roche = True             DOWN : NONE   =      3.3 : 1.0
#                    Syria = True             NONE : UP     =      3.3 : 1.0
#            ('to', 'Pay') = True             NONE : UP     =      3.3 : 1.0
#     ('Merrill', 'Bonus') = True               UP : NONE   =      3.2 : 1.0
#                    Sharp = True               UP : NONE   =      3.2 : 1.0
#          ('Could', 'Be') = True               UP : NONE   =      3.2 : 1.0
#           ('on', 'Cost') = True               UP : NONE   =      3.2 : 1.0
#                  Advance = True               UP : NONE   =      3.2 : 1.0
#                 Sebelius = True               UP : NONE   =      3.2 : 1.0
#            ('a', 'Bank') = True               UP : NONE   =      3.2 : 1.0
#            ('Art', 'of') = True               UP : NONE   =      3.2 : 1.0
#                Europeans = True               UP : NONE   =      3.2 : 1.0
#            ('to', 'Net') = True               UP : NONE   =      3.2 : 1.0
#                      Kia = True               UP : NONE   =      3.2 : 1.0
#                     Foes = True               UP : NONE   =      3.2 : 1.0
#              Remittances = True               UP : NONE   =      3.2 : 1.0
#        ('Proxy', 'Firm') = True               UP : NONE   =      3.2 : 1.0
#        ('Talks', 'Over') = True               UP : NONE   =      3.2 : 1.0
#                    Techs = True               UP : NONE   =      3.2 : 1.0
#                   Fights = True               UP : NONE   =      3.2 : 1.0
#       ('on', 'Chrysler') = True               UP : NONE   =      3.2 : 1.0
#          ('for', 'Hypo') = True               UP : NONE   =      3.2 : 1.0
#    ('Economy', 'Slumps') = True               UP : NONE   =      3.2 : 1.0
#                   Expect = True               UP : NONE   =      3.2 : 1.0
#     ('Life', 'Insurers') = True               UP : NONE   =      3.2 : 1.0
#                    Kurds = True               UP : NONE   =      3.2 : 1.0
#        ('Behind', 'the') = True               UP : NONE   =      3.2 : 1.0
#                      BMW = True               UP : NONE   =      3.2 : 1.0
#                   Voters = True               UP : NONE   =      3.2 : 1.0
#                  Huiyuan = True               UP : NONE   =      3.2 : 1.0
#                      HIV = True               UP : NONE   =      3.2 : 1.0
#          ('Doubt', 'on') = True               UP : NONE   =      3.2 : 1.0
#      ('Rights', 'Issue') = True               UP : NONE   =      3.2 : 1.0
#        ('ADP', 'Report') = True               UP : NONE   =      3.2 : 1.0
#                    Cigna = True               UP : NONE   =      3.2 : 1.0
#                   Server = True               UP : NONE   =      3.2 : 1.0
#                    Hands = True               UP : NONE   =      3.2 : 1.0
#       ('Stocks', 'Gain') = True               UP : NONE   =      3.2 : 1.0
#               Discipline = True               UP : NONE   =      3.2 : 1.0
#                Economist = True               UP : NONE   =      3.2 : 1.0
#                    Estee = True               UP : NONE   =      3.2 : 1.0
#                  Insider = True               UP : NONE   =      3.2 : 1.0
#           ('Is', 'Near') = True               UP : NONE   =      3.2 : 1.0
#         ('PC', 'Market') = True               UP : NONE   =      3.2 : 1.0
#                  Getting = True               UP : NONE   =      3.2 : 1.0
#     ('Vegas', 'Project') = True               UP : NONE   =      3.2 : 1.0
#            ('In', 'New') = True               UP : NONE   =      3.2 : 1.0
#                    Vital = True               UP : NONE   =      3.2 : 1.0
#                Holocaust = True               UP : NONE   =      3.2 : 1.0
#                 Subpoena = True               UP : NONE   =      3.2 : 1.0
#                    Dealt = True               UP : NONE   =      3.2 : 1.0
#           ('Hon', 'Hai') = True               UP : NONE   =      3.2 : 1.0
# ('Contraction', 'Slows') = True               UP : NONE   =      3.2 : 1.0
#                 EchoStar = True               UP : NONE   =      3.2 : 1.0
#           ('Sony', 'to') = True               UP : NONE   =      3.2 : 1.0
#                    Troop = True               UP : NONE   =      3.2 : 1.0
#       ('Yahoo', 'Plans') = True               UP : NONE   =      3.2 : 1.0
#               AutoNation = True               UP : NONE   =      3.2 : 1.0
#          ('Fiat', 'CEO') = True               UP : NONE   =      3.2 : 1.0
#                 Shopping = True               UP : NONE   =      3.2 : 1.0
#                    Shaky = True               UP : NONE   =      3.2 : 1.0
#                   Barrel = True               UP : NONE   =      3.2 : 1.0
#        ('Charged', 'in') = True               UP : NONE   =      3.2 : 1.0
#           ('of', 'Unit') = True               UP : NONE   =      3.2 : 1.0
#                  Feeling = True               UP : NONE   =      3.2 : 1.0
#                     Miss = True               UP : NONE   =      3.2 : 1.0
#                     ICBC = True               UP : NONE   =      3.2 : 1.0
#                    Drama = True               UP : NONE   =      3.2 : 1.0
#        ('Credit', 'Net') = True               UP : NONE   =      3.2 : 1.0
#                  Clashes = True               UP : NONE   =      3.2 : 1.0
#          ('to', 'Fight') = True               UP : NONE   =      3.2 : 1.0
#                    Seize = True               UP : NONE   =      3.2 : 1.0
#       ('Ericsson', 'to') = True               UP : NONE   =      3.2 : 1.0
#                      App = True               UP : NONE   =      3.2 : 1.0
#        ('Daimler', 'to') = True               UP : NONE   =      3.2 : 1.0
#                     REIT = True               UP : NONE   =      3.2 : 1.0
#          ('Short', 'on') = True               UP : NONE   =      3.2 : 1.0
#                    Faith = True               UP : NONE   =      3.2 : 1.0
#                   Sharif = True               UP : NONE   =      3.2 : 1.0
#                 Michigan = True               UP : NONE   =      3.2 : 1.0
#                   Somali = True               UP : NONE   =      3.2 : 1.0
#           ('at', 'Risk') = True               UP : NONE   =      3.2 : 1.0
#  ('Raises', 'Questions') = True               UP : NONE   =      3.2 : 1.0
#      ('Profit', 'Beats') = True               UP : NONE   =      3.2 : 1.0
#            ('on', 'Oil') = True               UP : NONE   =      3.2 : 1.0
#        ('in', 'January') = True               UP : NONE   =      3.2 : 1.0
#                     Lows = True               UP : NONE   =      3.2 : 1.0
#     ('Madoff', 'Losses') = True               UP : NONE   =      3.2 : 1.0
#          ('Meet', 'the') = True               UP : NONE   =      3.2 : 1.0
#        ('for', 'Satyam') = True               UP : NONE   =      3.2 : 1.0
#               Accountant = True               UP : NONE   =      3.2 : 1.0
#                    Bucks = True               UP : NONE   =      3.2 : 1.0
#                Stability = True               UP : NONE   =      3.2 : 1.0
#          ('Faith', 'in') = True               UP : NONE   =      3.2 : 1.0
#                  Trouble = True               UP : NONE   =      3.2 : 1.0
#                      Hai = True               UP : NONE   =      3.2 : 1.0
#   ('Lawmakers', 'Weigh') = True               UP : NONE   =      3.2 : 1.0
#        ('Up', 'Efforts') = True               UP : NONE   =      3.2 : 1.0
#           ('in', 'June') = True               UP : NONE   =      3.2 : 1.0
#      ('in', 'Indonesia') = True               UP : NONE   =      3.2 : 1.0
#         ('Closer', 'to') = True               UP : NONE   =      3.2 : 1.0
#                      She = True               UP : NONE   =      3.2 : 1.0
#            ('a', 'Long') = True               UP : NONE   =      3.2 : 1.0
# ...
#                  Remains = True             NONE : UP     =      2.9 : 1.0
#                     File = True             NONE : UP     =      2.9 : 1.0
#                   Afghan = True             NONE : DOWN   =      2.9 : 1.0
#            ('in', 'the') = True             DOWN : NONE   =      2.9 : 1.0
#                      Law = True             DOWN : NONE   =      2.9 : 1.0
#                      Fed = True             NONE : DOWN   =      2.9 : 1.0
#                      Ire = True             NONE : DOWN   =      2.9 : 1.0
#                     Vows = True             NONE : DOWN   =      2.9 : 1.0
#                    Leads = True             NONE : DOWN   =      2.9 : 1.0
#            ('to', 'the') = True             NONE : DOWN   =      2.9 : 1.0
#                     Long = True             NONE : DOWN   =      2.9 : 1.0
#                 Protests = True             NONE : DOWN   =      2.9 : 1.0
#                   Stress = True             NONE : DOWN   =      2.9 : 1.0
#        ('Air', 'France') = True             NONE : DOWN   =      2.9 : 1.0
#                    Heart = True             NONE : DOWN   =      2.9 : 1.0
#                    Intel = True               UP : NONE   =      2.9 : 1.0
#                     Taps = True               UP : NONE   =      2.9 : 1.0
#                      Gas = True             NONE : UP     =      2.9 : 1.0
#                    Visit = True             DOWN : NONE   =      2.8 : 1.0
#    ('General', 'Growth') = True             DOWN : NONE   =      2.8 : 1.0
#                Genentech = True             DOWN : NONE   =      2.8 : 1.0
#           ('to', 'Step') = True               UP : NONE   =      2.8 : 1.0
#                   Delays = True               UP : NONE   =      2.8 : 1.0
#          ('in', 'Japan') = True               UP : NONE   =      2.8 : 1.0
#                    Would = True               UP : NONE   =      2.8 : 1.0
#                   Debate = True               UP : NONE   =      2.8 : 1.0
#                 National = True               UP : NONE   =      2.8 : 1.0
#                   iPhone = True             NONE : UP     =      2.8 : 1.0
#                   Leader = True             NONE : UP     =      2.8 : 1.0
#                  Missile = True             DOWN : NONE   =      2.8 : 1.0
#                     Mall = True             DOWN : NONE   =      2.8 : 1.0
#                  Pioneer = True             DOWN : NONE   =      2.8 : 1.0
#                   Shakes = True             DOWN : NONE   =      2.8 : 1.0
#                      Aer = True             DOWN : NONE   =      2.8 : 1.0
#                 Detained = True             DOWN : NONE   =      2.8 : 1.0
#                  Request = True             DOWN : NONE   =      2.8 : 1.0
#       ('SEC', 'Charges') = True             DOWN : NONE   =      2.8 : 1.0
#            ('Off', 'in') = True             DOWN : NONE   =      2.8 : 1.0
#                      Woo = True             DOWN : NONE   =      2.8 : 1.0
#                 Football = True             DOWN : NONE   =      2.8 : 1.0
#         ('Jobs', 'Data') = True             DOWN : NONE   =      2.8 : 1.0
#                 Tensions = True             DOWN : NONE   =      2.8 : 1.0
#     ('Stimulus', 'Bill') = True             DOWN : NONE   =      2.8 : 1.0
#        ('Reach', 'Deal') = True             DOWN : NONE   =      2.8 : 1.0
#       ('Court', 'Sides') = True             DOWN : NONE   =      2.8 : 1.0
#         ('Calls', 'for') = True             DOWN : NONE   =      2.8 : 1.0
#                    Thain = True             DOWN : NONE   =      2.8 : 1.0
#                    Skype = True             DOWN : NONE   =      2.8 : 1.0
#        ('Focuses', 'on') = True             DOWN : NONE   =      2.8 : 1.0
#         ('Funds', 'for') = True             DOWN : NONE   =      2.8 : 1.0
#                   Iberia = True             DOWN : NONE   =      2.8 : 1.0
#                  Chevron = True             DOWN : NONE   =      2.8 : 1.0
#                  Suspect = True             DOWN : NONE   =      2.8 : 1.0
#           ('Move', 'to') = True             DOWN : NONE   =      2.8 : 1.0
#                 Receives = True             DOWN : NONE   =      2.8 : 1.0
#          ('AB', 'InBev') = True             DOWN : NONE   =      2.8 : 1.0
#                    Field = True             DOWN : NONE   =      2.8 : 1.0
#                 Outlines = True             DOWN : NONE   =      2.8 : 1.0
#                   Action = True             DOWN : NONE   =      2.8 : 1.0
#      ('for', 'Stimulus') = True             DOWN : NONE   =      2.8 : 1.0
#                  Tighten = True             DOWN : NONE   =      2.8 : 1.0
#                 Emerging = True             DOWN : NONE   =      2.8 : 1.0
#            International = True             DOWN : NONE   =      2.8 : 1.0
#                     Park = True             DOWN : NONE   =      2.8 : 1.0
#         ('Sees', 'More') = True             DOWN : NONE   =      2.8 : 1.0
#                Venezuela = True             DOWN : NONE   =      2.8 : 1.0
#                     Raid = True             DOWN : NONE   =      2.8 : 1.0
#                    Watch = True             DOWN : NONE   =      2.8 : 1.0
#                     Pope = True             DOWN : NONE   =      2.8 : 1.0
#                      Tap = True             DOWN : NONE   =      2.8 : 1.0
#            ('of', 'New') = True             DOWN : NONE   =      2.8 : 1.0
#                  Seagate = True             DOWN : NONE   =      2.8 : 1.0
#                      Day = True             DOWN : NONE   =      2.8 : 1.0
#          ('Loss', 'for') = True             DOWN : NONE   =      2.8 : 1.0
#            ('Bet', 'on') = True             DOWN : NONE   =      2.8 : 1.0
#                    Stirs = True             DOWN : NONE   =      2.8 : 1.0
#                    InBev = True             DOWN : NONE   =      2.8 : 1.0
#                    Crude = True             DOWN : NONE   =      2.8 : 1.0
#                  Propose = True             DOWN : NONE   =      2.8 : 1.0
#                    Focus = True             DOWN : UP     =      2.8 : 1.0
#         ('Hong', 'Kong') = True             DOWN : UP     =      2.8 : 1.0
#                     Loan = True             DOWN : UP     =      2.8 : 1.0
#                     Kong = True             DOWN : UP     =      2.8 : 1.0
#                    Power = True               UP : DOWN   =      2.7 : 1.0
#                    Hynix = True               UP : NONE   =      2.7 : 1.0
#         ('Net', 'Slips') = True               UP : NONE   =      2.7 : 1.0
#        ('Plans', 'More') = True               UP : NONE   =      2.7 : 1.0
#                      Due = True               UP : NONE   =      2.7 : 1.0
#                     Wait = True               UP : NONE   =      2.7 : 1.0
#                 Explores = True               UP : NONE   =      2.7 : 1.0
#                      CIC = True               UP : NONE   =      2.7 : 1.0
#                  Parties = True               UP : NONE   =      2.7 : 1.0
#                  Station = True               UP : NONE   =      2.7 : 1.0
#                     Wine = True               UP : NONE   =      2.7 : 1.0
#                    Peace = True               UP : NONE   =      2.7 : 1.0
#                    Guide = True               UP : NONE   =      2.7 : 1.0
#                   Killed = True               UP : NONE   =      2.7 : 1.0
#           ('to', 'Back') = True               UP : NONE   =      2.7 : 1.0
#                 Cerberus = True               UP : NONE   =      2.7 : 1.0
#                     June = True               UP : NONE   =      2.7 : 1.0
#                Hutchison = True               UP : NONE   =      2.7 : 1.0
#                    Value = True               UP : NONE   =      2.7 : 1.0
#                  January = True               UP : NONE   =      2.7 : 1.0
#      ('Than', 'Doubles') = True               UP : NONE   =      2.7 : 1.0
#                    Merge = True               UP : NONE   =      2.7 : 1.0
#                Estimates = True               UP : NONE   =      2.7 : 1.0
#   ('British', 'Airways') = True               UP : NONE   =      2.7 : 1.0
#   ('Consumer', 'Prices') = True               UP : NONE   =      2.7 : 1.0
#                    Today = True               UP : NONE   =      2.7 : 1.0
#            ('as', 'Net') = True               UP : NONE   =      2.7 : 1.0
#                 Prepares = True               UP : NONE   =      2.7 : 1.0
#                   DuPont = True               UP : NONE   =      2.7 : 1.0
#                      LCD = True               UP : NONE   =      2.7 : 1.0
#        ('Million', 'in') = True               UP : NONE   =      2.7 : 1.0
#        ('Fight', 'Over') = True               UP : NONE   =      2.7 : 1.0
#            ('for', 'in') = True               UP : NONE   =      2.7 : 1.0
#               Indonesian = True               UP : NONE   =      2.7 : 1.0
#      ('Climate', 'Bill') = True               UP : NONE   =      2.7 : 1.0
#                  Calpers = True               UP : NONE   =      2.7 : 1.0
#         ('Las', 'Vegas') = True               UP : NONE   =      2.7 : 1.0
#     ('Posts', 'Million') = True               UP : NONE   =      2.7 : 1.0
#                      Las = True               UP : NONE   =      2.7 : 1.0
#           ('Role', 'in') = True               UP : NONE   =      2.7 : 1.0
#                      EMC = True               UP : NONE   =      2.7 : 1.0
#               Settlement = True               UP : NONE   =      2.7 : 1.0
#                    Canon = True               UP : NONE   =      2.7 : 1.0
#          ('May', 'Have') = True               UP : NONE   =      2.7 : 1.0
#                   Allies = True               UP : NONE   =      2.7 : 1.0
#       ('North', 'Korea') = True               UP : NONE   =      2.7 : 1.0
#          ('Job', 'Cuts') = True             DOWN : NONE   =      2.7 : 1.0
#                Retailers = True             DOWN : NONE   =      2.7 : 1.0
#                     Gain = True               UP : DOWN   =      2.7 : 1.0
#          ('Seeks', 'to') = True             DOWN : UP     =      2.7 : 1.0
#                    Loans = True             DOWN : NONE   =      2.7 : 1.0
#          ('to', 'Close') = True               UP : NONE   =      2.6 : 1.0
#                    Panel = True               UP : NONE   =      2.6 : 1.0
#                     Toll = True               UP : NONE   =      2.6 : 1.0
#            ('on', 'the') = True             DOWN : UP     =      2.6 : 1.0
#       ('Hedge', 'Funds') = True             DOWN : UP     =      2.6 : 1.0
#                  Returns = True             DOWN : UP     =      2.6 : 1.0
#               Regulation = True             DOWN : UP     =      2.6 : 1.0
#                  Strikes = True             DOWN : UP     =      2.6 : 1.0
#        ('Posts', 'Loss') = True               UP : NONE   =      2.6 : 1.0
#                 Stanford = True             DOWN : NONE   =      2.6 : 1.0
#                   Begins = True             DOWN : NONE   =      2.6 : 1.0
#          ('to', 'Leave') = True             DOWN : NONE   =      2.6 : 1.0
#                    First = True             DOWN : NONE   =      2.6 : 1.0
#                    Shows = True             DOWN : NONE   =      2.6 : 1.0
#                     HSBC = True             NONE : UP     =      2.6 : 1.0
#                    Corus = True             NONE : UP     =      2.6 : 1.0
#                  Hurdles = True             NONE : UP     =      2.6 : 1.0
#                     Life = True             NONE : UP     =      2.6 : 1.0
#                    Total = True             NONE : UP     =      2.6 : 1.0
#                    Spurs = True             NONE : UP     =      2.6 : 1.0
#                     West = True             NONE : UP     =      2.6 : 1.0
#                    Cases = True             NONE : UP     =      2.6 : 1.0
#                       Re = True             NONE : UP     =      2.6 : 1.0
#                      Why = True             NONE : UP     =      2.6 : 1.0
#                    Phone = True             NONE : UP     =      2.6 : 1.0
#                     TALF = True             NONE : UP     =      2.6 : 1.0
#                     Flee = True             NONE : UP     =      2.6 : 1.0
#                     Real = True             NONE : UP     =      2.6 : 1.0
#       ('Drug', 'Makers') = True             NONE : UP     =      2.6 : 1.0
#                     Boom = True             NONE : UP     =      2.6 : 1.0
#                 Payments = True             NONE : UP     =      2.6 : 1.0
#                   Income = True               UP : DOWN   =      2.6 : 1.0
#                 Software = True               UP : DOWN   =      2.6 : 1.0
#                       At = True               UP : DOWN   =      2.6 : 1.0
#                    Slide = True               UP : DOWN   =      2.6 : 1.0
#                   Battle = True               UP : DOWN   =      2.6 : 1.0
#        ('Job', 'Losses') = True               UP : DOWN   =      2.6 : 1.0
#                Forecasts = True               UP : DOWN   =      2.6 : 1.0
#          ('Rises', 'on') = True               UP : DOWN   =      2.6 : 1.0
#                    Slows = True               UP : NONE   =      2.6 : 1.0
#         ('Names', 'New') = True               UP : NONE   =      2.5 : 1.0
#                    Nears = True             NONE : DOWN   =      2.5 : 1.0
#                  Approve = True             NONE : DOWN   =      2.5 : 1.0
#                    Opens = True             NONE : DOWN   =      2.5 : 1.0
#                  Package = True             NONE : DOWN   =      2.5 : 1.0
#                     Seat = True             NONE : DOWN   =      2.5 : 1.0
#                     Ends = True             NONE : DOWN   =      2.5 : 1.0
#                   Second = True             NONE : DOWN   =      2.5 : 1.0
#                    Ahead = True             NONE : DOWN   =      2.5 : 1.0
#           ('to', 'Drop') = True             NONE : DOWN   =      2.5 : 1.0
#                     Bomb = True             NONE : DOWN   =      2.5 : 1.0
#                  Pledges = True             NONE : DOWN   =      2.5 : 1.0
#                  Eastern = True             DOWN : NONE   =      2.5 : 1.0
#            Manufacturing = True             DOWN : NONE   =      2.5 : 1.0
#                    Sides = True             DOWN : NONE   =      2.5 : 1.0
#                  Focuses = True             DOWN : NONE   =      2.5 : 1.0
#       ('for', 'Chapter') = True             DOWN : NONE   =      2.5 : 1.0
#           ('of', 'Work') = True             DOWN : NONE   =      2.5 : 1.0
#    ('Private', 'Equity') = True             DOWN : NONE   =      2.5 : 1.0
#                  Savings = True             DOWN : NONE   =      2.5 : 1.0
#                    Needs = True             DOWN : NONE   =      2.5 : 1.0
#                      Lay = True             DOWN : NONE   =      2.5 : 1.0
#                  Project = True             DOWN : NONE   =      2.5 : 1.0
#                    Roots = True             DOWN : NONE   =      2.5 : 1.0
#                      Bet = True             DOWN : NONE   =      2.5 : 1.0
#                   Clears = True             DOWN : NONE   =      2.5 : 1.0
#                    Cisco = True             DOWN : NONE   =      2.5 : 1.0
#                    Volvo = True               UP : NONE   =      2.5 : 1.0
#                   Forces = True               UP : NONE   =      2.5 : 1.0
#               Securities = True               UP : NONE   =      2.5 : 1.0
#            ('to', 'End') = True               UP : NONE   =      2.5 : 1.0
#                   Easing = True               UP : NONE   =      2.5 : 1.0
#                     Good = True               UP : NONE   =      2.5 : 1.0
#                    Paper = True               UP : NONE   =      2.5 : 1.0
#           ('in', '2008') = True               UP : NONE   =      2.5 : 1.0
#      ('Case', 'Against') = True               UP : NONE   =      2.5 : 1.0
#                  MySpace = True               UP : NONE   =      2.5 : 1.0
#                  Russian = True             DOWN : NONE   =      2.5 : 1.0
#                    Makes = True             DOWN : NONE   =      2.5 : 1.0

# %%
from nltk.classify import DecisionTreeClassifier
dt_classifier = DecisionTreeClassifier.train(train_feats)#, entropy_cutoff=0.8, depth_cutoff=5, support_cutoff=30)

# %%
accuracy(dt_classifier, test_feats)
# Out:
# 0.3055555555555556

# %%
from nltk.classify import MaxentClassifier
me_classifier = MaxentClassifier.train(train_feats)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-69a5376f7192> in <module>()
#       1 from nltk.classify import MaxentClassifier
# ----> 2 me_classifier = MaxentClassifier.train(train_feats)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/nltk/classify/maxent.pyc in train(cls, train_toks, algorithm, trace, encoding, labels, sparse, gaussian_prior_sigma, **cutoffs)
#     309                 train_toks, trace, encoding, labels,
#     310                 cls._SCIPY_ALGS[algorithm], sparse,
# --> 311                 gaussian_prior_sigma, **cutoffs)
#     312         elif algorithm == 'megam':
#     313             return train_maxent_classifier_with_megam(
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/nltk/classify/maxent.pyc in train_maxent_classifier_with_scipy(train_toks, trace, encoding, labels, algorithm, sparse, gaussian_prior_sigma, **cutoffs)
#    1434
#    1435     # Train the model.
# -> 1436     model.fit(algorithm=algorithm)
#    1437
#    1438     # Convert the model's weights from base-e to base-2 weights.
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/scipy/maxentropy/maxentropy.py in fit(self, algorithm)
#    1025
#    1026         # Call base class method
# -> 1027         return model.fit(self, self.K, algorithm)
#    1028
#    1029
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/scipy/maxentropy/maxentropy.py in fit(self, K, algorithm)
#     225                                       maxiter=self.maxiter, full_output=1, \
#     226                                       disp=self.verbose, retall=0,
# --> 227                                       callback=callback)
#     228
#     229             (newparams, fopt, func_calls, grad_calls, warnflag) = retval
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/scipy/optimize/optimize.py in fmin_cg(f, x0, fprime, args, gtol, norm, epsilon, maxiter, full_output, disp, retall, callback)
#     689     else:
#     690         grad_calls, myfprime = wrap_function(fprime, args)
# --> 691     gfk = myfprime(x0)
#     692     k = 0
#     693     N = len(x0)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/scipy/optimize/optimize.py in function_wrapper(x)
#     174     def function_wrapper(x):
#     175         ncalls[0] += 1
# --> 176         return function(x, *args)
#     177     return ncalls, function_wrapper
#     178
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/scipy/maxentropy/maxentropy.py in grad(self, params, ignorepenalty)
#     419             self.setparams(params)
#     420
# --> 421         G = self.expectations() - self.K
#     422
#     423         if self.verbose and self.external is None:
#
# ValueError: operands could not be broadcast together with shapes (648) (6198)
# Grad eval #0

# %%
accuracy(me_classifier, test_feats)

# %%
fdist = FreqDist(reader)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-05e4a813f3cb> in <module>()
# ----> 1 fdist = FreqDist(reader)
#
# NameError: name 'FreqDist' is not defined

# %%
fdist = nltk.FreqDist(reader.words())

# %%
vocab = fdist.keys()

# %%
vocab[:50]
# Out:
# ['to',
#  'in',
#  'on',
#  'for',
#  'of',
#  'Profit',
#  'China',
#  'Loss',
#  'New',
#  'a',
#  'Net',
#  'Deal',
#  'Sales',
#  'Is',
#  'Bank',
#  'at',
#  'Posts',
#  'the',
#  'Cuts',
#  'Stocks',
#  'as',
#  'With',
#  'Plan',
#  'Banks',
#  'Cut',
#  'Plans',
#  'Up',
#  'CEO',
#  'Falls',
#  'More',
#  'Over',
#  'Jobs',
#  'GM',
#  'Sees',
#  'Seeks',
#  'May',
#  'Obama',
#  'Swings',
#  'Fall',
#  'Billion',
#  'The',
#  'Buy',
#  'Gets',
#  'Firms',
#  'Talks',
#  'Rise',
#  'Stake',
#  'Says',
#  'by',
#  'Oil']

# %%
fdist
# Out:
# <FreqDist with 8548 samples and 52653 outcomes>

# %%
fdist.plot(50, cumulative=True)
