# %%
import nltk as nltk

# %%
import os, os.path

# %%
path = os.path.expanduser('~/nltk_data')

# %%
if not os.path.exists(path):
    os.mkdir(path)
os.path.exists(path)
# Out:
# True

# %%
import nltk.data

# %%
path in nltk.data.path
# Out:
# True

# %%
from nltk.corpus.reader import CategorizedPlaintextCorpusReader

# %%
reader2 = CategorizedPlaintextCorpusReader('.', r'news_.*\.csv', cat_pattern=r'news_(\w+)\.csv')

# %%
reader.categories()
# Out:
# ['DOWN', 'NONE', 'UP']

# %%
reader.fileids(categories=['UP'])
# Out:
# ['news_UP.csv']

# %%
def bag_of_words(words):
    return dict([(word, True) for word in words])

# %%
import collections

# %%
def label_feats_from_corpus(corp, feature_detector=bag_of_words):
    label_feats = collections.defaultdict(list)
    for label in corp.categories():
        for fileid in corp.fileids(categories=[label]):
            feats = feature_detector(corp.words(fileids=[fileid]))
            label_feats[label].append(feats)
    return label_feats

# %%
def split_label_feats(lfeats, split=0.75):
    train_feats = []
    test_feats = []
    for label, feats in lfeats.iteritems():
        cutoff = int(len(feats) * split)
        train_feats.extend([(feat, label) for feat in feats[:cutoff]])
        test_feats.extend([(feat, label) for feat in feats[cutoff:]])
    return train_feats, test_feats

# %%
reader.categories()
# Out:
# ['DOWN', 'NONE', 'UP']

# %%
lfeats = label_feats_from_corpus(reader2)

# %%
lfeats.keys()
# Out:
# ['DOWN', 'NONE', 'UP']

# %%
train_feats, test_feats = split_label_feats(lfeats)

# %%
len(train_feats)
# Out:
# 0

# %%
len(test_feats)
# Out:
# 3

# %%
len(lfeats)
# Out:
# 3

# %%
reader.?
# Out:
# Object `reader.` not found.

# %%
reader.words
# Out:
# <bound method CategorizedPlaintextCorpusReader.words of <CategorizedPlaintextCorpusReader in '/Users/lyonwj/Documents/CSCI_555/GradProj'>>

# %%
reader2.words()
# Out:
# ['2010', '-', '11', '-', '10', '00', ':', '00', ':', ...]

# %%
reader2.raw()
# Out:
# '2010-11-10 00:00:00,Dentsu Inc. Announces Partnership with Apple Inc. to Bring iAd to Japan\n2010-11-16 00:00:00,Hrvatski Telekom d.d. Signs Agreement With Apple Inc.&#39;s Apcom/Powercom\n2010-12-16 00:00:00,"Nokia Oyj Files Patent Infringement Complaints against Apple Inc. in UK, Germany and Netherlands"\n2010-12-28 00:00:00,Apple Inc. Sued For Allegedly Sending User Data To Advertisers-DJ\n2010-12-29 00:00:00,"Microsoft Co-founder Relaunches Tech Patent Suit Against Apple Inc., Google Inc., Facebook And Others-Reuters"\n2011-01-11 00:00:00,"Hagens Berman Investigates Claims Apple Inc.&#39;s iPhone 4&#39;s Glass Prone to Scratches, Breakage"\n2011-01-18 00:00:00,Apple Inc. Issues Q2 2011 Guidance Above Analysts&#39; Estimates\n2011-01-24 00:00:00,Eastman Kodak Company Receives Notice of Initial Determination In ITC Patent Infringement Action Against Apple Inc. And Research In Motion Limited\n2011-01-31 00:00:00,Wi-LAN Inc. To Reach Settlement With Apple Inc.\n2011-02-17 00:00:00,"
# ...

# %%
print lfeats
# Out:
# defaultdict(<type 'list'>, {'DOWN': [{'Sell': True, 'Canada': True, 'founder': True, 'CORRECTION': True, 'Does': True, 'Department': True, 'Subsidiaries': True, 'Prone': True, 'Notice': True, 'Business': True, 'Award': True, 'Standard': True, 'to': True, 'Joins': True, 'Not': True, 'Eight': True, 'Battling': True, 'Notches': True, 'Sale': True, 'Tech': True, 'Co': True, 'LAN': True, 'Chomp': True, 'Talking': True, 'Tab': True, 'Distributor': True, 'Glass': True, 'Tablet': True, 'Lawsuits': True, 'Unfair': True, 'Favor': True, 'Version': True, 'Damages': True, 'Suit': True, 'Seeks': True, 'Appeal': True, '.&#': True, 'Tried': True, 'Collaboration': True, 'Antitrust': True, 'Amazon': True, 'Imaging': True, 'CEOs': True, ';': True, 'Schuster': True, 'Pricing': True, 'Ipad': True, 'Motorola': True, 'Counterclaim': True, 'Ahead': True, 'Bids': True, 'Arthur': True, '&#': True, 'Ltd': True, '39': True, 'Sees': True, 'Chinese': True, '31': True, '30': True, 'CBS': True, 'Out': True, 'Techno
# ...

# %%
len(train_feats)
# Out:
# 0

# %%
len(test_feats)
# Out:
# 3

# %%
print test_feats['UP']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-99c38ad57af8> in <module>()
# ----> 1 print test_feats['UP']
#
# TypeError: list indices must be integers, not str

# %%
len(test_feats)
# Out:
# 3

# %%
from nltk.classify import NaiveBayesClassifier

# %%
nb_classifier = NaiveBayesClassifier.train(test_feats)

# %%
nb_classifier.labels()
# Out:
# ['DOWN', 'NONE', 'UP']

# %%
from nltk.classify.util import accuracy

# %%
accuracy(nb_classifier, test_feats)
# Out:
# 0.3333333333333333

# %%
news_item = bag_of_words(['AAPL', 'plunges', 'on', 'Cooks', 'new', 'management', 'team'])

# %%
nb_classifier.classify(news_item)
# Out:
# 'UP'

# %%
fdist = nltk.FreqDist(reader.words())

# %%
fdist.keys()
# Out:
# ['00',
#  '-',
#  ':',
#  'Inc',
#  'Apple',
#  ',',
#  '.',
#  '2012',
#  'Reuters',
#  '2011',
#  ',"',
#  '"',
#  ';',
#  'Co',
#  'Ltd',
#  'Samsung',
#  'Electronics',
#  '39',
#  'In',
#  '.,',
#  'To',
#  's',
#  '&#',
#  'Against',
#  '07',
#  'Patent',
#  '08',
#  'DJ',
#  'And',
#  '04',
#  '06',
#  'On',
#  '09',
#  '03',
#  '02',
#  '10',
#  'Court',
#  'With',
#  'Files',
#  '.&#',
#  '.-',
#  '11',
#  'Over',
#  'Patents',
#  'Corp',
#  'Google',
#  'Judge',
#  '01',
#  '24',
#  'Lawsuit',
#  'iPad',
#  '18',
#  'Corporation',
#  'For',
#  'S',
#  'Sues',
#  'US',
#  '12',
#  'Company',
#  'U',
#  '05',
#  '20',
#  '22',
#  '25',
#  'Complaint',
#  'HTC',
#  'Talks',
#  'iPhone',
#  '14',
#  '17',
#  '19',
#  'Announces',
#  'Eastman',
#  'Guidance',
#  'Kodak',
#  'Limited',
#  'Of',
#  'Says',
#  'Suit',
#  'Wins',
#  'of',
#  '$',
#  '15',
#  '2010',
#  '29',
#  'Action',
#  'Analysts',
#  'Bid',
#  'Case',
#  'Estimates',
#  'From',
#  'Holdings',
# ...

# %%
vocab = fdist.keys()

# %%
vocab[:50]
# Out:
# ['00',
#  '-',
#  ':',
#  'Inc',
#  'Apple',
#  ',',
#  '.',
#  '2012',
#  'Reuters',
#  '2011',
#  ',"',
#  '"',
#  ';',
#  'Co',
#  'Ltd',
#  'Samsung',
#  'Electronics',
#  '39',
#  'In',
#  '.,',
#  'To',
#  's',
#  '&#',
#  'Against',
#  '07',
#  'Patent',
#  '08',
#  'DJ',
#  'And',
#  '04',
#  '06',
#  'On',
#  '09',
#  '03',
#  '02',
#  '10',
#  'Court',
#  'With',
#  'Files',
#  '.&#',
#  '.-',
#  '11',
#  'Over',
#  'Patents',
#  'Corp',
#  'Google',
#  'Judge',
#  '01',
#  '24',
#  'Lawsuit']

# %%
fdist.plot(50, cumulative=True)

# %%
fdist.hapaxes()
# Out:
# []

# %%
probs = nb_classifier.prob_classify(test_feats[0][0])

# %%
probs.samples()
# Out:
# ['DOWN', 'NONE', 'UP']

# %%
probs.max()
# Out:
# 'UP'

# %%
probs.prob('UP')
# Out:
# 0.33333333333333215

# %%
probs.prob('DOWN')
# Out:
# 0.33333333333333215

# %%
nb_classifier.most_informative_features(n=10)
# Out:
# [('Pearson', True),
#  ('Resigns', True),
#  ('Pay', True),
#  ('22', True),
#  ('Judgement', True),
#  ('Complaints', True),
#  ('Property', True),
#  ('Safari', True),
#  ('Cisco', True),
#  ('Mobility', True)]

# %%
nb_classifier.show_most_informative_features(n=1000)
# Out:
# Most Informative Features
#                  Pearson = True               UP : DOWN   =      1.0 : 1.0
#                  Resigns = True               UP : DOWN   =      1.0 : 1.0
#                      Pay = True               UP : DOWN   =      1.0 : 1.0
#                       22 = True               UP : DOWN   =      1.0 : 1.0
#                Judgement = True               UP : DOWN   =      1.0 : 1.0
#               Complaints = True               UP : DOWN   =      1.0 : 1.0
#                 Property = True               UP : DOWN   =      1.0 : 1.0
#                   Safari = True               UP : DOWN   =      1.0 : 1.0
#                    Cisco = True               UP : DOWN   =      1.0 : 1.0
#                 Mobility = True               UP : DOWN   =      1.0 : 1.0
#                  Federal = True               UP : DOWN   =      1.0 : 1.0
#                 Motorola = True               UP : DOWN   =      1.0 : 1.0
# ...
